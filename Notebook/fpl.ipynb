# %%
import pandas as pd
import numpy as np
import sasoptpy as so
import requests
import os

import time
from subprocess import Popen, DEVNULL
gw = 34
ft=1
horizon = 5

# %%
def xmin_to_prob(xmin, sub_on=0.5, sub_off=0.3):
    start = min(max((xmin - 25 * sub_on) / (90 * (1-sub_off) +
                65 * sub_off - 25 * sub_on), 0.001), 0.999)
    return start + (1-start) * sub_on

# %%
def get_data(team_id, gw, seed_val, horizon, randomized):
    r = requests.get('https://fantasy.premierleague.com/api/bootstrap-static/')
    fpl_data = r.json()
    element_data = pd.DataFrame(fpl_data['elements'])
    team_data = pd.DataFrame(fpl_data['teams'])
    elements_team = pd.merge(element_data, team_data,
                             left_on='team', right_on='id')
    review_data = pd.read_csv('../Data/fplreview.csv')
    review_data = review_data.fillna(0)
    review_data['review_id'] = review_data.index+1
    merged_data = pd.merge(elements_team, review_data,
                           left_on='id_x', right_on='review_id')
    merged_data.set_index(['id_x'], inplace=True)

    if randomized:
        rng = np.random.default_rng(seed=seed_val)
        gws = list(range(gw+1, min(39, gw+1+horizon)))
        for w in gws:
            noise = merged_data[f"{w}_Pts"] * (
                92 - merged_data[f"{w}_xMins"]) / 134 * rng.standard_normal(size=len(merged_data))
            merged_data[f"{w}_Pts"] = merged_data[f"{w}_Pts"] + noise

    next_gw = int(review_data.keys()[6].split('_')[0])
    type_data = pd.DataFrame(fpl_data['element_types']).set_index(['id'])

    r = requests.get(
        f'https://fantasy.premierleague.com/api/entry/{team_id}/event/{gw}/picks/')
    picks_data = r.json()
    initial_squad = [i['element'] for i in picks_data['picks']]
    r = requests.get(f'https://fantasy.premierleague.com/api/entry/{team_id}/')
    general_data = r.json()
    itb = general_data['last_deadline_bank'] / 10

    return {'merged_data': merged_data, 'team_data': team_data, 'type_data': type_data, 'next_gw': next_gw, 'initial_squad': initial_squad, 'itb': itb}

# %%
# review_data = pd.read_csv('../Data/xp_points.csv')
# next_gw = int(review_data.keys()[6].split('_')[0])
# next_gw

# %%
def solve_multi_period_fpl(team_id, gw, ft, horizon, objective='regular', decay_base=0.85, bench_weights=None, seed=None, randomized=False):
    """
    Solves multi-objective FPL problem with transfers
    Parameters
    ----------
    team_id: integer
        FPL ID of the team to be optimized
    gw: integer
        Upcoming (next) gameweek
    ft: integer
        Number of available free transfers (currently)
    horizon: integer
        Number of weeks to consider in optimization
    objective: string
        Type of objective "regular" or "decay"
    decay_base: float
        Base for the decay function
    """

    # Data
    problem_name = f'mp_h{horizon}_regular' if objective == 'regular' else f'mp_h{horizon}_o{objective[0]}_d{decay_base}'
    data = get_data(team_id, gw-1, seed, horizon, randomized)
    merged_data = data['merged_data']
    team_data = data['team_data']
    type_data = data['type_data']
    next_gw = data['next_gw']
    initial_squad = data['initial_squad']
    itb = data['itb']

    # Sets
    players = merged_data.index.to_list()
    element_types = type_data.index.to_list()
    teams = team_data['name'].to_list()
    gameweeks = list(range(next_gw, next_gw+horizon))
    all_gw = [next_gw-1] + gameweeks
    order = [0, 1, 2, 3]
    if bench_weights is None:
        bench_weights = {0: 0.03, 1: 0.21, 2: 0.06, 3: 0.002}

    # Model
    model = so.Model(name=problem_name)

    # Variables
    squad = model.add_variables(
        players, all_gw, name='squad', vartype=so.binary)
    lineup = model.add_variables(
        players, gameweeks, name='lineup', vartype=so.binary)
    captain = model.add_variables(
        players, gameweeks, name='captain', vartype=so.binary)
    vicecap = model.add_variables(
        players, gameweeks, name='vicecap', vartype=so.binary)
    bench = model.add_variables(
        players, gameweeks, order, name='bench', vartype=so.binary)
    transfer_in = model.add_variables(
        players, gameweeks, name='transfer_in', vartype=so.binary)
    transfer_out = model.add_variables(
        players, gameweeks, name='transfer_out', vartype=so.binary)
    in_the_bank = model.add_variables(
        all_gw, name='itb', vartype=so.continuous, lb=0)
    free_transfers = model.add_variables(
        all_gw, name='ft', vartype=so.integer, lb=1, ub=2)
    penalized_transfers = model.add_variables(
        gameweeks, name='pt', vartype=so.integer, lb=0)
    aux = model.add_variables(gameweeks, name='aux', vartype=so.binary)

    # Dictionaries
    lineup_type_count = {(t, w): so.expr_sum(
        lineup[p, w] for p in players if merged_data.loc[p, 'element_type'] == t) for t in element_types for w in gameweeks}
    squad_type_count = {(t, w): so.expr_sum(
        squad[p, w] for p in players if merged_data.loc[p, 'element_type'] == t) for t in element_types for w in gameweeks}
    player_type = merged_data['element_type'].to_dict()

    # player_price = (merged_data['now_cost'] / 10).to_dict()
    sell_price = (merged_data['SV']).to_dict()
    buy_price = (merged_data['BV']).to_dict()
    sold_amount = {w: so.expr_sum(
        sell_price[p] * transfer_out[p, w] for p in players) for w in gameweeks}
    bought_amount = {w: so.expr_sum(
        buy_price[p] * transfer_in[p, w] for p in players) for w in gameweeks}
    points_player_week = {
        (p, w): merged_data.loc[p, f'{w}_Pts'] for p in players for w in gameweeks}
    minutes_player_week = {
        (p, w): merged_data.loc[p, f'{w}_xMins'] for p in players for w in gameweeks}
    squad_count = {w: so.expr_sum(squad[p, w]
                                  for p in players) for w in gameweeks}
    number_of_transfers = {w: so.expr_sum(
        transfer_out[p, w] for p in players) for w in gameweeks}
    number_of_transfers[next_gw-1] = 1
    transfer_diff = {
        w: number_of_transfers[w] - free_transfers[w] for w in gameweeks}

    # Initial conditions
    model.add_constraints(
        (squad[p, next_gw-1] == 1 for p in initial_squad), name='initial_squad_players')
    model.add_constraints(
        (squad[p, next_gw-1] == 0 for p in players if p not in initial_squad), name='initial_squad_others')
    model.add_constraint(in_the_bank[next_gw-1] == itb, name='initial_itb')
    model.add_constraint(free_transfers[next_gw-1] == ft, name='initial_ft')

    # Constraints
    model.add_constraints(
        (squad_count[w] == 15 for w in gameweeks), name='squad_count')
    model.add_constraints((so.expr_sum(
        lineup[p, w] for p in players) == 11 for w in gameweeks), name='lineup_count')
    model.add_constraints((so.expr_sum(
        bench[p, w, 0] for p in players if player_type[p] == 1) == 1 for w in gameweeks), name='bench_gk')
    model.add_constraints((so.expr_sum(
        bench[p, w, o] for p in players) == 1 for w in gameweeks for o in [1, 2, 3]), name='bench_count')
    model.add_constraints((so.expr_sum(
        captain[p, w] for p in players) == 1 for w in gameweeks), name='captain_count')
    model.add_constraints((so.expr_sum(
        vicecap[p, w] for p in players) == 1 for w in gameweeks), name='vicecap_count')
    model.add_constraints((lineup[p, w] <= squad[p, w]
                          for p in players for w in gameweeks), name='lineup_squad_rel')
    model.add_constraints((bench[p, w, o] <= squad[p, w]
                          for p in players for w in gameweeks for o in order), name='bench_squad_rel')
    model.add_constraints((captain[p, w] <= lineup[p, w]
                          for p in players for w in gameweeks), name='captain_lineup_rel')
    model.add_constraints((vicecap[p, w] <= lineup[p, w]
                          for p in players for w in gameweeks), name='vicecap_lineup_rel')
    model.add_constraints((captain[p, w] + vicecap[p, w] <=
                          1 for p in players for w in gameweeks), name='cap_vc_rel')
    model.add_constraints((lineup[p, w] + so.expr_sum(bench[p, w, o] for o in order)
                          <= 1 for p in players for w in gameweeks), name='lineup_bench_rel')
    model.add_constraints((lineup_type_count[t, w] == [type_data.loc[t, 'squad_min_play'], type_data.loc[t,
                          'squad_max_play']] for t in element_types for w in gameweeks), name='valid_formation')
    model.add_constraints((squad_type_count[t, w] == type_data.loc[t, 'squad_select']
                          for t in element_types for w in gameweeks), name='valid_squad')
    model.add_constraints((so.expr_sum(squad[p, w] for p in players if merged_data.loc[p,
                          'name'] == t) <= 3 for t in teams for w in gameweeks), name='team_limit')

    # Transfer constraints
    model.add_constraints((squad[p, w] == squad[p, w-1] + transfer_in[p, w] - transfer_out[p, w]
                          for p in players for w in gameweeks), name='squad_transfer_rel')
    model.add_constraints((in_the_bank[w] == in_the_bank[w-1] + sold_amount[w] -
                          bought_amount[w] for w in gameweeks), name='cont_budget')

    # Free transfer constraints
    model.add_constraints(
        (free_transfers[w] == aux[w] + 1 for w in gameweeks), name='aux_ft_rel')
    model.add_constraints((free_transfers[w-1] - number_of_transfers[w-1]
                          <= 2 * aux[w] for w in gameweeks), name='force_aux_1')
    model.add_constraints((free_transfers[w-1] - number_of_transfers[w-1]
                          >= aux[w] + (-14)*(1-aux[w]) for w in gameweeks), name='force_aux_2')
    model.add_constraints(
        (penalized_transfers[w] >= transfer_diff[w] for w in gameweeks), name='pen_transfer_rel')

    # Objectives
    gw_xp = {w: so.expr_sum(points_player_week[p, w] * (lineup[p, w] + captain[p, w] + 0.1*vicecap[p, w] + so.expr_sum(
        bench_weights[o] * bench[p, w, o] for o in order)) for p in players) for w in gameweeks}
    gw_total = {w: gw_xp[w] - 4 * penalized_transfers[w] for w in gameweeks}
    if objective == 'regular':
        total_xp = so.expr_sum(gw_total[w] for w in gameweeks)
        model.set_objective(-total_xp, sense='N', name='total_regular_xp')
    else:
        decay_objective = so.expr_sum(
            gw_total[w] * pow(decay_base, w-next_gw) for w in gameweeks)
        model.set_objective(-decay_objective, sense='N', name='total_decay_xp')

    # Solve
    model.export_mps(f'{problem_name}.mps')
    command = f'cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/{problem_name}.mps solve solu {problem_name}_sol.txt'
    # add 'stdout=DEVNULL' for disabling logs
    process = Popen(command, shell=True)
    process.wait()

    # Parsing
    with open(f'{problem_name}_sol.txt', 'r') as f:
        for line in f:
            if 'objective value' in line:
                continue
            words = line.split()
            var = model.get_variable(words[1])
            var.set_value(float(words[2]))

    # DataFrame generation
    picks = []
    for w in gameweeks:
        for p in players:
            if squad[p, w].get_value() + transfer_out[p, w].get_value() > 0.5:
                lp = merged_data.loc[p]
                is_captain = 1 if captain[p, w].get_value() > 0.5 else 0
                is_lineup = 1 if lineup[p, w].get_value() > 0.5 else 0
                is_vice = 1 if vicecap[p, w].get_value() > 0.5 else 0
                is_transfer_in = 1 if transfer_in[p,
                                                  w].get_value() > 0.5 else 0
                is_transfer_out = 1 if transfer_out[p, w].get_value(
                ) > 0.5 else 0
                bench_value = -1
                for o in order:
                    if bench[p, w, o].get_value() > 0.5:
                        bench_value = o
                position = type_data.loc[lp['element_type'],
                                         'singular_name_short']
                picks.append([
                    w, lp['web_name'], position, lp['element_type'], lp['name'], buy_price[p], sell_price[p], round(
                        points_player_week[p, w], 2), minutes_player_week[p, w], is_lineup, bench_value, is_captain, is_vice, is_transfer_in, is_transfer_out
                ])

    picks_df = pd.DataFrame(picks, columns=['week', 'name', 'pos', 'type', 'team', 'buy_price', 'sell_price', 'xP', 'xMin', 'lineup', 'bench',
                            'captain', 'vicecaptain', 'transfer_in', 'transfer_out']).sort_values(by=['week', 'lineup', 'type', 'xP'], ascending=[True, False, True, True])
    total_xp = so.expr_sum((lineup[p, w] + captain[p, w]) * points_player_week[p, w]
                           for p in players for w in gameweeks).get_value()

    # Writing summary
    summary_of_actions = ""
    for w in gameweeks:
        summary_of_actions += f"** GW {w}:\n"
        summary_of_actions += f"ITB = {in_the_bank[w].get_value()}, FT={free_transfers[w].get_value()}, PT={penalized_transfers[w].get_value()}\n"
        for p in players:
            if transfer_in[p, w].get_value() > 0.5:
                summary_of_actions += f"Buy {p} - {merged_data['web_name'][p]}\n"
            if transfer_out[p, w].get_value() > 0.5:
                summary_of_actions += f"Sell {p} - {merged_data['web_name'][p]}\n"

    return {'model': model, 'picks': picks_df, 'total_xp': total_xp, 'summary': summary_of_actions}

# %%
def solve_standard_problem():
    r = solve_multi_period_fpl(
        team_id=2821496, gw=gw, ft=ft, horizon=horizon, objective='regular')
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular.csv')

# %%
def solve_autobench_problem():
    r = solve_multi_period_fpl(
        team_id=2821496, gw=gw, ft=ft, horizon=horizon, objective='regular')
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular_stage_1.csv')

    df = r['picks']
    lineup_gk = df[(df['week'] == 4) & (
        df['pos'] == 'GKP') & (df['lineup'] == 1)]
    lineup_gk = lineup_gk.iloc[0]
    lineup_gk_mins = lineup_gk['xMin']
    gk_autosub_prob = xmin_to_prob(lineup_gk_mins, sub_on=0, sub_off=0)
    gk_weight = 1-gk_autosub_prob

    field_players = df[(df['week'] == 4) & (
        df['pos'] != 'GKP') & (df['lineup'] == 1)]
    field_players_xmins = field_players['xMin'].tolist()
    field_players_probs = [xmin_to_prob(i) for i in field_players_xmins]

    prob = 1
    for i in field_players_probs:
        prob *= i
    bench_1_weight = 1 - prob

    bench_weights = {0: gk_weight, 1: bench_1_weight, 2: 0.06, 3: 0.002}
    r = solve_multi_period_fpl(team_id=2821496, gw=gw, ft=ft,
                               horizon=8, objective='regular', bench_weights=bench_weights)
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular_stage_2.csv')

# %%
def solve_randomized_problem():
    r = solve_multi_period_fpl(team_id=2821496, gw=gw, ft=ft,
                               horizon=horizon, objective='regular', seed=None, randomized=True)
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_randomized.csv')


if __name__ == '__main__':

    solve_standard_problem()  
    
    solve_randomized_problem()
# Out:
# NOTE: Initialized model mp_h5_regular.
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Nov  6 2022
#
# command line - cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/mp_h5_regular.mps solve solu mp_h5_regular_sol.txt (default strategy 1)
# At line 1 NAME    mp_h5_regular
# At line 2 ROWS
# At line 38971 COLUMNS
# At line 131343 RHS
# At line 135248 RANGES
# At line 135264 BOUNDS
# At line 174047 ENDATA
# Problem mp_h5_regular has 38967 rows, 38782 columns and 151707 elements
# Coin0008I mp_h5_regular read with 0 errors
# Continuous objective value is -425.919 - 2.11 seconds
# Cgl0002I 745 variables fixed
# Cgl0003I 0 fixed, 5 tightened bounds, 32977 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17815 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14031 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8998 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2232 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 15 strengthened rows, 0 substitutions
# Cgl0004I processed model has 15382 rows, 36790 columns (36786 integer (36781 of which binary)) and 128226 elements
# Cbc0038I Initial state - 165 integers unsatisfied sum - 50.4501
# Cbc0038I Pass   1: (15.88 seconds) suminf.    4.99758 (20) obj. -407.333 iterations 4749
# Cbc0038I Pass   2: (16.02 seconds) suminf.    3.29897 (15) obj. -406.728 iterations 986
# Cbc0038I Pass   3: (16.12 seconds) suminf.    0.00000 (0) obj. -389.709 iterations 433
# Cbc0038I Solution found of -389.709
# Cbc0038I Relaxing continuous gives -389.709
# Cbc0038I Cleaned solution of -389.709
# Cbc0038I Before mini branch and bound, 36600 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15382 rows 36790 columns, reduced to 123 rows 106 columns
# Cbc0038I Mini branch and bound improved solution from -389.709 to -412.009 (16.20 seconds)
# Cbc0038I Round again with cutoff of -412.684
# Cbc0038I Reduced cost fixing fixed 2953 variables on major pass 2
# Cbc0038I Pass   4: (16.97 seconds) suminf.    9.34164 (38) obj. -412.684 iterations 2638
# Cbc0038I Pass   5: (17.87 seconds) suminf.    4.80943 (30) obj. -412.684 iterations 5268
# Cbc0038I Pass   6: (18.43 seconds) suminf.    3.74051 (51) obj. -412.684 iterations 3336
# Cbc0038I Pass   7: (18.45 seconds) suminf.    3.74051 (51) obj. -412.684 iterations 1
# Cbc0038I Pass   8: (18.87 seconds) suminf.    7.03903 (29) obj. -412.684 iterations 3325
# Cbc0038I Pass   9: (19.02 seconds) suminf.    4.81442 (30) obj. -412.684 iterations 852
# Cbc0038I Pass  10: (19.06 seconds) suminf.    4.80351 (30) obj. -412.684 iterations 140
# Cbc0038I Pass  11: (19.46 seconds) suminf.    5.05453 (30) obj. -412.684 iterations 2496
# Cbc0038I Pass  12: (19.48 seconds) suminf.    5.05453 (30) obj. -412.684 iterations 16
# Cbc0038I Pass  13: (20.11 seconds) suminf.    6.84216 (30) obj. -412.684 iterations 4432
# Cbc0038I Pass  14: (20.17 seconds) suminf.    6.84216 (30) obj. -412.684 iterations 345
# Cbc0038I Pass  15: (20.53 seconds) suminf.    5.10993 (30) obj. -412.684 iterations 2349
# Cbc0038I Pass  16: (20.69 seconds) suminf.    5.68380 (32) obj. -412.684 iterations 993
# Cbc0038I Pass  17: (20.84 seconds) suminf.    5.25453 (33) obj. -412.684 iterations 929
# Cbc0038I Pass  18: (21.35 seconds) suminf.    6.95118 (31) obj. -412.684 iterations 3409
# Cbc0038I Pass  19: (21.41 seconds) suminf.    6.95118 (31) obj. -412.684 iterations 272
# Cbc0038I Pass  20: (21.78 seconds) suminf.    5.51152 (28) obj. -412.684 iterations 2551
# Cbc0038I Pass  21: (21.89 seconds) suminf.    4.91464 (30) obj. -412.684 iterations 847
# Cbc0038I Pass  22: (22.05 seconds) suminf.    4.81427 (29) obj. -412.684 iterations 842
# Cbc0038I Pass  23: (22.47 seconds) suminf.    5.03855 (21) obj. -412.684 iterations 2600
# Cbc0038I Pass  24: (22.66 seconds) suminf.    4.80351 (30) obj. -412.684 iterations 1132
# Cbc0038I Pass  25: (23.05 seconds) suminf.    4.81427 (29) obj. -412.684 iterations 2400
# Cbc0038I Pass  26: (23.32 seconds) suminf.    6.43683 (27) obj. -412.684 iterations 1834
# Cbc0038I Pass  27: (23.52 seconds) suminf.    3.36356 (25) obj. -412.684 iterations 1293
# Cbc0038I Pass  28: (23.57 seconds) suminf.    3.36356 (25) obj. -412.684 iterations 206
# Cbc0038I Pass  29: (23.73 seconds) suminf.    2.44283 (41) obj. -412.684 iterations 821
# Cbc0038I Pass  30: (23.77 seconds) suminf.    2.44283 (41) obj. -412.684 iterations 94
# Cbc0038I Pass  31: (24.16 seconds) suminf.    5.91491 (26) obj. -412.684 iterations 2624
# Cbc0038I Pass  32: (24.53 seconds) suminf.    5.38769 (33) obj. -412.684 iterations 2613
# Cbc0038I Pass  33: (24.85 seconds) suminf.    6.87584 (21) obj. -412.684 iterations 2155
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 36558 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15382 rows 36790 columns, reduced to 152 rows 150 columns
# Cbc0038I Mini branch and bound did not improve solution (24.89 seconds)
# Cbc0038I After 24.89 seconds - Feasibility pump exiting with objective of -412.009 - took 9.59 seconds
# Cbc0012I Integer solution of -412.00886 found by feasibility pump after 0 iterations and 0 nodes (24.90 seconds)
# Cbc0038I Full problem 15382 rows 36790 columns, reduced to 113 rows 91 columns
# Cbc0031I 9 added rows had average density of 1167.8889
# Cbc0013I At root node, 9 cuts changed objective from -418.75828 to -415.7881 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 2118 column cuts (2118 active)  in 0.049 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 762.8 elements, 0 column cuts (0 active)  in 0.075 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.042 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 15 row cuts average 1372.9 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 3 row cuts average 762.7 elements, 0 column cuts (0 active)  in 0.367 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -412.00886 best solution, best possible -415.7881 (27.89 seconds)
# Cbc0012I Integer solution of -414.92456 found by DiveCoefficient after 2739 iterations and 2 nodes (29.26 seconds)
# Cbc0038I Full problem 15382 rows 36790 columns, reduced to 65 rows 48 columns
# Cbc0038I Full problem 15391 rows 36790 columns, reduced to 6444 rows 16104 columns
# Cbc0044I Reduced cost fixing - 6444 rows, 16104 columns - restarting search
# Cbc0012I Integer solution of -414.92456 found by Previous solution after 0 iterations and 0 nodes (33.14 seconds)
# Cbc0038I Full problem 6444 rows 16104 columns, reduced to 124 rows 103 columns
# Cbc0031I 9 added rows had average density of 816.66667
# Cbc0013I At root node, 9 cuts changed objective from -418.75828 to -415.78758 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1693 column cuts (1693 active)  in 0.033 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 608.8 elements, 0 column cuts (0 active)  in 0.087 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.025 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 9 row cuts average 620.8 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (TwoMirCuts) - 1 row cuts average 338.0 elements, 0 column cuts (0 active)  in 0.096 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 3 row cuts average 567.3 elements, 0 column cuts (0 active)  in 0.122 seconds - new frequency is 1
# Cbc0014I Cut generator 9 (Stored from first) - 9 row cuts average 835.9 elements, 0 column cuts (0 active)
# Cbc0010I After 0 nodes, 1 on tree, -414.92456 best solution, best possible -415.78758 (34.32 seconds)
# Cbc0012I Integer solution of -415.24886 found by DiveCoefficient after 4347 iterations and 32 nodes (36.40 seconds)
# Cbc0038I Full problem 6444 rows 16104 columns, reduced to 12 rows 12 columns
# Cbc0012I Integer solution of -415.26626 found by DiveCoefficient after 5200 iterations and 45 nodes (37.34 seconds)
# Cbc0001I Search completed - best objective -415.2662599999999, took 5447 iterations and 50 nodes (37.60 seconds)
# Cbc0032I Strong branching done 264 times (3261 iterations), fathomed 7 nodes and fixed 0 variables
# Cbc0035I Maximum depth 9, 14698 variables fixed on reduced cost
# Cbc0038I Probing was tried 36 times and created 1728 cuts of which 0 were active after adding rounds of cuts (0.060 seconds)
# Cbc0038I Gomory was tried 4 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.087 seconds)
# Cbc0038I Knapsack was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.025 seconds)
# Cbc0038I Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Cbc0038I MixedIntegerRounding2 was tried 36 times and created 87 cuts of which 0 were active after adding rounds of cuts (0.046 seconds)
# Cbc0038I FlowCover was tried 26 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
# Cbc0038I TwoMirCuts was tried 4 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.096 seconds)
# Cbc0038I ZeroHalf was tried 36 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.871 seconds)
# Cbc0038I Stored from first was tried 36 times and created 21 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Cbc0012I Integer solution of -415.26626 found by Reduced search after 11761 iterations and 100 nodes (37.64 seconds)
# Cbc0001I Search completed - best objective -415.2662599999999, took 11761 iterations and 100 nodes (37.64 seconds)
# Cbc0032I Strong branching done 298 times (4717 iterations), fathomed 0 nodes and fixed 1 variables
# Cbc0035I Maximum depth 12, 19001 variables fixed on reduced cost
# Cuts at root node changed objective from -418.758 to -415.788
# Probing was tried 20 times and created 2132 cuts of which 0 were active after adding rounds of cuts (0.077 seconds)
# Gomory was tried 3 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.075 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.042 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 20 times and created 41 cuts of which 0 were active after adding rounds of cuts (0.069 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.049 seconds)
# ZeroHalf was tried 20 times and created 3 cuts of which 0 were active after adding rounds of cuts (2.213 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -415.26626000
# Enumerated nodes:               100
# Total iterations:               11761
# Time (CPU seconds):             37.79
# Time (Wallclock seconds):       38.57
#
# Total time (CPU seconds):       37.86   (Wallclock seconds):       38.65
#
#     week              name  pos  type       team  buy_price  sell_price  \
# 8     34           Ederson  GKP     1   Man City        5.4         5.4
# 11    34              Shaw  DEF     2    Man Utd        5.1         5.1
# 9     34              Dias  DEF     2   Man City        6.0         6.0
# 6     34         Robertson  DEF     2  Liverpool        6.8         6.8
# 7     34  Alexander-Arnold  DEF     2  Liverpool        7.5         7.4
# ..   ...               ...  ...   ...        ...        ...         ...
# 68    38      Arrizabalaga  GKP     1    Chelsea        4.7         4.7
# 78    38             Schär  DEF     2  Newcastle        5.1         5.1
# 77    38          Trippier  DEF     2  Newcastle        6.2         6.1
# 72    38              Dias  DEF     2   Man City        6.0         6.0
# 69    38         Greenwood  FWD     4      Leeds        4.0         4.0
#
#        xP  xMin  lineup  bench  captain  vicecaptain  transfer_in  \
# 8    8.32    89       1     -1        0            0            0
# 11   5.32    77       1     -1        0            0            1
# 9    7.30    71       1     -1        0            0            0
# 6    7.84    74       1     -1        0            0            0
# 7   10.30    86       1     -1        0            0            0
# ..    ...   ...     ...    ...      ...          ...          ...
# 68   3.29    77       0      0        0            0            0
# 78   2.62    74       0     -1        0            0            0
# 77   2.91    78       0      2        0            0            0
# 72   3.00    64       0      1        0            0            0
# 69   0.72    15       0      3        0            0            0
#
#     transfer_out
# 8              0
# 11             0
# 9              0
# 6              0
# 7              0
# ..           ...
# 68             0
# 78             1
# 77             0
# 72             0
# 69             0
#
# [80 rows x 15 columns]
# ** GW 34:
# ITB = 0.3, FT=1.0, PT=0
# Buy 332 - Shaw
# Sell 377 - Botman
# ** GW 35:
# ITB = 0.3, FT=1.0, PT=0
# ** GW 36:
# ITB = 2.0, FT=2.0, PT=0
# Sell 284 - Robertson
# Buy 366 - Schär
# ** GW 37:
# ITB = 0.7, FT=2.0, PT=0
# Sell 283 - Salah
# Buy 333 - Fernandes
# Sell 594 - Isak
# Buy 427 - Kane
# ** GW 38:
# ITB = 0.5, FT=1.0, PT=0
# Buy 16 - Gabriel
# Sell 366 - Schär
#
# NOTE: Initialized model mp_h5_regular.
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Nov  6 2022
#
# command line - cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/mp_h5_regular.mps solve solu mp_h5_regular_sol.txt (default strategy 1)
# At line 1 NAME    mp_h5_regular
# At line 2 ROWS
# At line 38971 COLUMNS
# At line 131343 RHS
# At line 135248 RANGES
# At line 135264 BOUNDS
# At line 174047 ENDATA
# Problem mp_h5_regular has 38967 rows, 38782 columns and 151707 elements
# Coin0008I mp_h5_regular read with 0 errors
# Continuous objective value is -431.204 - 1.55 seconds
# Cgl0002I 745 variables fixed
# Cgl0003I 0 fixed, 5 tightened bounds, 32938 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17791 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14013 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8949 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2213 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 11 strengthened rows, 0 substitutions
# Cgl0004I processed model has 15393 rows, 36751 columns (36747 integer (36742 of which binary)) and 128213 elements
# Cbc0038I Initial state - 180 integers unsatisfied sum - 46.3858
# Cbc0038I Pass   1: (15.71 seconds) suminf.    3.59961 (19) obj. -413.889 iterations 4920
# Cbc0038I Pass   2: (15.74 seconds) suminf.    3.59961 (19) obj. -413.889 iterations 106
# Cbc0038I Pass   3: (15.87 seconds) suminf.    0.00000 (0) obj. -377.874 iterations 905
# Cbc0038I Solution found of -377.874
# Cbc0038I Relaxing continuous gives -377.874
# Cbc0038I Cleaned solution of -377.874
# Cbc0038I Before mini branch and bound, 36549 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15393 rows 36751 columns, reduced to 142 rows 115 columns
# Cbc0038I Mini branch and bound improved solution from -377.874 to -408.45 (15.98 seconds)
# Cbc0038I Round again with cutoff of -409.841
# Cbc0038I Reduced cost fixing fixed 761 variables on major pass 2
# Cbc0038I Pass   4: (16.00 seconds) suminf.    3.59961 (19) obj. -413.889 iterations 0
# Cbc0038I Pass   5: (16.06 seconds) suminf.    3.59961 (19) obj. -413.889 iterations 246
# Cbc0038I Pass   6: (16.80 seconds) suminf.    4.85201 (21) obj. -409.841 iterations 4757
# Cbc0038I Pass   7: (16.94 seconds) suminf.    4.44116 (16) obj. -409.841 iterations 1050
# Cbc0038I Pass   8: (17.53 seconds) suminf.    3.68553 (12) obj. -409.841 iterations 4128
# Cbc0038I Pass   9: (17.86 seconds) suminf.    3.51923 (18) obj. -409.841 iterations 2544
# Cbc0038I Pass  10: (18.17 seconds) suminf.    5.21757 (14) obj. -409.841 iterations 1989
# Cbc0038I Pass  11: (18.21 seconds) suminf.    5.21757 (14) obj. -409.841 iterations 50
# Cbc0038I Pass  12: (18.78 seconds) suminf.    3.63900 (18) obj. -409.841 iterations 4532
# Cbc0038I Pass  13: (19.03 seconds) suminf.    4.51561 (24) obj. -409.841 iterations 1770
# Cbc0038I Pass  14: (19.54 seconds) suminf.    3.68317 (22) obj. -409.841 iterations 4189
# Cbc0038I Pass  15: (19.84 seconds) suminf.    5.54566 (16) obj. -409.841 iterations 1915
# Cbc0038I Pass  16: (19.86 seconds) suminf.    5.54566 (16) obj. -409.841 iterations 27
# Cbc0038I Pass  17: (20.30 seconds) suminf.    4.09046 (20) obj. -409.841 iterations 3226
# Cbc0038I Pass  18: (20.53 seconds) suminf.    3.59034 (20) obj. -409.841 iterations 1667
# Cbc0038I Pass  19: (20.76 seconds) suminf.    5.54566 (16) obj. -409.841 iterations 1532
# Cbc0038I Pass  20: (21.13 seconds) suminf.    3.98582 (20) obj. -409.841 iterations 2221
# Cbc0038I Pass  21: (21.45 seconds) suminf.    3.70781 (24) obj. -409.841 iterations 2640
# Cbc0038I Pass  22: (21.73 seconds) suminf.    3.84433 (18) obj. -409.841 iterations 1979
# Cbc0038I Pass  23: (21.75 seconds) suminf.    3.84433 (18) obj. -409.841 iterations 13
# Cbc0038I Pass  24: (22.06 seconds) suminf.    3.61859 (20) obj. -409.841 iterations 2315
# Cbc0038I Pass  25: (22.11 seconds) suminf.    3.56522 (20) obj. -409.841 iterations 290
# Cbc0038I Pass  26: (22.28 seconds) suminf.    5.61398 (16) obj. -409.841 iterations 1274
# Cbc0038I Pass  27: (22.31 seconds) suminf.    5.61398 (16) obj. -409.841 iterations 13
# Cbc0038I Pass  28: (22.78 seconds) suminf.    4.04020 (20) obj. -409.841 iterations 2948
# Cbc0038I Pass  29: (22.96 seconds) suminf.    3.91844 (18) obj. -409.841 iterations 1327
# Cbc0038I Pass  30: (23.22 seconds) suminf.    3.85583 (23) obj. -409.841 iterations 2204
# Cbc0038I Pass  31: (23.49 seconds) suminf.    3.84433 (18) obj. -409.841 iterations 1938
# Cbc0038I Pass  32: (23.52 seconds) suminf.    3.84433 (18) obj. -409.841 iterations 24
# Cbc0038I Pass  33: (23.63 seconds) suminf.    4.06057 (14) obj. -409.841 iterations 714
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 36521 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15393 rows 36751 columns, reduced to 153 rows 134 columns
# Cbc0038I Mini branch and bound improved solution from -408.45 to -408.871 (23.67 seconds)
# Cbc0038I Round again with cutoff of -412.343
# Cbc0038I Reduced cost fixing fixed 1511 variables on major pass 3
# Cbc0038I Pass  33: (23.69 seconds) suminf.    3.59961 (19) obj. -413.889 iterations 0
# Cbc0038I Pass  34: (23.76 seconds) suminf.    3.59961 (19) obj. -413.889 iterations 274
# Cbc0038I Pass  35: (24.39 seconds) suminf.    4.72132 (16) obj. -412.343 iterations 4533
# Cbc0038I Pass  36: (24.60 seconds) suminf.    4.98625 (17) obj. -412.343 iterations 1642
# Cbc0038I Pass  37: (24.91 seconds) suminf.    5.13843 (21) obj. -412.343 iterations 2513
# Cbc0038I Pass  38: (25.28 seconds) suminf.    4.05750 (22) obj. -412.343 iterations 2780
# Cbc0038I Pass  39: (25.52 seconds) suminf.    4.54643 (16) obj. -412.343 iterations 1685
# Cbc0038I Pass  40: (25.94 seconds) suminf.    3.64310 (21) obj. -412.343 iterations 3649
# Cbc0038I Pass  41: (26.60 seconds) suminf.    4.28583 (28) obj. -412.343 iterations 6399
# Cbc0038I Pass  42: (26.79 seconds) suminf.    4.01055 (22) obj. -412.343 iterations 1252
# Cbc0038I Pass  43: (27.00 seconds) suminf.    4.78373 (19) obj. -412.343 iterations 1225
# Cbc0038I Pass  44: (27.13 seconds) suminf.    4.34654 (20) obj. -412.343 iterations 961
# Cbc0038I Pass  45: (27.33 seconds) suminf.    4.20036 (20) obj. -412.343 iterations 1396
# Cbc0038I Pass  46: (27.95 seconds) suminf.    4.05796 (49) obj. -412.343 iterations 4375
# Cbc0038I Pass  47: (28.15 seconds) suminf.    4.67827 (17) obj. -412.343 iterations 1181
# Cbc0038I Pass  48: (28.57 seconds) suminf.    3.65298 (24) obj. -412.343 iterations 2771
# Cbc0038I Pass  49: (28.76 seconds) suminf.    4.44757 (16) obj. -412.343 iterations 1183
# Cbc0038I Pass  50: (29.41 seconds) suminf.    3.85860 (242) obj. -412.343 iterations 3641
# Cbc0038I Pass  51: (29.64 seconds) suminf.    3.49142 (14) obj. -412.343 iterations 908
# Cbc0038I Pass  52: (29.98 seconds) suminf.    3.39504 (18) obj. -412.343 iterations 1915
# Cbc0038I Pass  53: (30.11 seconds) suminf.    3.49142 (14) obj. -412.343 iterations 690
# Cbc0038I Pass  54: (30.25 seconds) suminf.    3.46587 (16) obj. -412.343 iterations 855
# Cbc0038I Pass  55: (30.74 seconds) suminf.    3.46587 (17) obj. -412.343 iterations 2896
# Cbc0038I Pass  56: (31.08 seconds) suminf.    3.73689 (20) obj. -412.343 iterations 2566
# Cbc0038I Pass  57: (31.23 seconds) suminf.    3.39504 (18) obj. -412.343 iterations 849
# Cbc0038I Pass  58: (31.40 seconds) suminf.    3.49142 (14) obj. -412.343 iterations 812
# Cbc0038I Pass  59: (31.55 seconds) suminf.    3.86777 (18) obj. -412.343 iterations 1058
# Cbc0038I Pass  60: (31.71 seconds) suminf.    3.32481 (18) obj. -412.343 iterations 1181
# Cbc0038I Pass  61: (31.91 seconds) suminf.    3.33292 (14) obj. -412.343 iterations 1237
# Cbc0038I Pass  62: (32.09 seconds) suminf.    3.89926 (18) obj. -412.343 iterations 1502
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 35793 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15393 rows 36751 columns, reduced to 201 rows 219 columns
# Cbc0038I Mini branch and bound improved solution from -408.871 to -414.89 (32.16 seconds)
# Cbc0038I Round again with cutoff of -417.129
# Cbc0038I Reduced cost fixing fixed 3622 variables on major pass 4
# Cbc0038I Pass  62: (33.75 seconds) suminf.   16.47600 (58) obj. -417.129 iterations 3845
# Cbc0038I Pass  63: (34.41 seconds) suminf.    6.35687 (31) obj. -417.129 iterations 3700
# Cbc0038I Pass  64: (35.34 seconds) suminf.    5.72322 (22) obj. -417.129 iterations 3196
# Cbc0038I Pass  65: (35.42 seconds) suminf.    4.35647 (39) obj. -417.129 iterations 285
# Cbc0038I Pass  66: (36.76 seconds) suminf.   11.89542 (39) obj. -417.129 iterations 7562
# Cbc0038I Pass  67: (36.89 seconds) suminf.   11.50392 (39) obj. -417.129 iterations 779
# Cbc0038I Pass  68: (36.92 seconds) suminf.   11.50392 (39) obj. -417.129 iterations 35
# Cbc0038I Pass  69: (37.23 seconds) suminf.   10.60237 (28) obj. -417.129 iterations 2164
# Cbc0038I Pass  70: (37.70 seconds) suminf.    7.72031 (30) obj. -417.129 iterations 2409
# Cbc0038I Pass  71: (38.41 seconds) suminf.    6.16124 (140) obj. -417.129 iterations 3995
# Cbc0038I Pass  72: (38.64 seconds) suminf.    4.56419 (35) obj. -417.129 iterations 1215
# Cbc0038I Pass  73: (38.69 seconds) suminf.    4.35647 (39) obj. -417.129 iterations 166
# Cbc0038I Pass  74: (39.21 seconds) suminf.   11.37683 (42) obj. -417.129 iterations 3059
# Cbc0038I Pass  75: (39.62 seconds) suminf.    8.49921 (46) obj. -417.129 iterations 2300
# Cbc0038I Pass  76: (39.91 seconds) suminf.    6.89939 (41) obj. -417.129 iterations 1306
# Cbc0038I Pass  77: (40.02 seconds) suminf.    7.36035 (52) obj. -417.129 iterations 648
# Cbc0038I Pass  78: (40.17 seconds) suminf.    6.89939 (41) obj. -417.129 iterations 752
# Cbc0038I Pass  79: (40.31 seconds) suminf.    4.35647 (39) obj. -417.129 iterations 910
# Cbc0038I Pass  80: (40.34 seconds) suminf.    4.35647 (39) obj. -417.129 iterations 88
# Cbc0038I Pass  81: (40.84 seconds) suminf.   11.50392 (39) obj. -417.129 iterations 2685
# Cbc0038I Pass  82: (40.87 seconds) suminf.   11.50392 (39) obj. -417.129 iterations 81
# Cbc0038I Pass  83: (41.15 seconds) suminf.    7.52145 (25) obj. -417.129 iterations 1456
# Cbc0038I Pass  84: (41.37 seconds) suminf.    4.84022 (39) obj. -417.129 iterations 996
# Cbc0038I Pass  85: (41.41 seconds) suminf.    4.35647 (39) obj. -417.129 iterations 76
# Cbc0038I Pass  86: (41.57 seconds) suminf.    8.47266 (37) obj. -417.129 iterations 922
# Cbc0038I Pass  87: (41.73 seconds) suminf.    6.18466 (23) obj. -417.129 iterations 691
# Cbc0038I Pass  88: (41.96 seconds) suminf.    5.72322 (22) obj. -417.129 iterations 1298
# Cbc0038I Pass  89: (42.06 seconds) suminf.    6.01010 (18) obj. -417.129 iterations 541
# Cbc0038I Pass  90: (42.38 seconds) suminf.    7.09300 (52) obj. -417.129 iterations 1362
# Cbc0038I Pass  91: (42.60 seconds) suminf.    6.85067 (35) obj. -417.129 iterations 1038
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 36195 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15393 rows 36751 columns, reduced to 186 rows 178 columns
# Cbc0038I Mini branch and bound improved solution from -414.89 to -415.152 (42.67 seconds)
# Cbc0038I Round again with cutoff of -418.696
# Cbc0038I Reduced cost fixing fixed 5600 variables on major pass 5
# Cbc0038I Pass  91: (43.39 seconds) suminf.   16.42492 (62) obj. -418.696 iterations 1791
# Cbc0038I Pass  92: (43.56 seconds) suminf.   16.28736 (65) obj. -418.696 iterations 1304
# Cbc0038I Pass  93: (44.01 seconds) suminf.   12.30699 (36) obj. -418.696 iterations 2653
# Cbc0038I Pass  94: (44.20 seconds) suminf.    9.48839 (55) obj. -418.696 iterations 969
# Cbc0038I Pass  95: (44.50 seconds) suminf.   12.77342 (55) obj. -418.696 iterations 2276
# Cbc0038I Pass  96: (44.86 seconds) suminf.   11.50992 (63) obj. -418.696 iterations 1929
# Cbc0038I Pass  97: (45.03 seconds) suminf.   10.96114 (85) obj. -418.696 iterations 860
# Cbc0038I Pass  98: (45.13 seconds) suminf.   10.83206 (95) obj. -418.696 iterations 536
# Cbc0038I Pass  99: (45.22 seconds) suminf.   10.96114 (85) obj. -418.696 iterations 414
# Cbc0038I Pass 100: (45.35 seconds) suminf.   12.27715 (48) obj. -418.696 iterations 751
# Cbc0038I Pass 101: (45.48 seconds) suminf.   11.23425 (59) obj. -418.696 iterations 816
# Cbc0038I Pass 102: (45.73 seconds) suminf.    8.04470 (29) obj. -418.696 iterations 1804
# Cbc0038I Pass 103: (45.93 seconds) suminf.    7.74317 (38) obj. -418.696 iterations 1195
# Cbc0038I Pass 104: (46.57 seconds) suminf.    9.19747 (34) obj. -418.696 iterations 3517
# Cbc0038I Pass 105: (46.82 seconds) suminf.    8.66178 (40) obj. -418.696 iterations 766
# Cbc0038I Pass 106: (46.90 seconds) suminf.    8.07658 (39) obj. -418.696 iterations 381
# Cbc0038I Pass 107: (46.99 seconds) suminf.    8.52314 (46) obj. -418.696 iterations 473
# Cbc0038I Pass 108: (47.10 seconds) suminf.    8.20543 (41) obj. -418.696 iterations 501
# Cbc0038I Pass 109: (47.19 seconds) suminf.    8.07658 (39) obj. -418.696 iterations 566
# Cbc0038I Pass 110: (47.41 seconds) suminf.    8.66178 (40) obj. -418.696 iterations 1317
# Cbc0038I Pass 111: (47.55 seconds) suminf.    8.03615 (33) obj. -418.696 iterations 756
# Cbc0038I Pass 112: (47.61 seconds) suminf.    7.74317 (38) obj. -418.696 iterations 234
# Cbc0038I Pass 113: (48.00 seconds) suminf.    8.66178 (40) obj. -418.696 iterations 2338
# Cbc0038I Pass 114: (48.10 seconds) suminf.    8.20543 (41) obj. -418.696 iterations 457
# Cbc0038I Pass 115: (48.22 seconds) suminf.    8.07658 (39) obj. -418.696 iterations 765
# Cbc0038I Pass 116: (48.39 seconds) suminf.    8.66178 (40) obj. -418.696 iterations 1399
# Cbc0038I Pass 117: (48.73 seconds) suminf.    8.46978 (28) obj. -418.696 iterations 2447
# Cbc0038I Pass 118: (48.84 seconds) suminf.    8.46978 (28) obj. -418.696 iterations 540
# Cbc0038I Pass 119: (49.14 seconds) suminf.    8.48988 (36) obj. -418.696 iterations 2183
# Cbc0038I Pass 120: (49.28 seconds) suminf.    7.74317 (38) obj. -418.696 iterations 667
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 36371 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15393 rows 36751 columns, reduced to 194 rows 184 columns
# Cbc0038I Mini branch and bound did not improve solution (49.34 seconds)
# Cbc0038I After 49.34 seconds - Feasibility pump exiting with objective of -415.152 - took 34.36 seconds
# Cbc0012I Integer solution of -415.15241 found by feasibility pump after 0 iterations and 0 nodes (49.34 seconds)
# Cbc0038I Full problem 15393 rows 36751 columns, reduced to 134 rows 103 columns
# Cbc0031I 8 added rows had average density of 597.625
# Cbc0013I At root node, 8 cuts changed objective from -422.35402 to -415.78978 in 5 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 2032 column cuts (2032 active)  in 0.033 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 762.8 elements, 0 column cuts (0 active)  in 0.143 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.074 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 17 row cuts average 688.5 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 3 row cuts average 762.7 elements, 0 column cuts (0 active)  in 0.601 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -415.15241 best solution, best possible -415.78978 (52.39 seconds)
# Cbc0001I Search completed - best objective -415.152411, took 3636 iterations and 10 nodes (53.78 seconds)
# Cbc0032I Strong branching done 54 times (1844 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 3, 13756 variables fixed on reduced cost
# Cuts at root node changed objective from -422.354 to -415.79
# Probing was tried 13 times and created 2037 cuts of which 0 were active after adding rounds of cuts (0.042 seconds)
# Gomory was tried 5 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.143 seconds)
# Knapsack was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.074 seconds)
# Clique was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 13 times and created 29 cuts of which 0 were active after adding rounds of cuts (0.034 seconds)
# FlowCover was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.049 seconds)
# ZeroHalf was tried 13 times and created 3 cuts of which 0 were active after adding rounds of cuts (1.506 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -415.15241100
# Enumerated nodes:               10
# Total iterations:               3636
# Time (CPU seconds):             53.97
# Time (Wallclock seconds):       54.81
#
# Total time (CPU seconds):       54.04   (Wallclock seconds):       54.90
#
#     week              name  pos  type       team  buy_price  sell_price    xP  \
# 8     34           Ederson  GKP     1   Man City        5.4         5.4  8.34
# 12    34          Trippier  DEF     2  Newcastle        6.2         6.1  4.74
# 9     34              Dias  DEF     2   Man City        6.0         6.0  6.26
# 6     34         Robertson  DEF     2  Liverpool        6.8         6.8  8.22
# 7     34  Alexander-Arnold  DEF     2  Liverpool        7.5         7.4  9.88
# ..   ...               ...  ...   ...        ...        ...         ...   ...
# 68    38      Arrizabalaga  GKP     1    Chelsea        4.7         4.7  3.16
# 79    38             Schär  DEF     2  Newcastle        5.1         5.1  3.00
# 65    38             March  MID     3   Brighton        5.2         5.2  3.21
# 78    38            Wilson  FWD     4  Newcastle        6.9         6.9  0.06
# 69    38         Greenwood  FWD     4      Leeds        4.0         4.0  1.23
#
#     xMin  lineup  bench  captain  vicecaptain  transfer_in  transfer_out
# 8     89       1     -1        0            0            0             0
# 12    85       1     -1        0            0            0             0
# 9     71       1     -1        0            0            0             0
# 6     74       1     -1        0            0            0             0
# 7     86       1     -1        0            0            0             0
# ..   ...     ...    ...      ...          ...          ...           ...
# 68    77       0      0        0            0            0             0
# 79    74       0      1        0            0            0             0
# 65    75       0     -1        0            0            0             1
# 78    37       0      3        0            0            0             0
# 69    15       0      2        0            0            0             0
#
# [80 rows x 15 columns]
# ** GW 34:
# ITB = 0.9, FT=1.0, PT=0
# ** GW 35:
# ITB = 0.3, FT=2.0, PT=0
# Buy 366 - Schär
# Sell 377 - Botman
# ** GW 36:
# ITB = 0.2, FT=2.0, PT=0
# Buy 356 - Wilson
# Sell 594 - Isak
# ** GW 37:
# ITB = 4.6, FT=2.0, PT=0
# Sell 283 - Salah
# Buy 332 - Shaw
# Buy 333 - Fernandes
# Sell 357 - Trippier
# ** GW 38:
# ITB = 1.4, FT=1.0, PT=0
# Buy 13 - Saka
# Sell 107 - March

# %%
sjekk =pd.read_csv("../output/optimal_plan_regular.csv")

# %%
sjekk
# Out:
#     Unnamed: 0  week              name  pos  type       team  buy_price  \
# 0            8    34           Ederson  GKP     1   Man City        5.4
# 1           11    34              Shaw  DEF     2    Man Utd        5.1
# 2            9    34              Dias  DEF     2   Man City        6.0
# 3            6    34         Robertson  DEF     2  Liverpool        6.8
# 4            7    34  Alexander-Arnold  DEF     2  Liverpool        7.5
# ..         ...   ...               ...  ...   ...        ...        ...
# 75          68    38      Arrizabalaga  GKP     1    Chelsea        4.7
# 76          78    38             Schär  DEF     2  Newcastle        5.1
# 77          77    38          Trippier  DEF     2  Newcastle        6.2
# 78          72    38              Dias  DEF     2   Man City        6.0
# 79          69    38         Greenwood  FWD     4      Leeds        4.0
#
#     sell_price     xP  xMin  lineup  bench  captain  vicecaptain  transfer_in  \
# 0          5.4   8.32    89       1     -1        0            0            0
# 1          5.1   5.32    77       1     -1        0            0            1
# 2          6.0   7.30    71       1     -1        0            0            0
# 3          6.8   7.84    74       1     -1        0            0            0
# 4          7.4  10.30    86       1     -1        0            0            0
# ..         ...    ...   ...     ...    ...      ...          ...          ...
# 75         4.7   3.29    77       0      0        0            0            0
# 76         5.1   2.62    74       0     -1        0            0            0
# 77         6.1   2.91    78       0      2        0            0            0
# 78         6.0   3.00    64       0      1        0            0            0
# 79         4.0   0.72    15       0      3        0            0            0
#
#     transfer_out
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 75             0
# 76             1
# 77             0
# 78             0
# 79             0
#
# [80 rows x 16 columns]
