# %%
import pandas as pd
import numpy as np
import sasoptpy as so
import requests
import os

import time
from subprocess import Popen, DEVNULL

# %%
def xmin_to_prob(xmin, sub_on=0.5, sub_off=0.3):
    start = min(max((xmin - 25 * sub_on) / (90 * (1-sub_off) +
                65 * sub_off - 25 * sub_on), 0.001), 0.999)
    return start + (1-start) * sub_on

# %%
def get_data(team_id, gw, seed_val, horizon, randomized):
    r = requests.get('https://fantasy.premierleague.com/api/bootstrap-static/')
    fpl_data = r.json()
    element_data = pd.DataFrame(fpl_data['elements'])
    team_data = pd.DataFrame(fpl_data['teams'])
    elements_team = pd.merge(element_data, team_data,
                             left_on='team', right_on='id')
    review_data = pd.read_csv('../Data/fplreview.csv')
    review_data = review_data.fillna(0)
    review_data['review_id'] = review_data.index+1
    merged_data = pd.merge(elements_team, review_data,
                           left_on='id_x', right_on='review_id')
    merged_data.set_index(['id_x'], inplace=True)

    if randomized:
        rng = np.random.default_rng(seed=seed_val)
        gws = list(range(gw+1, min(39, gw+1+horizon)))
        for w in gws:
            noise = merged_data[f"{w}_Pts"] * (
                92 - merged_data[f"{w}_xMins"]) / 134 * rng.standard_normal(size=len(merged_data))
            merged_data[f"{w}_Pts"] = merged_data[f"{w}_Pts"] + noise

    next_gw = int(review_data.keys()[6].split('_')[0])
    type_data = pd.DataFrame(fpl_data['element_types']).set_index(['id'])

    r = requests.get(
        f'https://fantasy.premierleague.com/api/entry/{team_id}/event/{gw}/picks/')
    picks_data = r.json()
    initial_squad = [i['element'] for i in picks_data['picks']]
    r = requests.get(f'https://fantasy.premierleague.com/api/entry/{team_id}/')
    general_data = r.json()
    itb = general_data['last_deadline_bank'] / 10

    return {'merged_data': merged_data, 'team_data': team_data, 'type_data': type_data, 'next_gw': next_gw, 'initial_squad': initial_squad, 'itb': itb}

# %%
# review_data = pd.read_csv('../Data/xp_points.csv')
# next_gw = int(review_data.keys()[6].split('_')[0])
# next_gw

# %%
def solve_multi_period_fpl(team_id, gw, ft, horizon, objective='regular', decay_base=0.84, bench_weights=None, seed=None, randomized=False):
    """
    Solves multi-objective FPL problem with transfers
    Parameters
    ----------
    team_id: integer
        FPL ID of the team to be optimized
    gw: integer
        Upcoming (next) gameweek
    ft: integer
        Number of available free transfers (currently)
    horizon: integer
        Number of weeks to consider in optimization
    objective: string
        Type of objective "regular" or "decay"
    decay_base: float
        Base for the decay function
    """

    # Data
    problem_name = f'mp_h{horizon}_regular' if objective == 'regular' else f'mp_h{horizon}_o{objective[0]}_d{decay_base}'
    data = get_data(team_id, gw-1, seed, horizon, randomized)
    merged_data = data['merged_data']
    team_data = data['team_data']
    type_data = data['type_data']
    next_gw = data['next_gw']
    initial_squad = data['initial_squad']
    itb = data['itb']

    # Sets
    players = merged_data.index.to_list()
    element_types = type_data.index.to_list()
    teams = team_data['name'].to_list()
    gameweeks = list(range(next_gw, next_gw+horizon))
    all_gw = [next_gw-1] + gameweeks
    order = [0, 1, 2, 3]
    if bench_weights is None:
        bench_weights = {0: 0.03, 1: 0.21, 2: 0.06, 3: 0.002}

    # Model
    model = so.Model(name=problem_name)

    # Variables
    squad = model.add_variables(
        players, all_gw, name='squad', vartype=so.binary)
    lineup = model.add_variables(
        players, gameweeks, name='lineup', vartype=so.binary)
    captain = model.add_variables(
        players, gameweeks, name='captain', vartype=so.binary)
    vicecap = model.add_variables(
        players, gameweeks, name='vicecap', vartype=so.binary)
    bench = model.add_variables(
        players, gameweeks, order, name='bench', vartype=so.binary)
    transfer_in = model.add_variables(
        players, gameweeks, name='transfer_in', vartype=so.binary)
    transfer_out = model.add_variables(
        players, gameweeks, name='transfer_out', vartype=so.binary)
    in_the_bank = model.add_variables(
        all_gw, name='itb', vartype=so.continuous, lb=0)
    free_transfers = model.add_variables(
        all_gw, name='ft', vartype=so.integer, lb=1, ub=2)
    penalized_transfers = model.add_variables(
        gameweeks, name='pt', vartype=so.integer, lb=0)
    aux = model.add_variables(gameweeks, name='aux', vartype=so.binary)

    # Dictionaries
    lineup_type_count = {(t, w): so.expr_sum(
        lineup[p, w] for p in players if merged_data.loc[p, 'element_type'] == t) for t in element_types for w in gameweeks}
    squad_type_count = {(t, w): so.expr_sum(
        squad[p, w] for p in players if merged_data.loc[p, 'element_type'] == t) for t in element_types for w in gameweeks}
    player_type = merged_data['element_type'].to_dict()

    # player_price = (merged_data['now_cost'] / 10).to_dict()
    sell_price = (merged_data['SV']).to_dict()
    buy_price = (merged_data['BV']).to_dict()
    sold_amount = {w: so.expr_sum(
        sell_price[p] * transfer_out[p, w] for p in players) for w in gameweeks}
    bought_amount = {w: so.expr_sum(
        buy_price[p] * transfer_in[p, w] for p in players) for w in gameweeks}
    points_player_week = {
        (p, w): merged_data.loc[p, f'{w}_Pts'] for p in players for w in gameweeks}
    minutes_player_week = {
        (p, w): merged_data.loc[p, f'{w}_xMins'] for p in players for w in gameweeks}
    squad_count = {w: so.expr_sum(squad[p, w]
                                  for p in players) for w in gameweeks}
    number_of_transfers = {w: so.expr_sum(
        transfer_out[p, w] for p in players) for w in gameweeks}
    number_of_transfers[next_gw-1] = 1
    transfer_diff = {
        w: number_of_transfers[w] - free_transfers[w] for w in gameweeks}

    # Initial conditions
    model.add_constraints(
        (squad[p, next_gw-1] == 1 for p in initial_squad), name='initial_squad_players')
    model.add_constraints(
        (squad[p, next_gw-1] == 0 for p in players if p not in initial_squad), name='initial_squad_others')
    model.add_constraint(in_the_bank[next_gw-1] == itb, name='initial_itb')
    model.add_constraint(free_transfers[next_gw-1] == ft, name='initial_ft')

    # Constraints
    model.add_constraints(
        (squad_count[w] == 15 for w in gameweeks), name='squad_count')
    model.add_constraints((so.expr_sum(
        lineup[p, w] for p in players) == 11 for w in gameweeks), name='lineup_count')
    model.add_constraints((so.expr_sum(
        bench[p, w, 0] for p in players if player_type[p] == 1) == 1 for w in gameweeks), name='bench_gk')
    model.add_constraints((so.expr_sum(
        bench[p, w, o] for p in players) == 1 for w in gameweeks for o in [1, 2, 3]), name='bench_count')
    model.add_constraints((so.expr_sum(
        captain[p, w] for p in players) == 1 for w in gameweeks), name='captain_count')
    model.add_constraints((so.expr_sum(
        vicecap[p, w] for p in players) == 1 for w in gameweeks), name='vicecap_count')
    model.add_constraints((lineup[p, w] <= squad[p, w]
                          for p in players for w in gameweeks), name='lineup_squad_rel')
    model.add_constraints((bench[p, w, o] <= squad[p, w]
                          for p in players for w in gameweeks for o in order), name='bench_squad_rel')
    model.add_constraints((captain[p, w] <= lineup[p, w]
                          for p in players for w in gameweeks), name='captain_lineup_rel')
    model.add_constraints((vicecap[p, w] <= lineup[p, w]
                          for p in players for w in gameweeks), name='vicecap_lineup_rel')
    model.add_constraints((captain[p, w] + vicecap[p, w] <=
                          1 for p in players for w in gameweeks), name='cap_vc_rel')
    model.add_constraints((lineup[p, w] + so.expr_sum(bench[p, w, o] for o in order)
                          <= 1 for p in players for w in gameweeks), name='lineup_bench_rel')
    model.add_constraints((lineup_type_count[t, w] == [type_data.loc[t, 'squad_min_play'], type_data.loc[t,
                          'squad_max_play']] for t in element_types for w in gameweeks), name='valid_formation')
    model.add_constraints((squad_type_count[t, w] == type_data.loc[t, 'squad_select']
                          for t in element_types for w in gameweeks), name='valid_squad')
    model.add_constraints((so.expr_sum(squad[p, w] for p in players if merged_data.loc[p,
                          'name'] == t) <= 3 for t in teams for w in gameweeks), name='team_limit')

    # Transfer constraints
    model.add_constraints((squad[p, w] == squad[p, w-1] + transfer_in[p, w] - transfer_out[p, w]
                          for p in players for w in gameweeks), name='squad_transfer_rel')
    model.add_constraints((in_the_bank[w] == in_the_bank[w-1] + sold_amount[w] -
                          bought_amount[w] for w in gameweeks), name='cont_budget')

    # Free transfer constraints
    model.add_constraints(
        (free_transfers[w] == aux[w] + 1 for w in gameweeks), name='aux_ft_rel')
    model.add_constraints((free_transfers[w-1] - number_of_transfers[w-1]
                          <= 2 * aux[w] for w in gameweeks), name='force_aux_1')
    model.add_constraints((free_transfers[w-1] - number_of_transfers[w-1]
                          >= aux[w] + (-14)*(1-aux[w]) for w in gameweeks), name='force_aux_2')
    model.add_constraints(
        (penalized_transfers[w] >= transfer_diff[w] for w in gameweeks), name='pen_transfer_rel')

    # Objectives
    gw_xp = {w: so.expr_sum(points_player_week[p, w] * (lineup[p, w] + captain[p, w] + 0.1*vicecap[p, w] + so.expr_sum(
        bench_weights[o] * bench[p, w, o] for o in order)) for p in players) for w in gameweeks}
    gw_total = {w: gw_xp[w] - 4 * penalized_transfers[w] for w in gameweeks}
    if objective == 'regular':
        total_xp = so.expr_sum(gw_total[w] for w in gameweeks)
        model.set_objective(-total_xp, sense='N', name='total_regular_xp')
    else:
        decay_objective = so.expr_sum(
            gw_total[w] * pow(decay_base, w-next_gw) for w in gameweeks)
        model.set_objective(-decay_objective, sense='N', name='total_decay_xp')

    # Solve
    model.export_mps(f'{problem_name}.mps')
    command = f'cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/{problem_name}.mps solve solu {problem_name}_sol.txt'
    # add 'stdout=DEVNULL' for disabling logs
    process = Popen(command, shell=True)
    process.wait()

    # Parsing
    with open(f'{problem_name}_sol.txt', 'r') as f:
        for line in f:
            if 'objective value' in line:
                continue
            words = line.split()
            var = model.get_variable(words[1])
            var.set_value(float(words[2]))

    # DataFrame generation
    picks = []
    for w in gameweeks:
        for p in players:
            if squad[p, w].get_value() + transfer_out[p, w].get_value() > 0.5:
                lp = merged_data.loc[p]
                is_captain = 1 if captain[p, w].get_value() > 0.5 else 0
                is_lineup = 1 if lineup[p, w].get_value() > 0.5 else 0
                is_vice = 1 if vicecap[p, w].get_value() > 0.5 else 0
                is_transfer_in = 1 if transfer_in[p,
                                                  w].get_value() > 0.5 else 0
                is_transfer_out = 1 if transfer_out[p, w].get_value(
                ) > 0.5 else 0
                bench_value = -1
                for o in order:
                    if bench[p, w, o].get_value() > 0.5:
                        bench_value = o
                position = type_data.loc[lp['element_type'],
                                         'singular_name_short']
                picks.append([
                    w, lp['web_name'], position, lp['element_type'], lp['name'], buy_price[p], sell_price[p], round(
                        points_player_week[p, w], 2), minutes_player_week[p, w], is_lineup, bench_value, is_captain, is_vice, is_transfer_in, is_transfer_out
                ])

    picks_df = pd.DataFrame(picks, columns=['week', 'name', 'pos', 'type', 'team', 'buy_price', 'sell_price', 'xP', 'xMin', 'lineup', 'bench',
                            'captain', 'vicecaptain', 'transfer_in', 'transfer_out']).sort_values(by=['week', 'lineup', 'type', 'xP'], ascending=[True, False, True, True])
    total_xp = so.expr_sum((lineup[p, w] + captain[p, w]) * points_player_week[p, w]
                           for p in players for w in gameweeks).get_value()

    # Writing summary
    summary_of_actions = ""
    for w in gameweeks:
        summary_of_actions += f"** GW {w}:\n"
        summary_of_actions += f"ITB = {in_the_bank[w].get_value()}, FT={free_transfers[w].get_value()}, PT={penalized_transfers[w].get_value()}\n"
        for p in players:
            if transfer_in[p, w].get_value() > 0.5:
                summary_of_actions += f"Buy {p} - {merged_data['web_name'][p]}\n"
            if transfer_out[p, w].get_value() > 0.5:
                summary_of_actions += f"Sell {p} - {merged_data['web_name'][p]}\n"

    return {'model': model, 'picks': picks_df, 'total_xp': total_xp, 'summary': summary_of_actions}

# %%
def solve_standard_problem():
    r = solve_multi_period_fpl(
        team_id=2821496, gw=18, ft=1, horizon=3, objective='regular')
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular.csv')

# %%
def solve_autobench_problem():
    r = solve_multi_period_fpl(
        team_id=2821496, gw=18, ft=1, horizon=3, objective='regular')
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular_stage_1.csv')

    df = r['picks']
    lineup_gk = df[(df['week'] == 4) & (
        df['pos'] == 'GKP') & (df['lineup'] == 1)]
    lineup_gk = lineup_gk.iloc[0]
    lineup_gk_mins = lineup_gk['xMin']
    gk_autosub_prob = xmin_to_prob(lineup_gk_mins, sub_on=0, sub_off=0)
    gk_weight = 1-gk_autosub_prob

    field_players = df[(df['week'] == 4) & (
        df['pos'] != 'GKP') & (df['lineup'] == 1)]
    field_players_xmins = field_players['xMin'].tolist()
    field_players_probs = [xmin_to_prob(i) for i in field_players_xmins]

    prob = 1
    for i in field_players_probs:
        prob *= i
    bench_1_weight = 1 - prob

    bench_weights = {0: gk_weight, 1: bench_1_weight, 2: 0.06, 3: 0.002}
    r = solve_multi_period_fpl(team_id=2821496, gw=18, ft=1,
                               horizon=3, objective='regular', bench_weights=bench_weights)
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular_stage_2.csv')

# %%
def solve_randomized_problem():
    r = solve_multi_period_fpl(team_id=2821496, gw=19, ft=1,
                               horizon=3, objective='regular', seed=None, randomized=True)
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_randomized.csv')


if __name__ == '__main__':

    solve_standard_problem()  
    
    solve_randomized_problem()
# Out:
# NOTE: Initialized model mp_h3_regular.
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Nov  6 2022
#
# command line - cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/mp_h3_regular.mps solve solu mp_h3_regular_sol.txt (default strategy 1)
# At line 1 NAME    mp_h3_regular
# At line 2 ROWS
# At line 21302 COLUMNS
# At line 71594 RHS
# At line 73710 RANGES
# At line 73720 BOUNDS
# At line 94908 ENDATA
# Problem mp_h3_regular has 21298 rows, 21187 columns and 81525 elements
# Coin0008I mp_h3_regular read with 0 errors
# Continuous objective value is -236.113 - 0.60 seconds
# Cgl0002I 668 variables fixed
# Cgl0003I 0 fixed, 3 tightened bounds, 17998 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9847 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7799 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5304 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1444 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0004I processed model has 8329 rows, 20054 columns (20052 integer (20049 of which binary)) and 68924 elements
# Cbc0038I Initial state - 79 integers unsatisfied sum - 16.6164
# Cbc0038I Pass   1: (4.37 seconds) suminf.    2.29854 (12) obj. -228.25 iterations 1143
# Cbc0038I Pass   2: (4.39 seconds) suminf.    2.27556 (10) obj. -227.737 iterations 259
# Cbc0038I Pass   3: (4.44 seconds) suminf.    0.00000 (0) obj. -212.374 iterations 418
# Cbc0038I Solution found of -212.374
# Cbc0038I Relaxing continuous gives -212.374
# Cbc0038I Cleaned solution of -212.374
# Cbc0038I Rounding solution of -212.964 is better than previous of -212.374
#
# Cbc0038I Before mini branch and bound, 19964 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 8329 rows 20054 columns, reduced to 53 rows 44 columns
# Cbc0038I Mini branch and bound improved solution from -212.964 to -225.119 (4.48 seconds)
# Cbc0038I Round again with cutoff of -225.647
# Cbc0038I Reduced cost fixing fixed 1958 variables on major pass 2
# Cbc0038I Pass   4: (4.49 seconds) suminf.    2.29854 (12) obj. -228.25 iterations 0
# Cbc0038I Pass   5: (4.51 seconds) suminf.    2.27556 (10) obj. -227.737 iterations 247
# Cbc0038I Pass   6: (4.69 seconds) suminf.    3.50497 (10) obj. -225.647 iterations 1337
# Cbc0038I Pass   7: (4.78 seconds) suminf.    2.99453 (12) obj. -225.647 iterations 1064
# Cbc0038I Pass   8: (4.84 seconds) suminf.    2.49944 (13) obj. -225.647 iterations 613
# Cbc0038I Pass   9: (4.97 seconds) suminf.    2.89455 (10) obj. -225.647 iterations 1363
# Cbc0038I Pass  10: (5.00 seconds) suminf.    2.89455 (10) obj. -225.647 iterations 213
# Cbc0038I Pass  11: (5.08 seconds) suminf.    1.86649 (10) obj. -225.647 iterations 682
# Cbc0038I Pass  12: (5.09 seconds) suminf.    1.86649 (10) obj. -225.647 iterations 2
# Cbc0038I Pass  13: (5.18 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 907
# Cbc0038I Pass  14: (5.19 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 1
# Cbc0038I Pass  15: (5.24 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 335
# Cbc0038I Pass  16: (5.28 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 322
# Cbc0038I Pass  17: (5.34 seconds) suminf.    1.86649 (10) obj. -225.647 iterations 516
# Cbc0038I Pass  18: (5.36 seconds) suminf.    1.86649 (10) obj. -225.647 iterations 2
# Cbc0038I Pass  19: (5.44 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 821
# Cbc0038I Pass  20: (5.51 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 403
# Cbc0038I Pass  21: (5.56 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 364
# Cbc0038I Pass  22: (5.61 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 382
# Cbc0038I Pass  23: (5.67 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 462
# Cbc0038I Pass  24: (5.72 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 421
# Cbc0038I Pass  25: (5.76 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 438
# Cbc0038I Pass  26: (5.80 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 485
# Cbc0038I Pass  27: (5.85 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 505
# Cbc0038I Pass  28: (5.89 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 450
# Cbc0038I Pass  29: (5.91 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 277
# Cbc0038I Pass  30: (5.94 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 272
# Cbc0038I Pass  31: (5.98 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 407
# Cbc0038I Pass  32: (6.01 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 253
# Cbc0038I Pass  33: (6.03 seconds) suminf.    0.49384 (10) obj. -225.647 iterations 203
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 19956 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 8329 rows 20054 columns, reduced to 58 rows 52 columns
# Cbc0038I Mini branch and bound did not improve solution (6.05 seconds)
# Cbc0038I After 6.05 seconds - Feasibility pump exiting with objective of -225.119 - took 1.83 seconds
# Cbc0012I Integer solution of -225.11938 found by feasibility pump after 0 iterations and 0 nodes (6.05 seconds)
# Cbc0038I Full problem 8329 rows 20054 columns, reduced to 48 rows 35 columns
# Cbc0031I 8 added rows had average density of 450.625
# Cbc0013I At root node, 8 cuts changed objective from -230.39952 to -226.07654 in 6 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 2313 column cuts (2313 active)  in 0.021 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 685.5 elements, 0 column cuts (0 active)  in 0.034 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.046 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 15 row cuts average 624.7 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 11.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 4 row cuts average 344.0 elements, 0 column cuts (0 active)  in 0.206 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -225.11938 best solution, best possible -225.77308 (6.74 seconds)
# Cbc0012I Integer solution of -225.41286 found by DiveCoefficient after 1036 iterations and 1 nodes (6.93 seconds)
# Cbc0001I Search completed - best objective -225.4128600000001, took 1506 iterations and 6 nodes (7.33 seconds)
# Cbc0032I Strong branching done 68 times (2382 iterations), fathomed 2 nodes and fixed 3 variables
# Cbc0035I Maximum depth 2, 6435 variables fixed on reduced cost
# Cuts at root node changed objective from -230.4 to -225.773
# Probing was tried 14 times and created 2325 cuts of which 0 were active after adding rounds of cuts (0.026 seconds)
# Gomory was tried 6 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.034 seconds)
# Knapsack was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.046 seconds)
# Clique was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 14 times and created 29 cuts of which 0 were active after adding rounds of cuts (0.022 seconds)
# FlowCover was tried 14 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# ZeroHalf was tried 14 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.489 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -225.41286000
# Enumerated nodes:               6
# Total iterations:               1506
# Time (CPU seconds):             7.40
# Time (Wallclock seconds):       7.59
#
# Total time (CPU seconds):       7.44   (Wallclock seconds):       7.63
#
#     week              name  pos  type       team  buy_price  sell_price  \
# 6     19              Leno  GKP     1     Fulham        4.5         4.5
# 13    19              Shaw  DEF     2    Man Utd        5.0         4.9
# 9     19  Alexander-Arnold  DEF     2  Liverpool        7.2         7.2
# 5     19         Cucurella  DEF     2    Chelsea        5.2         5.2
# 2     19        Martinelli  MID     3    Arsenal        6.8         6.8
# 0     19              Saka  MID     3    Arsenal        8.1         8.0
# 14    19          Rashford  MID     3    Man Utd        6.9         6.7
# 8     19           Andreas  MID     3     Fulham        4.6         4.5
# 10    19            Darwin  FWD     4  Liverpool        9.0         8.9
# 12    19           Haaland  FWD     4   Man City       12.2        11.9
# 7     19          Mitrović  FWD     4     Fulham        7.1         6.9
# 4     19           Sánchez  GKP     1   Brighton        4.6         4.6
# 15    19          Trippier  DEF     2  Newcastle        5.9         5.6
# 11    19           Cancelo  DEF     2   Man City        7.3         7.3
# 1     19           Gabriel  DEF     2    Arsenal        5.2         5.2
# 3     19          Trossard  MID     3   Brighton        6.9         6.9
# 28    20           Ederson  GKP     1   Man City        5.4         5.4
# 30    20              Shaw  DEF     2    Man Utd        5.0         4.9
# 21    20         Cucurella  DEF     2    Chelsea        5.2         5.2
# 25    20  Alexander-Arnold  DEF     2  Liverpool        7.2         7.2
# 27    20           Cancelo  DEF     2   Man City        7.3         7.3
# 19    20          Trossard  MID     3   Brighton        6.9         6.9
# 16    20              Saka  MID     3    Arsenal        8.1         8.0
# 18    20        Martinelli  MID     3    Arsenal        6.8         6.8
# 31    20          Rashford  MID     3    Man Utd        6.9         6.7
# 26    20            Darwin  FWD     4  Liverpool        9.0         8.9
# 29    20           Haaland  FWD     4   Man City       12.2        11.9
# 20    20           Sánchez  GKP     1   Brighton        4.6         4.6
# 22    20              Leno  GKP     1     Fulham        4.5         4.5
# 17    20           Gabriel  DEF     2    Arsenal        5.2         5.2
# 24    20           Andreas  MID     3     Fulham        4.6         4.5
# 23    20          Mitrović  FWD     4     Fulham        7.1         6.9
# 37    21           Sánchez  GKP     1   Brighton        4.6         4.6
# 43    21           Cancelo  DEF     2   Man City        7.3         7.3
# 41    21  Alexander-Arnold  DEF     2  Liverpool        7.2         7.2
# 33    21           Gabriel  DEF     2    Arsenal        5.2         5.2
# 35    21              Groß  MID     3   Brighton        5.6         5.6
# 36    21          Trossard  MID     3   Brighton        6.9         6.9
# 34    21        Martinelli  MID     3    Arsenal        6.8         6.8
# 32    21              Saka  MID     3    Arsenal        8.1         8.0
# 39    21          Mitrović  FWD     4     Fulham        7.1         6.9
# 42    21            Darwin  FWD     4  Liverpool        9.0         8.9
# 45    21           Haaland  FWD     4   Man City       12.2        11.9
# 44    21           Ederson  GKP     1   Man City        5.4         5.4
# 46    21              Shaw  DEF     2    Man Utd        5.0         4.9
# 38    21         Cucurella  DEF     2    Chelsea        5.2         5.2
# 40    21           Andreas  MID     3     Fulham        4.6         4.5
# 47    21          Rashford  MID     3    Man Utd        6.9         6.7
#
#        xP  xMin  lineup  bench  captain  vicecaptain  transfer_in  \
# 6    6.73    87       1     -1        0            1            0
# 13   4.39    75       1     -1        0            0            0
# 9    4.73    83       1     -1        0            0            0
# 5    5.57    76       1     -1        0            0            1
# 2    4.70    83       1     -1        0            0            0
# 0    5.12    82       1     -1        0            0            0
# 14   5.68    75       1     -1        0            0            0
# 8    6.47    81       1     -1        0            0            0
# 10   5.26    77       1     -1        0            0            0
# 12   5.86    82       1     -1        0            0            0
# 7    7.99    73       1     -1        1            0            0
# 4    3.80    89       0      0        0            0            0
# 15   2.63    85       0     -1        0            0            0
# 11   3.37    68       0      3        0            0            0
# 1    3.77    82       0      2        0            0            0
# 3    4.43    75       0      1        0            0            0
# 28   6.46    88       1     -1        0            1            1
# 30   3.72    76       1     -1        0            0            0
# 21   3.88    72       1     -1        0            0            0
# 25   4.08    82       1     -1        0            0            0
# 27   5.69    68       1     -1        0            0            0
# 19   3.78    74       1     -1        0            0            0
# 16   4.16    68       1     -1        0            0            0
# 18   4.44    81       1     -1        0            0            0
# 31   5.82    71       1     -1        0            0            0
# 26   4.61    73       1     -1        0            0            0
# 29  10.40    77       1     -1        1            0            0
# 20   3.20    88       0      0        0            0            0
# 22   3.24    87       0     -1        0            0            0
# 17   3.27    79       0      2        0            0            0
# 24   2.74    77       0      3        0            0            0
# 23   3.30    71       0      1        0            0            0
# 37   6.43    87       1     -1        0            0            0
# 43   4.28    65       1     -1        0            0            0
# 41   6.40    81       1     -1        0            0            0
# 33   7.10    79       1     -1        0            0            0
# 35   6.36    73       1     -1        0            0            1
# 36   7.31    72       1     -1        0            0            0
# 34   8.68    78       1     -1        0            1            0
# 32   8.71    71       1     -1        1            0            0
# 39   4.47    78       1     -1        0            0            0
# 42   6.51    68       1     -1        0            0            0
# 45   7.10    73       1     -1        0            0            0
# 44   4.50    88       0      0        0            0            0
# 46   1.87    68       0      3        0            0            0
# 38   2.76    65       0      2        0            0            0
# 40   3.16    77       0      1        0            0            0
# 47   3.26    66       0     -1        0            0            0
#
#     transfer_out
# 6              0
# 13             0
# 9              0
# 5              0
# 2              0
# 0              0
# 14             0
# 8              0
# 10             0
# 12             0
# 7              0
# 4              0
# 15             1
# 11             0
# 1              0
# 3              0
# 28             0
# 30             0
# 21             0
# 25             0
# 27             0
# 19             0
# 16             0
# 18             0
# 31             0
# 26             0
# 29             0
# 20             0
# 22             1
# 17             0
# 24             0
# 23             0
# 37             0
# 43             0
# 41             0
# 33             0
# 35             0
# 36             0
# 34             0
# 32             0
# 39             0
# 42             0
# 45             0
# 44             0
# 46             0
# 38             0
# 40             0
# 47             1
# ** GW 19:
# ITB = 1.1, FT=1.0, PT=0
# Buy 112 - Cucurella
# Sell 357 - Trippier
# ** GW 20:
# ITB = 0.2, FT=1.0, PT=0
# Sell 2 - Leno
# Buy 307 - Ederson
# ** GW 21:
# ITB = 1.3, FT=1.0, PT=0
# Buy 104 - Groß
# Sell 335 - Rashford
#
# NOTE: Initialized model mp_h3_regular.
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Nov  6 2022
#
# command line - cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/mp_h3_regular.mps solve solu mp_h3_regular_sol.txt (default strategy 1)
# At line 1 NAME    mp_h3_regular
# At line 2 ROWS
# At line 21302 COLUMNS
# At line 71594 RHS
# At line 73710 RANGES
# At line 73720 BOUNDS
# At line 94908 ENDATA
# Problem mp_h3_regular has 21298 rows, 21187 columns and 81525 elements
# Coin0008I mp_h3_regular read with 0 errors
# Continuous objective value is -237.47 - 0.67 seconds
# Cgl0002I 668 variables fixed
# Cgl0003I 0 fixed, 3 tightened bounds, 17965 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9803 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7757 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5232 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1400 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0004I processed model has 8325 rows, 20021 columns (20019 integer (20016 of which binary)) and 68823 elements
# Cbc0038I Initial state - 97 integers unsatisfied sum - 26.9099
# Cbc0038I Pass   1: (4.74 seconds) suminf.    0.40889 (4) obj. -223.076 iterations 2166
# Cbc0038I Pass   2: (4.75 seconds) suminf.    0.40889 (4) obj. -223.076 iterations 9
# Cbc0038I Pass   3: (4.76 seconds) suminf.    0.00000 (0) obj. -215.894 iterations 6
# Cbc0038I Solution found of -215.894
# Cbc0038I Relaxing continuous gives -215.894
# Cbc0038I Cleaned solution of -215.894
# Cbc0038I Before mini branch and bound, 19919 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 8325 rows 20021 columns, reduced to 78 rows 57 columns
# Cbc0038I Mini branch and bound improved solution from -215.894 to -218.156 (4.80 seconds)
# Cbc0038I Round again with cutoff of -219.357
# Cbc0038I Reduced cost fixing fixed 141 variables on major pass 2
# Cbc0038I Pass   4: (4.81 seconds) suminf.    0.40889 (4) obj. -223.076 iterations 0
# Cbc0038I Pass   5: (4.82 seconds) suminf.    0.40889 (4) obj. -223.076 iterations 6
# Cbc0038I Pass   6: (4.91 seconds) suminf.    0.51491 (4) obj. -219.357 iterations 857
# Cbc0038I Pass   7: (4.93 seconds) suminf.    0.51491 (4) obj. -219.357 iterations 53
# Cbc0038I Pass   8: (5.02 seconds) suminf.    0.13333 (2) obj. -219.628 iterations 976
# Cbc0038I Pass   9: (5.32 seconds) suminf.    0.92788 (7) obj. -219.357 iterations 1874
# Cbc0038I Pass  10: (5.39 seconds) suminf.    0.92788 (7) obj. -219.357 iterations 408
# Cbc0038I Pass  11: (5.47 seconds) suminf.    0.92697 (7) obj. -219.357 iterations 802
# Cbc0038I Pass  12: (5.53 seconds) suminf.    0.92697 (7) obj. -219.357 iterations 430
# Cbc0038I Pass  13: (5.63 seconds) suminf.    0.51431 (4) obj. -219.357 iterations 1081
# Cbc0038I Pass  14: (5.65 seconds) suminf.    0.51431 (4) obj. -219.357 iterations 59
# Cbc0038I Pass  15: (5.74 seconds) suminf.    0.13333 (2) obj. -219.629 iterations 928
# Cbc0038I Pass  16: (5.85 seconds) suminf.    0.47865 (6) obj. -219.357 iterations 1128
# Cbc0038I Pass  17: (5.93 seconds) suminf.    0.47865 (6) obj. -219.357 iterations 448
# Cbc0038I Pass  18: (5.99 seconds) suminf.    0.50137 (6) obj. -219.357 iterations 433
# Cbc0038I Pass  19: (6.05 seconds) suminf.    0.50137 (6) obj. -219.357 iterations 354
# Cbc0038I Pass  20: (6.14 seconds) suminf.    0.55406 (4) obj. -219.357 iterations 979
# Cbc0038I Pass  21: (6.16 seconds) suminf.    0.55406 (4) obj. -219.357 iterations 36
# Cbc0038I Pass  22: (6.23 seconds) suminf.    0.13333 (2) obj. -219.538 iterations 763
# Cbc0038I Pass  23: (6.32 seconds) suminf.    1.24972 (5) obj. -219.357 iterations 863
# Cbc0038I Pass  24: (6.37 seconds) suminf.    0.13333 (2) obj. -220.845 iterations 624
# Cbc0038I Pass  25: (6.43 seconds) suminf.    0.87759 (2) obj. -219.357 iterations 619
# Cbc0038I Pass  26: (6.49 seconds) suminf.    0.40000 (2) obj. -220.312 iterations 718
# Cbc0038I Pass  27: (6.61 seconds) suminf.    1.11638 (4) obj. -219.357 iterations 1502
# Cbc0038I Pass  28: (6.68 seconds) suminf.    0.40000 (2) obj. -220.312 iterations 1030
# Cbc0038I Pass  29: (6.79 seconds) suminf.    0.87759 (4) obj. -219.357 iterations 1173
# Cbc0038I Pass  30: (6.92 seconds) suminf.    0.54222 (4) obj. -220.028 iterations 1343
# Cbc0038I Pass  31: (6.98 seconds) suminf.    0.87759 (4) obj. -219.357 iterations 693
# Cbc0038I Pass  32: (7.09 seconds) suminf.    1.04527 (6) obj. -219.357 iterations 847
# Cbc0038I Pass  33: (7.19 seconds) suminf.    1.09729 (6) obj. -219.357 iterations 821
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 19901 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 8325 rows 20021 columns, reduced to 82 rows 65 columns
# Cbc0038I Mini branch and bound did not improve solution (7.20 seconds)
# Cbc0038I After 7.20 seconds - Feasibility pump exiting with objective of -218.156 - took 2.74 seconds
# Cbc0012I Integer solution of -218.15572 found by feasibility pump after 0 iterations and 0 nodes (7.21 seconds)
# Cbc0038I Full problem 8325 rows 20021 columns, reduced to 78 rows 56 columns
# Cbc0012I Integer solution of -219.98881 found by DiveCoefficient after 1664 iterations and 0 nodes (8.01 seconds)
# Cbc0031I 8 added rows had average density of 1025.5
# Cbc0013I At root node, 8 cuts changed objective from -230.1671 to -225.17129 in 6 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1268 column cuts (1268 active)  in 0.059 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 685.5 elements, 0 column cuts (0 active)  in 0.056 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.047 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 17 row cuts average 1247.5 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 1 row cuts average 685.0 elements, 0 column cuts (0 active)  in 0.037 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -219.98881 best solution, best possible -225.17129 (8.41 seconds)
# Cbc0012I Integer solution of -223.17198 found by DiveCoefficient after 2032 iterations and 1 nodes (8.57 seconds)
# Cbc0012I Integer solution of -223.19131 found by DiveCoefficient after 2627 iterations and 5 nodes (8.86 seconds)
# Cbc0012I Integer solution of -223.25652 found by DiveCoefficient after 4674 iterations and 37 nodes (9.57 seconds)
# Cbc0012I Integer solution of -223.77182 found by rounding after 4769 iterations and 38 nodes (9.65 seconds)
# Cbc0001I Search completed - best objective -223.771816668, took 5152 iterations and 42 nodes (9.75 seconds)
# Cbc0032I Strong branching done 232 times (3777 iterations), fathomed 4 nodes and fixed 0 variables
# Cbc0035I Maximum depth 9, 15538 variables fixed on reduced cost
# Cuts at root node changed objective from -230.167 to -225.171
# Probing was tried 47 times and created 1302 cuts of which 0 were active after adding rounds of cuts (0.097 seconds)
# Gomory was tried 6 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.056 seconds)
# Knapsack was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.047 seconds)
# Clique was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 47 times and created 112 cuts of which 0 were active after adding rounds of cuts (0.086 seconds)
# FlowCover was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# ZeroHalf was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.037 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -223.77181667
# Enumerated nodes:               42
# Total iterations:               5152
# Time (CPU seconds):             9.80
# Time (Wallclock seconds):       10.00
#
# Total time (CPU seconds):       9.85   (Wallclock seconds):       10.05
#
#     week              name  pos  type       team  buy_price  sell_price  \
# 5     19              Leno  GKP     1     Fulham        4.5         4.5
# 10    19           Cancelo  DEF     2   Man City        7.3         7.3
# 12    19              Shaw  DEF     2    Man Utd        5.0         4.9
# 8     19  Alexander-Arnold  DEF     2  Liverpool        7.2         7.2
# 13    19          Rashford  MID     3    Man Utd        6.9         6.7
# 3     19          Trossard  MID     3   Brighton        6.9         6.9
# 0     19              Saka  MID     3    Arsenal        8.1         8.0
# 7     19           Andreas  MID     3     Fulham        4.6         4.5
# 9     19            Darwin  FWD     4  Liverpool        9.0         8.9
# 11    19           Haaland  FWD     4   Man City       12.2        11.9
# 14    19           Martial  FWD     4    Man Utd        6.7         6.7
# 4     19           Sánchez  GKP     1   Brighton        4.6         4.6
# 15    19          Trippier  DEF     2  Newcastle        5.9         5.6
# 1     19           Gabriel  DEF     2    Arsenal        5.2         5.2
# 2     19        Martinelli  MID     3    Arsenal        6.8         6.8
# 6     19          Mitrović  FWD     4     Fulham        7.1         6.9
# 26    20           Ederson  GKP     1   Man City        5.4         5.4
# 17    20           Gabriel  DEF     2    Arsenal        5.2         5.2
# 23    20  Alexander-Arnold  DEF     2  Liverpool        7.2         7.2
# 25    20           Cancelo  DEF     2   Man City        7.3         7.3
# 19    20          Trossard  MID     3   Brighton        6.9         6.9
# 18    20        Martinelli  MID     3    Arsenal        6.8         6.8
# 16    20              Saka  MID     3    Arsenal        8.1         8.0
# 29    20          Rashford  MID     3    Man Utd        6.9         6.7
# 24    20            Darwin  FWD     4  Liverpool        9.0         8.9
# 30    20           Martial  FWD     4    Man Utd        6.7         6.7
# 27    20           Haaland  FWD     4   Man City       12.2        11.9
# 20    20           Sánchez  GKP     1   Brighton        4.6         4.6
# 21    20              Leno  GKP     1     Fulham        4.5         4.5
# 31    20          Trippier  DEF     2  Newcastle        5.9         5.6
# 28    20              Shaw  DEF     2    Man Utd        5.0         4.9
# 22    20           Andreas  MID     3     Fulham        4.6         4.5
# 36    21           Sánchez  GKP     1   Brighton        4.6         4.6
# 41    21           Cancelo  DEF     2   Man City        7.3         7.3
# 39    21  Alexander-Arnold  DEF     2  Liverpool        7.2         7.2
# 33    21           Gabriel  DEF     2    Arsenal        5.2         5.2
# 38    21           Rodrigo  MID     3      Leeds        6.3         6.3
# 35    21          Trossard  MID     3   Brighton        6.9         6.9
# 34    21        Martinelli  MID     3    Arsenal        6.8         6.8
# 32    21              Saka  MID     3    Arsenal        8.1         8.0
# 46    21           Martial  FWD     4    Man Utd        6.7         6.7
# 43    21           Haaland  FWD     4   Man City       12.2        11.9
# 40    21            Darwin  FWD     4  Liverpool        9.0         8.9
# 42    21           Ederson  GKP     1   Man City        5.4         5.4
# 44    21              Shaw  DEF     2    Man Utd        5.0         4.9
# 47    21          Trippier  DEF     2  Newcastle        5.9         5.6
# 45    21          Rashford  MID     3    Man Utd        6.9         6.7
# 37    21           Andreas  MID     3     Fulham        4.6         4.5
#
#        xP  xMin  lineup  bench  captain  vicecaptain  transfer_in  \
# 5    6.37    87       1     -1        0            1            0
# 10   4.26    68       1     -1        0            0            0
# 12   4.76    75       1     -1        0            0            0
# 8    4.85    83       1     -1        0            0            0
# 13   4.63    75       1     -1        0            0            0
# 3    4.82    75       1     -1        0            0            0
# 0    4.90    82       1     -1        0            0            0
# 7    5.99    81       1     -1        0            0            0
# 9    5.42    77       1     -1        0            0            0
# 11   6.16    82       1     -1        0            0            0
# 14   7.29    73       1     -1        1            0            1
# 4    3.66    89       0      0        0            0            0
# 15   2.49    85       0      3        0            0            0
# 1    4.13    82       0      2        0            0            0
# 2    4.52    83       0      1        0            0            0
# 6    6.49    73       0     -1        0            0            0
# 26   6.42    88       1     -1        0            1            1
# 17   3.53    79       1     -1        0            0            0
# 23   4.37    82       1     -1        0            0            0
# 25   4.76    68       1     -1        0            0            0
# 19   3.70    74       1     -1        0            0            0
# 18   4.50    81       1     -1        0            0            0
# 16   4.61    68       1     -1        0            0            0
# 29   5.20    71       1     -1        0            0            0
# 24   4.52    73       1     -1        0            0            0
# 30   6.40    70       1     -1        0            0            0
# 27  10.96    77       1     -1        1            0            0
# 20   3.13    88       0      0        0            0            0
# 21   3.39    87       0     -1        0            0            0
# 31   2.09    69       0      3        0            0            0
# 28   3.49    76       0      1        0            0            0
# 22   2.89    77       0      2        0            0            0
# 36   6.76    87       1     -1        0            0            0
# 41   3.47    65       1     -1        0            0            0
# 39   5.70    81       1     -1        0            0            0
# 33   8.64    79       1     -1        0            1            0
# 38   6.53    57       1     -1        0            0            1
# 35   7.34    72       1     -1        0            0            0
# 34   7.50    78       1     -1        0            0            0
# 32   8.66    71       1     -1        1            0            0
# 46   3.31    66       1     -1        0            0            0
# 43   7.34    73       1     -1        0            0            0
# 40   7.80    68       1     -1        0            0            0
# 42   4.60    88       0      0        0            0            0
# 44   1.62    68       0      3        0            0            0
# 47   2.84    72       0      2        0            0            0
# 45   1.85    66       0     -1        0            0            0
# 37   3.09    77       0      1        0            0            0
#
#     transfer_out
# 5              0
# 10             0
# 12             0
# 8              0
# 13             0
# 3              0
# 0              0
# 7              0
# 9              0
# 11             0
# 14             0
# 4              0
# 15             0
# 1              0
# 2              0
# 6              1
# 26             0
# 17             0
# 23             0
# 25             0
# 19             0
# 18             0
# 16             0
# 29             0
# 24             0
# 30             0
# 27             0
# 20             0
# 21             1
# 31             0
# 28             0
# 22             0
# 36             0
# 41             0
# 39             0
# 33             0
# 38             0
# 35             0
# 34             0
# 32             0
# 46             0
# 43             0
# 40             0
# 42             0
# 44             0
# 47             0
# 45             1
# 37             0
# ** GW 19:
# ITB = 0.9, FT=1.0, PT=0
# Sell 210 - Mitrović
# Buy 345 - Martial
# ** GW 20:
# ITB = 0, FT=1.0, PT=0
# Sell 2 - Leno
# Buy 307 - Ederson
# ** GW 21:
# ITB = 0.4, FT=1.0, PT=0
# Buy 225 - Rodrigo
# Sell 335 - Rashford

# %%
sjekk =pd.read_csv("../output/optimal_plan_regular.csv")
