# %%
import pandas as pd
import numpy as np
import sasoptpy as so
import requests
import os

import time
from subprocess import Popen, DEVNULL
gw = 25
ft=1

# %%
def xmin_to_prob(xmin, sub_on=0.5, sub_off=0.3):
    start = min(max((xmin - 25 * sub_on) / (90 * (1-sub_off) +
                65 * sub_off - 25 * sub_on), 0.001), 0.999)
    return start + (1-start) * sub_on

# %%
def get_data(team_id, gw, seed_val, horizon, randomized):
    r = requests.get('https://fantasy.premierleague.com/api/bootstrap-static/')
    fpl_data = r.json()
    element_data = pd.DataFrame(fpl_data['elements'])
    team_data = pd.DataFrame(fpl_data['teams'])
    elements_team = pd.merge(element_data, team_data,
                             left_on='team', right_on='id')
    review_data = pd.read_csv('../Data/fplreview.csv')
    review_data = review_data.fillna(0)
    review_data['review_id'] = review_data.index+1
    merged_data = pd.merge(elements_team, review_data,
                           left_on='id_x', right_on='review_id')
    merged_data.set_index(['id_x'], inplace=True)

    if randomized:
        rng = np.random.default_rng(seed=seed_val)
        gws = list(range(gw+1, min(39, gw+1+horizon)))
        for w in gws:
            noise = merged_data[f"{w}_Pts"] * (
                92 - merged_data[f"{w}_xMins"]) / 134 * rng.standard_normal(size=len(merged_data))
            merged_data[f"{w}_Pts"] = merged_data[f"{w}_Pts"] + noise

    next_gw = int(review_data.keys()[6].split('_')[0])
    type_data = pd.DataFrame(fpl_data['element_types']).set_index(['id'])

    r = requests.get(
        f'https://fantasy.premierleague.com/api/entry/{team_id}/event/{gw}/picks/')
    picks_data = r.json()
    initial_squad = [i['element'] for i in picks_data['picks']]
    r = requests.get(f'https://fantasy.premierleague.com/api/entry/{team_id}/')
    general_data = r.json()
    itb = general_data['last_deadline_bank'] / 10

    return {'merged_data': merged_data, 'team_data': team_data, 'type_data': type_data, 'next_gw': next_gw, 'initial_squad': initial_squad, 'itb': itb}

# %%
# review_data = pd.read_csv('../Data/xp_points.csv')
# next_gw = int(review_data.keys()[6].split('_')[0])
# next_gw

# %%
def solve_multi_period_fpl(team_id, gw, ft, horizon, objective='regular', decay_base=0.85, bench_weights=None, seed=None, randomized=False):
    """
    Solves multi-objective FPL problem with transfers
    Parameters
    ----------
    team_id: integer
        FPL ID of the team to be optimized
    gw: integer
        Upcoming (next) gameweek
    ft: integer
        Number of available free transfers (currently)
    horizon: integer
        Number of weeks to consider in optimization
    objective: string
        Type of objective "regular" or "decay"
    decay_base: float
        Base for the decay function
    """

    # Data
    problem_name = f'mp_h{horizon}_regular' if objective == 'regular' else f'mp_h{horizon}_o{objective[0]}_d{decay_base}'
    data = get_data(team_id, gw-1, seed, horizon, randomized)
    merged_data = data['merged_data']
    team_data = data['team_data']
    type_data = data['type_data']
    next_gw = data['next_gw']
    initial_squad = data['initial_squad']
    itb = data['itb']

    # Sets
    players = merged_data.index.to_list()
    element_types = type_data.index.to_list()
    teams = team_data['name'].to_list()
    gameweeks = list(range(next_gw, next_gw+horizon))
    all_gw = [next_gw-1] + gameweeks
    order = [0, 1, 2, 3]
    if bench_weights is None:
        bench_weights = {0: 0.03, 1: 0.21, 2: 0.06, 3: 0.002}

    # Model
    model = so.Model(name=problem_name)

    # Variables
    squad = model.add_variables(
        players, all_gw, name='squad', vartype=so.binary)
    lineup = model.add_variables(
        players, gameweeks, name='lineup', vartype=so.binary)
    captain = model.add_variables(
        players, gameweeks, name='captain', vartype=so.binary)
    vicecap = model.add_variables(
        players, gameweeks, name='vicecap', vartype=so.binary)
    bench = model.add_variables(
        players, gameweeks, order, name='bench', vartype=so.binary)
    transfer_in = model.add_variables(
        players, gameweeks, name='transfer_in', vartype=so.binary)
    transfer_out = model.add_variables(
        players, gameweeks, name='transfer_out', vartype=so.binary)
    in_the_bank = model.add_variables(
        all_gw, name='itb', vartype=so.continuous, lb=0)
    free_transfers = model.add_variables(
        all_gw, name='ft', vartype=so.integer, lb=1, ub=2)
    penalized_transfers = model.add_variables(
        gameweeks, name='pt', vartype=so.integer, lb=0)
    aux = model.add_variables(gameweeks, name='aux', vartype=so.binary)

    # Dictionaries
    lineup_type_count = {(t, w): so.expr_sum(
        lineup[p, w] for p in players if merged_data.loc[p, 'element_type'] == t) for t in element_types for w in gameweeks}
    squad_type_count = {(t, w): so.expr_sum(
        squad[p, w] for p in players if merged_data.loc[p, 'element_type'] == t) for t in element_types for w in gameweeks}
    player_type = merged_data['element_type'].to_dict()

    # player_price = (merged_data['now_cost'] / 10).to_dict()
    sell_price = (merged_data['SV']).to_dict()
    buy_price = (merged_data['BV']).to_dict()
    sold_amount = {w: so.expr_sum(
        sell_price[p] * transfer_out[p, w] for p in players) for w in gameweeks}
    bought_amount = {w: so.expr_sum(
        buy_price[p] * transfer_in[p, w] for p in players) for w in gameweeks}
    points_player_week = {
        (p, w): merged_data.loc[p, f'{w}_Pts'] for p in players for w in gameweeks}
    minutes_player_week = {
        (p, w): merged_data.loc[p, f'{w}_xMins'] for p in players for w in gameweeks}
    squad_count = {w: so.expr_sum(squad[p, w]
                                  for p in players) for w in gameweeks}
    number_of_transfers = {w: so.expr_sum(
        transfer_out[p, w] for p in players) for w in gameweeks}
    number_of_transfers[next_gw-1] = 1
    transfer_diff = {
        w: number_of_transfers[w] - free_transfers[w] for w in gameweeks}

    # Initial conditions
    model.add_constraints(
        (squad[p, next_gw-1] == 1 for p in initial_squad), name='initial_squad_players')
    model.add_constraints(
        (squad[p, next_gw-1] == 0 for p in players if p not in initial_squad), name='initial_squad_others')
    model.add_constraint(in_the_bank[next_gw-1] == itb, name='initial_itb')
    model.add_constraint(free_transfers[next_gw-1] == ft, name='initial_ft')

    # Constraints
    model.add_constraints(
        (squad_count[w] == 15 for w in gameweeks), name='squad_count')
    model.add_constraints((so.expr_sum(
        lineup[p, w] for p in players) == 11 for w in gameweeks), name='lineup_count')
    model.add_constraints((so.expr_sum(
        bench[p, w, 0] for p in players if player_type[p] == 1) == 1 for w in gameweeks), name='bench_gk')
    model.add_constraints((so.expr_sum(
        bench[p, w, o] for p in players) == 1 for w in gameweeks for o in [1, 2, 3]), name='bench_count')
    model.add_constraints((so.expr_sum(
        captain[p, w] for p in players) == 1 for w in gameweeks), name='captain_count')
    model.add_constraints((so.expr_sum(
        vicecap[p, w] for p in players) == 1 for w in gameweeks), name='vicecap_count')
    model.add_constraints((lineup[p, w] <= squad[p, w]
                          for p in players for w in gameweeks), name='lineup_squad_rel')
    model.add_constraints((bench[p, w, o] <= squad[p, w]
                          for p in players for w in gameweeks for o in order), name='bench_squad_rel')
    model.add_constraints((captain[p, w] <= lineup[p, w]
                          for p in players for w in gameweeks), name='captain_lineup_rel')
    model.add_constraints((vicecap[p, w] <= lineup[p, w]
                          for p in players for w in gameweeks), name='vicecap_lineup_rel')
    model.add_constraints((captain[p, w] + vicecap[p, w] <=
                          1 for p in players for w in gameweeks), name='cap_vc_rel')
    model.add_constraints((lineup[p, w] + so.expr_sum(bench[p, w, o] for o in order)
                          <= 1 for p in players for w in gameweeks), name='lineup_bench_rel')
    model.add_constraints((lineup_type_count[t, w] == [type_data.loc[t, 'squad_min_play'], type_data.loc[t,
                          'squad_max_play']] for t in element_types for w in gameweeks), name='valid_formation')
    model.add_constraints((squad_type_count[t, w] == type_data.loc[t, 'squad_select']
                          for t in element_types for w in gameweeks), name='valid_squad')
    model.add_constraints((so.expr_sum(squad[p, w] for p in players if merged_data.loc[p,
                          'name'] == t) <= 3 for t in teams for w in gameweeks), name='team_limit')

    # Transfer constraints
    model.add_constraints((squad[p, w] == squad[p, w-1] + transfer_in[p, w] - transfer_out[p, w]
                          for p in players for w in gameweeks), name='squad_transfer_rel')
    model.add_constraints((in_the_bank[w] == in_the_bank[w-1] + sold_amount[w] -
                          bought_amount[w] for w in gameweeks), name='cont_budget')

    # Free transfer constraints
    model.add_constraints(
        (free_transfers[w] == aux[w] + 1 for w in gameweeks), name='aux_ft_rel')
    model.add_constraints((free_transfers[w-1] - number_of_transfers[w-1]
                          <= 2 * aux[w] for w in gameweeks), name='force_aux_1')
    model.add_constraints((free_transfers[w-1] - number_of_transfers[w-1]
                          >= aux[w] + (-14)*(1-aux[w]) for w in gameweeks), name='force_aux_2')
    model.add_constraints(
        (penalized_transfers[w] >= transfer_diff[w] for w in gameweeks), name='pen_transfer_rel')

    # Objectives
    gw_xp = {w: so.expr_sum(points_player_week[p, w] * (lineup[p, w] + captain[p, w] + 0.1*vicecap[p, w] + so.expr_sum(
        bench_weights[o] * bench[p, w, o] for o in order)) for p in players) for w in gameweeks}
    gw_total = {w: gw_xp[w] - 4 * penalized_transfers[w] for w in gameweeks}
    if objective == 'regular':
        total_xp = so.expr_sum(gw_total[w] for w in gameweeks)
        model.set_objective(-total_xp, sense='N', name='total_regular_xp')
    else:
        decay_objective = so.expr_sum(
            gw_total[w] * pow(decay_base, w-next_gw) for w in gameweeks)
        model.set_objective(-decay_objective, sense='N', name='total_decay_xp')

    # Solve
    model.export_mps(f'{problem_name}.mps')
    command = f'cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/{problem_name}.mps solve solu {problem_name}_sol.txt'
    # add 'stdout=DEVNULL' for disabling logs
    process = Popen(command, shell=True)
    process.wait()

    # Parsing
    with open(f'{problem_name}_sol.txt', 'r') as f:
        for line in f:
            if 'objective value' in line:
                continue
            words = line.split()
            var = model.get_variable(words[1])
            var.set_value(float(words[2]))

    # DataFrame generation
    picks = []
    for w in gameweeks:
        for p in players:
            if squad[p, w].get_value() + transfer_out[p, w].get_value() > 0.5:
                lp = merged_data.loc[p]
                is_captain = 1 if captain[p, w].get_value() > 0.5 else 0
                is_lineup = 1 if lineup[p, w].get_value() > 0.5 else 0
                is_vice = 1 if vicecap[p, w].get_value() > 0.5 else 0
                is_transfer_in = 1 if transfer_in[p,
                                                  w].get_value() > 0.5 else 0
                is_transfer_out = 1 if transfer_out[p, w].get_value(
                ) > 0.5 else 0
                bench_value = -1
                for o in order:
                    if bench[p, w, o].get_value() > 0.5:
                        bench_value = o
                position = type_data.loc[lp['element_type'],
                                         'singular_name_short']
                picks.append([
                    w, lp['web_name'], position, lp['element_type'], lp['name'], buy_price[p], sell_price[p], round(
                        points_player_week[p, w], 2), minutes_player_week[p, w], is_lineup, bench_value, is_captain, is_vice, is_transfer_in, is_transfer_out
                ])

    picks_df = pd.DataFrame(picks, columns=['week', 'name', 'pos', 'type', 'team', 'buy_price', 'sell_price', 'xP', 'xMin', 'lineup', 'bench',
                            'captain', 'vicecaptain', 'transfer_in', 'transfer_out']).sort_values(by=['week', 'lineup', 'type', 'xP'], ascending=[True, False, True, True])
    total_xp = so.expr_sum((lineup[p, w] + captain[p, w]) * points_player_week[p, w]
                           for p in players for w in gameweeks).get_value()

    # Writing summary
    summary_of_actions = ""
    for w in gameweeks:
        summary_of_actions += f"** GW {w}:\n"
        summary_of_actions += f"ITB = {in_the_bank[w].get_value()}, FT={free_transfers[w].get_value()}, PT={penalized_transfers[w].get_value()}\n"
        for p in players:
            if transfer_in[p, w].get_value() > 0.5:
                summary_of_actions += f"Buy {p} - {merged_data['web_name'][p]}\n"
            if transfer_out[p, w].get_value() > 0.5:
                summary_of_actions += f"Sell {p} - {merged_data['web_name'][p]}\n"

    return {'model': model, 'picks': picks_df, 'total_xp': total_xp, 'summary': summary_of_actions}

# %%
def solve_standard_problem():
    r = solve_multi_period_fpl(
        team_id=2821496, gw=gw, ft=ft, horizon=8, objective='regular')
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular.csv')

# %%
def solve_autobench_problem():
    r = solve_multi_period_fpl(
        team_id=2821496, gw=gw, ft=ft, horizon=8, objective='regular')
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular_stage_1.csv')

    df = r['picks']
    lineup_gk = df[(df['week'] == 4) & (
        df['pos'] == 'GKP') & (df['lineup'] == 1)]
    lineup_gk = lineup_gk.iloc[0]
    lineup_gk_mins = lineup_gk['xMin']
    gk_autosub_prob = xmin_to_prob(lineup_gk_mins, sub_on=0, sub_off=0)
    gk_weight = 1-gk_autosub_prob

    field_players = df[(df['week'] == 4) & (
        df['pos'] != 'GKP') & (df['lineup'] == 1)]
    field_players_xmins = field_players['xMin'].tolist()
    field_players_probs = [xmin_to_prob(i) for i in field_players_xmins]

    prob = 1
    for i in field_players_probs:
        prob *= i
    bench_1_weight = 1 - prob

    bench_weights = {0: gk_weight, 1: bench_1_weight, 2: 0.06, 3: 0.002}
    r = solve_multi_period_fpl(team_id=2821496, gw=gw, ft=ft,
                               horizon=8, objective='regular', bench_weights=bench_weights)
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular_stage_2.csv')

# %%
def solve_randomized_problem():
    r = solve_multi_period_fpl(team_id=2821496, gw=gw, ft=ft,
                               horizon=8, objective='regular', seed=None, randomized=True)
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_randomized.csv')


if __name__ == '__main__':

    solve_standard_problem()  
    
    solve_randomized_problem()
# Out:
# NOTE: Initialized model mp_h8_regular.
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Nov  6 2022
#
# command line - cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/mp_h8_regular.mps solve solu mp_h8_regular_sol.txt (default strategy 1)
# At line 1 NAME    mp_h8_regular
# At line 2 ROWS
# At line 60760 COLUMNS
# At line 206488 RHS
# At line 212618 RANGES
# At line 212643 BOUNDS
# At line 273104 ENDATA
# Problem mp_h8_regular has 60756 rows, 60460 columns and 238680 elements
# Coin0008I mp_h8_regular read with 0 errors
# Continuous objective value is -539.731 - 5.26 seconds
# Cgl0002I 731 variables fixed
# Cgl0003I 0 fixed, 8 tightened bounds, 52069 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 28271 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 22325 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14704 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3825 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19 strengthened rows, 0 substitutions
# Cgl0004I processed model has 24166 rows, 58059 columns (58052 integer (58044 of which binary)) and 203297 elements
# Cbc0038I Initial state - 209 integers unsatisfied sum - 37.0977
# Cbc0038I Pass   1: (44.08 seconds) suminf.    7.58857 (62) obj. -519.504 iterations 8035
# Cbc0038I Pass   2: (44.10 seconds) suminf.    7.58857 (62) obj. -519.504 iterations 6
# Cbc0038I Pass   3: (44.45 seconds) suminf.    3.15552 (36) obj. -490.064 iterations 1833
# Cbc0038I Pass   4: (44.48 seconds) suminf.    3.15552 (36) obj. -490.064 iterations 46
# Cbc0038I Pass   5: (44.74 seconds) suminf.    0.00000 (0) obj. -440.895 iterations 1255
# Cbc0038I Solution found of -440.895
# Cbc0038I Relaxing continuous gives -440.895
# Cbc0038I Cleaned solution of -440.895
# Cbc0038I Before mini branch and bound, 57799 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 170 rows 147 columns
# Cbc0038I Mini branch and bound improved solution from -440.895 to -479.191 (44.89 seconds)
# Cbc0038I Round again with cutoff of -483.889
# Cbc0038I Pass   6: (44.92 seconds) suminf.    7.58857 (62) obj. -519.504 iterations 0
# Cbc0038I Pass   7: (44.94 seconds) suminf.    7.58857 (62) obj. -519.504 iterations 6
# Cbc0038I Pass   8: (45.35 seconds) suminf.    3.15552 (36) obj. -490.064 iterations 1966
# Cbc0038I Pass   9: (45.38 seconds) suminf.    3.15552 (36) obj. -490.064 iterations 73
# Cbc0038I Pass  10: (46.60 seconds) suminf.    3.47046 (30) obj. -483.889 iterations 5552
# Cbc0038I Pass  11: (46.64 seconds) suminf.    3.47046 (30) obj. -483.889 iterations 71
# Cbc0038I Pass  12: (47.56 seconds) suminf.    4.39184 (26) obj. -483.889 iterations 4279
# Cbc0038I Pass  13: (47.74 seconds) suminf.    4.21860 (28) obj. -483.889 iterations 925
# Cbc0038I Pass  14: (48.22 seconds) suminf.    2.85860 (18) obj. -483.889 iterations 2363
# Cbc0038I Pass  15: (48.56 seconds) suminf.    2.48881 (18) obj. -484.629 iterations 1694
# Cbc0038I Pass  16: (49.06 seconds) suminf.    2.23779 (14) obj. -483.889 iterations 2052
# Cbc0038I Pass  17: (49.16 seconds) suminf.    1.56059 (14) obj. -485.244 iterations 625
# Cbc0038I Pass  18: (49.60 seconds) suminf.    2.55391 (16) obj. -483.889 iterations 1908
# Cbc0038I Pass  19: (50.10 seconds) suminf.    1.56059 (14) obj. -485.244 iterations 4184
# Cbc0038I Pass  20: (50.45 seconds) suminf.    2.57639 (16) obj. -483.889 iterations 1814
# Cbc0038I Pass  21: (50.74 seconds) suminf.    2.57639 (16) obj. -483.889 iterations 1463
# Cbc0038I Pass  22: (51.08 seconds) suminf.    2.62945 (16) obj. -483.889 iterations 1638
# Cbc0038I Pass  23: (51.59 seconds) suminf.    1.56059 (14) obj. -485.347 iterations 3914
# Cbc0038I Pass  24: (51.73 seconds) suminf.    2.28929 (14) obj. -483.889 iterations 771
# Cbc0038I Pass  25: (51.96 seconds) suminf.    2.65364 (16) obj. -483.889 iterations 1030
# Cbc0038I Pass  26: (52.22 seconds) suminf.    2.62935 (17) obj. -483.889 iterations 1305
# Cbc0038I Pass  27: (52.50 seconds) suminf.    2.62936 (16) obj. -483.889 iterations 1424
# Cbc0038I Pass  28: (52.78 seconds) suminf.    2.62945 (16) obj. -483.889 iterations 1493
# Cbc0038I Pass  29: (53.03 seconds) suminf.    2.63087 (16) obj. -483.889 iterations 1357
# Cbc0038I Pass  30: (53.40 seconds) suminf.    2.63522 (22) obj. -483.889 iterations 2233
# Cbc0038I Pass  31: (53.75 seconds) suminf.    1.56059 (14) obj. -485.158 iterations 2660
# Cbc0038I Pass  32: (53.87 seconds) suminf.    2.19504 (14) obj. -483.889 iterations 684
# Cbc0038I Pass  33: (54.08 seconds) suminf.    2.47206 (16) obj. -483.889 iterations 1027
# Cbc0038I Pass  34: (54.68 seconds) suminf.    1.56059 (14) obj. -485.132 iterations 4924
# Cbc0038I Pass  35: (54.80 seconds) suminf.    2.18204 (14) obj. -483.889 iterations 583
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 57748 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 190 rows 172 columns
# Cbc0038I Mini branch and bound did not improve solution (54.86 seconds)
# Cbc0038I After 54.86 seconds - Feasibility pump exiting with objective of -479.191 - took 12.56 seconds
# Cbc0012I Integer solution of -479.19054 found by feasibility pump after 0 iterations and 0 nodes (54.87 seconds)
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 149 rows 123 columns
# Cbc0031I 13 added rows had average density of 1002.9231
# Cbc0013I At root node, 13 cuts changed objective from -526.17967 to -513.65468 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.100 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 6 row cuts average 749.0 elements, 0 column cuts (0 active)  in 0.195 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.094 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 34 row cuts average 1292.0 elements, 0 column cuts (0 active)  in 0.037 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 2 row cuts average 746.0 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 5 row cuts average 749.0 elements, 0 column cuts (0 active)  in 1.133 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -479.19054 best solution, best possible -513.65468 (62.30 seconds)
# Cbc0004I Integer solution of -504.59246 found after 37070 iterations and 36 nodes (102.06 seconds)
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 95 rows 81 columns
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 45 rows 37 columns
# Cbc0010I After 100 nodes, 22 on tree, -504.59246 best solution, best possible -513.65468 (111.93 seconds)
# Cbc0004I Integer solution of -504.67306 found after 49749 iterations and 101 nodes (111.95 seconds)
# Cbc0004I Integer solution of -505.46566 found after 72070 iterations and 156 nodes (130.55 seconds)
# Cbc0004I Integer solution of -505.50966 found after 72182 iterations and 162 nodes (131.10 seconds)
# Cbc0004I Integer solution of -505.51476 found after 72679 iterations and 173 nodes (131.20 seconds)
# Cbc0004I Integer solution of -505.91536 found after 72704 iterations and 177 nodes (131.72 seconds)
# Cbc0010I After 200 nodes, 31 on tree, -505.91536 best solution, best possible -513.65468 (138.62 seconds)
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 36 rows 30 columns
# Cbc0010I After 300 nodes, 38 on tree, -505.91536 best solution, best possible -513.65468 (166.49 seconds)
# Cbc0004I Integer solution of -506.21006 found after 116838 iterations and 337 nodes (167.92 seconds)
# Cbc0004I Integer solution of -506.27058 found after 130433 iterations and 394 nodes (177.08 seconds)
# Cbc0010I After 400 nodes, 33 on tree, -506.27058 best solution, best possible -513.65468 (178.15 seconds)
# Cbc0004I Integer solution of -506.64298 found after 169176 iterations and 497 nodes (204.48 seconds)
# Cbc0010I After 500 nodes, 41 on tree, -506.64298 best solution, best possible -513.65468 (204.53 seconds)
# Cbc0010I After 600 nodes, 41 on tree, -506.64298 best solution, best possible -513.65468 (219.57 seconds)
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 77 rows 62 columns
# Cbc0004I Integer solution of -506.64358 found after 204173 iterations and 604 nodes (221.15 seconds)
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 199 rows 184 columns
# Cbc0010I After 700 nodes, 51 on tree, -506.64358 best solution, best possible -513.65468 (241.14 seconds)
# Cbc0010I After 800 nodes, 57 on tree, -506.64358 best solution, best possible -513.65468 (255.06 seconds)
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 199 rows 181 columns
# Cbc0010I After 900 nodes, 62 on tree, -506.64358 best solution, best possible -513.65468 (267.44 seconds)
# Cbc0010I After 1000 nodes, 59 on tree, -506.64358 best solution, best possible -513.65468 (278.54 seconds)
# Cbc0010I After 1100 nodes, 62 on tree, -506.64358 best solution, best possible -513.65468 (292.81 seconds)
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 225 rows 200 columns
# Cbc0010I After 1200 nodes, 66 on tree, -506.64358 best solution, best possible -513.65468 (305.99 seconds)
# Cbc0004I Integer solution of -506.70908 found after 366675 iterations and 1246 nodes (312.20 seconds)
# Cbc0010I After 1300 nodes, 62 on tree, -506.70908 best solution, best possible -513.65468 (320.43 seconds)
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 196 rows 161 columns
# Cbc0010I After 1400 nodes, 64 on tree, -506.70908 best solution, best possible -513.65468 (326.81 seconds)
# Cbc0010I After 1500 nodes, 73 on tree, -506.70908 best solution, best possible -513.65468 (336.36 seconds)
# Cbc0004I Integer solution of -506.78798 found after 396336 iterations and 1511 nodes (336.93 seconds)
# Cbc0010I After 1600 nodes, 66 on tree, -506.78798 best solution, best possible -513.65468 (351.94 seconds)
# Cbc0010I After 1700 nodes, 72 on tree, -506.78798 best solution, best possible -513.65468 (364.40 seconds)
# Cbc0004I Integer solution of -506.84108 found after 442667 iterations and 1748 nodes (365.71 seconds)
# Cbc0004I Integer solution of -507.06948 found after 443058 iterations and 1768 nodes (366.84 seconds)
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 203 rows 180 columns
# Cbc0010I After 1800 nodes, 39 on tree, -507.06948 best solution, best possible -513.65468 (370.22 seconds)
# Cbc0010I After 1900 nodes, 38 on tree, -507.06948 best solution, best possible -513.65468 (379.18 seconds)
# Cbc0010I After 2000 nodes, 33 on tree, -507.06948 best solution, best possible -513.65468 (394.10 seconds)
# Cbc0004I Integer solution of -507.08498 found after 513887 iterations and 2021 nodes (396.73 seconds)
# Cbc0004I Integer solution of -507.08544 found after 514997 iterations and 2034 nodes (397.60 seconds)
# Cbc0010I After 2100 nodes, 32 on tree, -507.08544 best solution, best possible -513.65468 (404.12 seconds)
# Cbc0010I After 2200 nodes, 30 on tree, -507.08544 best solution, best possible -513.65468 (412.21 seconds)
# Cbc0010I After 2300 nodes, 26 on tree, -507.08544 best solution, best possible -513.65468 (425.93 seconds)
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 181 rows 159 columns
# Cbc0010I After 2400 nodes, 14 on tree, -507.08544 best solution, best possible -513.65468 (438.24 seconds)
# Cbc0010I After 2500 nodes, 11 on tree, -507.08544 best solution, best possible -513.65468 (449.46 seconds)
# Cbc0010I After 2600 nodes, 8 on tree, -507.08544 best solution, best possible -513.65468 (462.11 seconds)
# Cbc0004I Integer solution of -507.19862 found after 643750 iterations and 2634 nodes (468.02 seconds)
# Cbc0010I After 2700 nodes, 12 on tree, -507.19862 best solution, best possible -513.65468 (473.09 seconds)
# Cbc0004I Integer solution of -507.97082 found after 663707 iterations and 2703 nodes (474.26 seconds)
# Cbc0010I After 2800 nodes, 6 on tree, -507.97082 best solution, best possible -513.65468 (492.09 seconds)
# Cbc0010I After 2900 nodes, 29 on tree, -507.97082 best solution, best possible -513.45483 (518.67 seconds)
# Cbc0010I After 3000 nodes, 28 on tree, -507.97082 best solution, best possible -513.45483 (527.27 seconds)
# Cbc0010I After 3100 nodes, 34 on tree, -507.97082 best solution, best possible -513.45483 (539.48 seconds)
# Cbc0010I After 3200 nodes, 33 on tree, -507.97082 best solution, best possible -513.45483 (546.81 seconds)
# Cbc0010I After 3300 nodes, 43 on tree, -507.97082 best solution, best possible -513.45483 (559.84 seconds)
# Cbc0010I After 3400 nodes, 32 on tree, -507.97082 best solution, best possible -513.45483 (562.82 seconds)
# Cbc0010I After 3500 nodes, 30 on tree, -507.97082 best solution, best possible -513.45483 (571.47 seconds)
# Cbc0010I After 3600 nodes, 29 on tree, -507.97082 best solution, best possible -513.45483 (579.13 seconds)
# Cbc0038I Full problem 24166 rows 58059 columns, reduced to 185 rows 160 columns
# Cbc0010I After 3700 nodes, 25 on tree, -507.97082 best solution, best possible -513.45483 (585.88 seconds)
# Cbc0010I After 3800 nodes, 20 on tree, -507.97082 best solution, best possible -513.45483 (592.52 seconds)
# Cbc0010I After 3900 nodes, 9 on tree, -507.97082 best solution, best possible -513.45483 (600.61 seconds)
# Cbc0010I After 4000 nodes, 6 on tree, -507.97082 best solution, best possible -513.45483 (611.90 seconds)
# Cbc0010I After 4100 nodes, 8 on tree, -507.97082 best solution, best possible -513.45483 (620.78 seconds)
# Cbc0001I Search completed - best objective -507.9708199999999, took 913883 iterations and 4195 nodes (638.39 seconds)
# Cbc0032I Strong branching done 6104 times (56823 iterations), fathomed 30 nodes and fixed 22 variables
# Cbc0035I Maximum depth 31, 2691831 variables fixed on reduced cost
# Cuts at root node changed objective from -526.18 to -513.655
# Probing was tried 961 times and created 950 cuts of which 0 were active after adding rounds of cuts (2.342 seconds)
# Gomory was tried 4 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.195 seconds)
# Knapsack was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.094 seconds)
# Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 961 times and created 5546 cuts of which 0 were active after adding rounds of cuts (4.740 seconds)
# FlowCover was tried 961 times and created 221 cuts of which 0 were active after adding rounds of cuts (1.457 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.099 seconds)
# ZeroHalf was tried 961 times and created 38 cuts of which 0 were active after adding rounds of cuts (260.003 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -507.97082000
# Enumerated nodes:               4195
# Total iterations:               913883
# Time (CPU seconds):             638.61
# Time (Wallclock seconds):       653.11
#
# Total time (CPU seconds):       638.72   (Wallclock seconds):       653.23
#
#      week              name  pos  type       team  buy_price  sell_price  \
# 5      25          Pickford  GKP     1    Everton        4.4         4.4
# 12     25               Aké  DEF     2   Man City        5.1         5.0
# 2      25           Gabriel  DEF     2    Arsenal        5.2         5.2
# 9      25  Alexander-Arnold  DEF     2  Liverpool        7.3         7.2
# 7      25           Andreas  MID     3     Fulham        4.4         4.4
# ..    ...               ...  ...   ...        ...        ...         ...
# 130    32              Burn  DEF     2  Newcastle        4.6         4.6
# 120    32      Mac Allister  MID     3   Brighton        5.4         5.4
# 121    32            Mitoma  MID     3   Brighton        5.4         5.2
# 128    32          Rashford  MID     3    Man Utd        7.3         6.9
# 127    32           Haaland  FWD     4   Man City       12.2        11.9
#
#        xP  xMin  lineup  bench  captain  vicecaptain  transfer_in  \
# 5    7.02    89       1     -1        0            0            1
# 12   3.07    58       1     -1        0            0            0
# 2    8.66    84       1     -1        0            0            0
# 9    9.91    86       1     -1        0            0            0
# 7    3.90    80       1     -1        0            0            0
# ..    ...   ...     ...    ...      ...          ...          ...
# 130  2.19    76       0      2        0            0            0
# 120  0.92    72       0     -1        0            0            0
# 121  0.93    68       0      3        0            0            0
# 128  2.21    73       0      1        0            0            0
# 127  0.74    71       0     -1        0            0            0
#
#      transfer_out
# 5               0
# 12              0
# 2               0
# 9               0
# 7               0
# ..            ...
# 130             0
# 120             1
# 121             0
# 128             0
# 127             1
#
# [131 rows x 15 columns]
# ** GW 25:
# ITB = 0, FT=1.0, PT=2.0
# Buy 182 - Pickford
# Buy 534 - McNeil
# Buy 283 - Salah
# Sell 307 - Ederson
# Sell 333 - Fernandes
# Sell 335 - Rashford
# ** GW 26:
# ITB = 0.5, FT=1.0, PT=1.0
# Buy 40 - Watkins
# Buy 116 - Mac Allister
# Sell 346 - Andreas
# Sell 297 - Darwin
# ** GW 27:
# ITB = 0.9, FT=1.0, PT=0
# Sell 308 - Aké
# Buy 358 - Burn
# ** GW 28:
# ITB = 2.2, FT=1.0, PT=0
# Sell 11 - Nketiah
# Buy 66 - Solanke
# ** GW 29:
# ITB = 0, FT=1.0, PT=0
# Sell 534 - McNeil
# Buy 335 - Rashford
# ** GW 30:
# ITB = 0, FT=1.0, PT=0
# ** GW 31:
# ITB = 0, FT=2.0, PT=0
# Buy 526 - Mee
# Sell 332 - Shaw
# ** GW 32:
# ITB = 1.4, FT=2.0, PT=0
# Sell 116 - Mac Allister
# Buy 160 - Zaha
# Buy 297 - Darwin
# Sell 318 - Haaland
#
# NOTE: Initialized model mp_h8_regular.
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Nov  6 2022
#
# command line - cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/mp_h8_regular.mps solve solu mp_h8_regular_sol.txt (default strategy 1)
# At line 1 NAME    mp_h8_regular
# At line 2 ROWS
# At line 60760 COLUMNS
# At line 206488 RHS
# At line 212618 RANGES
# At line 212643 BOUNDS
# At line 273104 ENDATA
# Problem mp_h8_regular has 60756 rows, 60460 columns and 238680 elements
# Coin0008I mp_h8_regular read with 0 errors
# Continuous objective value is -564.948 - 5.11 seconds
# Cgl0002I 731 variables fixed
# Cgl0003I 0 fixed, 8 tightened bounds, 51967 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 28160 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 22239 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14511 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3707 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0004I processed model has 24164 rows, 57957 columns (57950 integer (57942 of which binary)) and 203040 elements
# Cbc0038I Initial state - 264 integers unsatisfied sum - 59.4517
# Cbc0038I Pass   1: (50.48 seconds) suminf.    8.12425 (72) obj. -534.541 iterations 13045
# Cbc0038I Pass   2: (51.36 seconds) suminf.    1.99943 (35) obj. -533.239 iterations 2528
# Cbc0038I Pass   3: (51.84 seconds) suminf.    1.00000 (3) obj. -482.181 iterations 1167
# Cbc0038I Pass   4: (51.94 seconds) suminf.    0.00000 (0) obj. -483.514 iterations 309
# Cbc0038I Solution found of -483.514
# Cbc0038I Relaxing continuous gives -483.514
# Cbc0038I Cleaned solution of -483.514
# Cbc0038I Before mini branch and bound, 57632 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 24164 rows 57957 columns, reduced to 212 rows 195 columns
# Cbc0038I Mini branch and bound improved solution from -483.514 to -519.652 (52.24 seconds)
# Cbc0038I Round again with cutoff of -522.695
# Cbc0038I Pass   5: (52.27 seconds) suminf.    8.12425 (72) obj. -534.541 iterations 0
# Cbc0038I Pass   6: (54.95 seconds) suminf.    2.07830 (1761) obj. -533.251 iterations 11324
# Cbc0038I Pass   7: (60.35 seconds) suminf.    9.11678 (614) obj. -522.695 iterations 16254
# Cbc0038I Pass   8: (60.53 seconds) suminf.    9.09965 (32) obj. -522.695 iterations 358
# Cbc0038I Pass   9: (72.76 seconds) suminf.    2.06506 (7417) obj. -522.695 iterations 28524
# Cbc0038I No solution found this major pass
# Cbc0038I After 72.76 seconds - Feasibility pump exiting with objective of -519.652 - took 26.80 seconds
# Cbc0012I Integer solution of -519.65181 found by feasibility pump after 0 iterations and 0 nodes (72.77 seconds)
# Cbc0038I Full problem 24164 rows 57957 columns, reduced to 164 rows 137 columns
# Cbc0031I 20 added rows had average density of 867.15
# Cbc0013I At root node, 20 cuts changed objective from -550.07895 to -531.37751 in 5 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 4.0 elements, 1054 column cuts (1054 active)  in 0.844 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 6 row cuts average 749.0 elements, 0 column cuts (0 active)  in 0.333 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 2 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.116 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 26 row cuts average 1180.2 elements, 0 column cuts (0 active)  in 0.044 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 746.0 elements, 0 column cuts (0 active)  in 0.037 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 8 row cuts average 387.4 elements, 0 column cuts (0 active)  in 1.569 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -519.65181 best solution, best possible -531.37751 (84.47 seconds)
# Cbc0038I Full problem 24164 rows 57957 columns, reduced to 82 rows 60 columns
# Cbc0004I Integer solution of -524.94229 found after 40945 iterations and 56 nodes (128.50 seconds)
# Cbc0004I Integer solution of -525.91329 found after 42259 iterations and 58 nodes (129.54 seconds)
# Cbc0038I Full problem 24164 rows 57957 columns, reduced to 24 rows 17 columns
# Cbc0010I After 100 nodes, 32 on tree, -525.91329 best solution, best possible -531.37751 (138.98 seconds)
# Cbc0004I Integer solution of -527.13748 found after 64253 iterations and 110 nodes (141.52 seconds)
# Cbc0004I Integer solution of -527.83484 found after 74117 iterations and 134 nodes (146.39 seconds)
# Cbc0004I Integer solution of -527.95805 found after 82483 iterations and 149 nodes (151.14 seconds)
# Cbc0004I Integer solution of -527.97241 found after 85471 iterations and 159 nodes (152.51 seconds)
# Cbc0004I Integer solution of -529.5369 found after 112342 iterations and 188 nodes (161.06 seconds)
# Cbc0004I Integer solution of -529.55793 found after 112387 iterations and 190 nodes (161.63 seconds)
# Cbc0004I Integer solution of -529.74784 found after 112428 iterations and 191 nodes (161.65 seconds)
# Cbc0010I After 200 nodes, 22 on tree, -529.74784 best solution, best possible -531.37751 (163.55 seconds)
# Cbc0038I Full problem 24164 rows 57957 columns, reduced to 132 rows 114 columns
# Cbc0004I Integer solution of -529.86526 found after 143321 iterations and 297 nodes (178.36 seconds)
# Cbc0010I After 300 nodes, 15 on tree, -529.86526 best solution, best possible -531.37751 (178.71 seconds)
# Cbc0004I Integer solution of -530.05134 found after 143763 iterations and 303 nodes (178.75 seconds)
# Cbc0004I Integer solution of -530.0753 found after 143775 iterations and 304 nodes (178.77 seconds)
# Cbc0004I Integer solution of -530.07745 found after 143975 iterations and 308 nodes (179.40 seconds)
# Cbc0038I Full problem 24164 rows 57957 columns, reduced to 178 rows 151 columns
# Cbc0010I After 400 nodes, 5 on tree, -530.07745 best solution, best possible -531.37751 (196.49 seconds)
# Cbc0004I Integer solution of -530.21217 found after 170007 iterations and 447 nodes (209.04 seconds)
# Cbc0004I Integer solution of -530.45505 found after 170220 iterations and 450 nodes (209.33 seconds)
# Cbc0001I Search completed - best objective -530.4550515868997, took 171247 iterations and 460 nodes (211.68 seconds)
# Cbc0032I Strong branching done 1788 times (18308 iterations), fathomed 5 nodes and fixed 3 variables
# Cbc0035I Maximum depth 34, 694945 variables fixed on reduced cost
# Cuts at root node changed objective from -550.079 to -531.378
# Probing was tried 147 times and created 1229 cuts of which 0 were active after adding rounds of cuts (1.310 seconds)
# Gomory was tried 5 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.333 seconds)
# Knapsack was tried 147 times and created 37 cuts of which 0 were active after adding rounds of cuts (3.414 seconds)
# Clique was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 147 times and created 611 cuts of which 0 were active after adding rounds of cuts (0.742 seconds)
# FlowCover was tried 5 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.037 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.120 seconds)
# ZeroHalf was tried 147 times and created 11 cuts of which 0 were active after adding rounds of cuts (40.970 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -530.45505159
# Enumerated nodes:               460
# Total iterations:               171247
# Time (CPU seconds):             212.12
# Time (Wallclock seconds):       217.36
#
# Total time (CPU seconds):       212.25   (Wallclock seconds):       217.51
#
#      week              name  pos  type       team  buy_price  sell_price  \
# 6      25          Pickford  GKP     1    Everton        4.4         4.4
# 7      25         Mykolenko  DEF     2    Everton        4.3         4.3
# 3      25           Gabriel  DEF     2    Arsenal        5.2         5.2
# 10     25  Alexander-Arnold  DEF     2  Liverpool        7.3         7.2
# 8      25           Andreas  MID     3     Fulham        4.4         4.4
# ..    ...               ...  ...   ...        ...        ...         ...
# 123    32         Estupiñán  DEF     2   Brighton        4.7         4.7
# 130    32              Shaw  DEF     2    Man Utd        5.3         5.0
# 122    32      Mac Allister  MID     3   Brighton        5.4         5.4
# 124    32        João Félix  FWD     4    Chelsea        7.6         7.6
# 133    32              Kane  FWD     4      Spurs       11.8        11.8
#
#         xP  xMin  lineup  bench  captain  vicecaptain  transfer_in  \
# 6     7.02    89       1     -1        0            0            1
# 7     5.50    74       1     -1        0            0            1
# 3     8.70    84       1     -1        0            0            0
# 10   10.25    86       1     -1        0            0            0
# 8     3.89    80       1     -1        0            0            0
# ..     ...   ...     ...    ...      ...          ...          ...
# 123   0.59    72       0     -1        0            0            0
# 130   1.38    72       0      2        0            0            0
# 122   1.00    72       0      3        0            0            0
# 124   1.53    68       0      1        0            0            0
# 133   1.90    78       0     -1        0            0            0
#
#      transfer_out
# 6               0
# 7               0
# 3               0
# 10              0
# 8               0
# ..            ...
# 123             1
# 130             0
# 122             0
# 124             0
# 133             1
#
# [134 rows x 15 columns]
# ** GW 25:
# ITB = 0.1, FT=1.0, PT=4.0
# Buy 7 - Ødegaard
# Sell 11 - Nketiah
# Buy 182 - Pickford
# Buy 194 - Mykolenko
# Buy 283 - Salah
# Sell 307 - Ederson
# Sell 308 - Aké
# Sell 333 - Fernandes
# Sell 335 - Rashford
# Buy 732 - Onuachu
# ** GW 26:
# ITB = 0.2, FT=1.0, PT=1.0
# Buy 116 - Mac Allister
# Buy 690 - João Félix
# Sell 346 - Andreas
# Sell 297 - Darwin
# ** GW 27:
# ITB = 0.2, FT=1.0, PT=0
# ** GW 28:
# ITB = 0, FT=2.0, PT=1.0
# Buy 40 - Watkins
# Buy 42 - Buendía
# Sell 124 - Mitoma
# Sell 285 - Alexander-Arnold
# Buy 366 - Schär
# Sell 732 - Onuachu
# ** GW 29:
# ITB = 0.5, FT=1.0, PT=0
# Sell 16 - Gabriel
# Buy 586 - Estupiñán
# ** GW 30:
# ITB = 0.5, FT=1.0, PT=0
# ** GW 31:
# ITB = 0.6, FT=2.0, PT=0
# Sell 318 - Haaland
# Buy 427 - Kane
# ** GW 32:
# ITB = 1.1, FT=2.0, PT=0
# Sell 586 - Estupiñán
# Buy 285 - Alexander-Arnold
# Buy 297 - Darwin
# Sell 427 - Kane

# %%
sjekk =pd.read_csv("../output/optimal_plan_regular.csv")

# %%
sjekk
# Out:
#      Unnamed: 0  week              name  pos  type       team  buy_price  \
# 0             5    25          Pickford  GKP     1    Everton        4.4
# 1            12    25               Aké  DEF     2   Man City        5.1
# 2             2    25           Gabriel  DEF     2    Arsenal        5.2
# 3             9    25  Alexander-Arnold  DEF     2  Liverpool        7.3
# 4             7    25           Andreas  MID     3     Fulham        4.4
# ..          ...   ...               ...  ...   ...        ...        ...
# 126         130    32              Burn  DEF     2  Newcastle        4.6
# 127         120    32      Mac Allister  MID     3   Brighton        5.4
# 128         121    32            Mitoma  MID     3   Brighton        5.4
# 129         128    32          Rashford  MID     3    Man Utd        7.3
# 130         127    32           Haaland  FWD     4   Man City       12.2
#
#      sell_price    xP  xMin  lineup  bench  captain  vicecaptain  transfer_in  \
# 0           4.4  7.02    89       1     -1        0            0            1
# 1           5.0  3.07    58       1     -1        0            0            0
# 2           5.2  8.66    84       1     -1        0            0            0
# 3           7.2  9.91    86       1     -1        0            0            0
# 4           4.4  3.90    80       1     -1        0            0            0
# ..          ...   ...   ...     ...    ...      ...          ...          ...
# 126         4.6  2.19    76       0      2        0            0            0
# 127         5.4  0.92    72       0     -1        0            0            0
# 128         5.2  0.93    68       0      3        0            0            0
# 129         6.9  2.21    73       0      1        0            0            0
# 130        11.9  0.74    71       0     -1        0            0            0
#
#      transfer_out
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 126             0
# 127             1
# 128             0
# 129             0
# 130             1
#
# [131 rows x 16 columns]
