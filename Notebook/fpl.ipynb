# %%
import pandas as pd
import numpy as np
import sasoptpy as so
import requests
import os

import time
from subprocess import Popen, DEVNULL
gw = 34
ft=1
horizon = 5

# %%
def xmin_to_prob(xmin, sub_on=0.5, sub_off=0.3):
    start = min(max((xmin - 25 * sub_on) / (90 * (1-sub_off) +
                65 * sub_off - 25 * sub_on), 0.001), 0.999)
    return start + (1-start) * sub_on

# %%
def get_data(team_id, gw, seed_val, horizon, randomized):
    r = requests.get('https://fantasy.premierleague.com/api/bootstrap-static/')
    fpl_data = r.json()
    element_data = pd.DataFrame(fpl_data['elements'])
    team_data = pd.DataFrame(fpl_data['teams'])
    elements_team = pd.merge(element_data, team_data,
                             left_on='team', right_on='id')
    review_data = pd.read_csv('../Data/fplreview.csv')
    review_data = review_data.fillna(0)
    review_data['review_id'] = review_data.index+1
    merged_data = pd.merge(elements_team, review_data,
                           left_on='id_x', right_on='review_id')
    merged_data.set_index(['id_x'], inplace=True)

    if randomized:
        rng = np.random.default_rng(seed=seed_val)
        gws = list(range(gw+1, min(39, gw+1+horizon)))
        for w in gws:
            noise = merged_data[f"{w}_Pts"] * (
                92 - merged_data[f"{w}_xMins"]) / 134 * rng.standard_normal(size=len(merged_data))
            merged_data[f"{w}_Pts"] = merged_data[f"{w}_Pts"] + noise

    next_gw = int(review_data.keys()[6].split('_')[0])
    type_data = pd.DataFrame(fpl_data['element_types']).set_index(['id'])

    r = requests.get(
        f'https://fantasy.premierleague.com/api/entry/{team_id}/event/{gw}/picks/')
    picks_data = r.json()
    initial_squad = [i['element'] for i in picks_data['picks']]
    r = requests.get(f'https://fantasy.premierleague.com/api/entry/{team_id}/')
    general_data = r.json()
    itb = general_data['last_deadline_bank'] / 10

    return {'merged_data': merged_data, 'team_data': team_data, 'type_data': type_data, 'next_gw': next_gw, 'initial_squad': initial_squad, 'itb': itb}

# %%
# review_data = pd.read_csv('../Data/xp_points.csv')
# next_gw = int(review_data.keys()[6].split('_')[0])
# next_gw

# %%
def solve_multi_period_fpl(team_id, gw, ft, horizon, objective='regular', decay_base=0.85, bench_weights=None, seed=None, randomized=False):
    """
    Solves multi-objective FPL problem with transfers
    Parameters
    ----------
    team_id: integer
        FPL ID of the team to be optimized
    gw: integer
        Upcoming (next) gameweek
    ft: integer
        Number of available free transfers (currently)
    horizon: integer
        Number of weeks to consider in optimization
    objective: string
        Type of objective "regular" or "decay"
    decay_base: float
        Base for the decay function
    """

    # Data
    problem_name = f'mp_h{horizon}_regular' if objective == 'regular' else f'mp_h{horizon}_o{objective[0]}_d{decay_base}'
    data = get_data(team_id, gw-1, seed, horizon, randomized)
    merged_data = data['merged_data']
    team_data = data['team_data']
    type_data = data['type_data']
    next_gw = data['next_gw']
    initial_squad = data['initial_squad']
    itb = data['itb']

    # Sets
    players = merged_data.index.to_list()
    element_types = type_data.index.to_list()
    teams = team_data['name'].to_list()
    gameweeks = list(range(next_gw, next_gw+horizon))
    all_gw = [next_gw-1] + gameweeks
    order = [0, 1, 2, 3]
    if bench_weights is None:
        bench_weights = {0: 0.03, 1: 0.21, 2: 0.06, 3: 0.002}

    # Model
    model = so.Model(name=problem_name)

    # Variables
    squad = model.add_variables(
        players, all_gw, name='squad', vartype=so.binary)
    lineup = model.add_variables(
        players, gameweeks, name='lineup', vartype=so.binary)
    captain = model.add_variables(
        players, gameweeks, name='captain', vartype=so.binary)
    vicecap = model.add_variables(
        players, gameweeks, name='vicecap', vartype=so.binary)
    bench = model.add_variables(
        players, gameweeks, order, name='bench', vartype=so.binary)
    transfer_in = model.add_variables(
        players, gameweeks, name='transfer_in', vartype=so.binary)
    transfer_out = model.add_variables(
        players, gameweeks, name='transfer_out', vartype=so.binary)
    in_the_bank = model.add_variables(
        all_gw, name='itb', vartype=so.continuous, lb=0)
    free_transfers = model.add_variables(
        all_gw, name='ft', vartype=so.integer, lb=1, ub=2)
    penalized_transfers = model.add_variables(
        gameweeks, name='pt', vartype=so.integer, lb=0)
    aux = model.add_variables(gameweeks, name='aux', vartype=so.binary)

    # Dictionaries
    lineup_type_count = {(t, w): so.expr_sum(
        lineup[p, w] for p in players if merged_data.loc[p, 'element_type'] == t) for t in element_types for w in gameweeks}
    squad_type_count = {(t, w): so.expr_sum(
        squad[p, w] for p in players if merged_data.loc[p, 'element_type'] == t) for t in element_types for w in gameweeks}
    player_type = merged_data['element_type'].to_dict()

    # player_price = (merged_data['now_cost'] / 10).to_dict()
    sell_price = (merged_data['SV']).to_dict()
    buy_price = (merged_data['BV']).to_dict()
    sold_amount = {w: so.expr_sum(
        sell_price[p] * transfer_out[p, w] for p in players) for w in gameweeks}
    bought_amount = {w: so.expr_sum(
        buy_price[p] * transfer_in[p, w] for p in players) for w in gameweeks}
    points_player_week = {
        (p, w): merged_data.loc[p, f'{w}_Pts'] for p in players for w in gameweeks}
    minutes_player_week = {
        (p, w): merged_data.loc[p, f'{w}_xMins'] for p in players for w in gameweeks}
    squad_count = {w: so.expr_sum(squad[p, w]
                                  for p in players) for w in gameweeks}
    number_of_transfers = {w: so.expr_sum(
        transfer_out[p, w] for p in players) for w in gameweeks}
    number_of_transfers[next_gw-1] = 1
    transfer_diff = {
        w: number_of_transfers[w] - free_transfers[w] for w in gameweeks}

    # Initial conditions
    model.add_constraints(
        (squad[p, next_gw-1] == 1 for p in initial_squad), name='initial_squad_players')
    model.add_constraints(
        (squad[p, next_gw-1] == 0 for p in players if p not in initial_squad), name='initial_squad_others')
    model.add_constraint(in_the_bank[next_gw-1] == itb, name='initial_itb')
    model.add_constraint(free_transfers[next_gw-1] == ft, name='initial_ft')

    # Constraints
    model.add_constraints(
        (squad_count[w] == 15 for w in gameweeks), name='squad_count')
    model.add_constraints((so.expr_sum(
        lineup[p, w] for p in players) == 11 for w in gameweeks), name='lineup_count')
    model.add_constraints((so.expr_sum(
        bench[p, w, 0] for p in players if player_type[p] == 1) == 1 for w in gameweeks), name='bench_gk')
    model.add_constraints((so.expr_sum(
        bench[p, w, o] for p in players) == 1 for w in gameweeks for o in [1, 2, 3]), name='bench_count')
    model.add_constraints((so.expr_sum(
        captain[p, w] for p in players) == 1 for w in gameweeks), name='captain_count')
    model.add_constraints((so.expr_sum(
        vicecap[p, w] for p in players) == 1 for w in gameweeks), name='vicecap_count')
    model.add_constraints((lineup[p, w] <= squad[p, w]
                          for p in players for w in gameweeks), name='lineup_squad_rel')
    model.add_constraints((bench[p, w, o] <= squad[p, w]
                          for p in players for w in gameweeks for o in order), name='bench_squad_rel')
    model.add_constraints((captain[p, w] <= lineup[p, w]
                          for p in players for w in gameweeks), name='captain_lineup_rel')
    model.add_constraints((vicecap[p, w] <= lineup[p, w]
                          for p in players for w in gameweeks), name='vicecap_lineup_rel')
    model.add_constraints((captain[p, w] + vicecap[p, w] <=
                          1 for p in players for w in gameweeks), name='cap_vc_rel')
    model.add_constraints((lineup[p, w] + so.expr_sum(bench[p, w, o] for o in order)
                          <= 1 for p in players for w in gameweeks), name='lineup_bench_rel')
    model.add_constraints((lineup_type_count[t, w] == [type_data.loc[t, 'squad_min_play'], type_data.loc[t,
                          'squad_max_play']] for t in element_types for w in gameweeks), name='valid_formation')
    model.add_constraints((squad_type_count[t, w] == type_data.loc[t, 'squad_select']
                          for t in element_types for w in gameweeks), name='valid_squad')
    model.add_constraints((so.expr_sum(squad[p, w] for p in players if merged_data.loc[p,
                          'name'] == t) <= 3 for t in teams for w in gameweeks), name='team_limit')

    # Transfer constraints
    model.add_constraints((squad[p, w] == squad[p, w-1] + transfer_in[p, w] - transfer_out[p, w]
                          for p in players for w in gameweeks), name='squad_transfer_rel')
    model.add_constraints((in_the_bank[w] == in_the_bank[w-1] + sold_amount[w] -
                          bought_amount[w] for w in gameweeks), name='cont_budget')

    # Free transfer constraints
    model.add_constraints(
        (free_transfers[w] == aux[w] + 1 for w in gameweeks), name='aux_ft_rel')
    model.add_constraints((free_transfers[w-1] - number_of_transfers[w-1]
                          <= 2 * aux[w] for w in gameweeks), name='force_aux_1')
    model.add_constraints((free_transfers[w-1] - number_of_transfers[w-1]
                          >= aux[w] + (-14)*(1-aux[w]) for w in gameweeks), name='force_aux_2')
    model.add_constraints(
        (penalized_transfers[w] >= transfer_diff[w] for w in gameweeks), name='pen_transfer_rel')

    # Objectives
    gw_xp = {w: so.expr_sum(points_player_week[p, w] * (lineup[p, w] + captain[p, w] + 0.1*vicecap[p, w] + so.expr_sum(
        bench_weights[o] * bench[p, w, o] for o in order)) for p in players) for w in gameweeks}
    gw_total = {w: gw_xp[w] - 4 * penalized_transfers[w] for w in gameweeks}
    if objective == 'regular':
        total_xp = so.expr_sum(gw_total[w] for w in gameweeks)
        model.set_objective(-total_xp, sense='N', name='total_regular_xp')
    else:
        decay_objective = so.expr_sum(
            gw_total[w] * pow(decay_base, w-next_gw) for w in gameweeks)
        model.set_objective(-decay_objective, sense='N', name='total_decay_xp')

    # Solve
    model.export_mps(f'{problem_name}.mps')
    command = f'cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/{problem_name}.mps solve solu {problem_name}_sol.txt'
    # add 'stdout=DEVNULL' for disabling logs
    process = Popen(command, shell=True)
    process.wait()

    # Parsing
    with open(f'{problem_name}_sol.txt', 'r') as f:
        for line in f:
            if 'objective value' in line:
                continue
            words = line.split()
            var = model.get_variable(words[1])
            var.set_value(float(words[2]))

    # DataFrame generation
    picks = []
    for w in gameweeks:
        for p in players:
            if squad[p, w].get_value() + transfer_out[p, w].get_value() > 0.5:
                lp = merged_data.loc[p]
                is_captain = 1 if captain[p, w].get_value() > 0.5 else 0
                is_lineup = 1 if lineup[p, w].get_value() > 0.5 else 0
                is_vice = 1 if vicecap[p, w].get_value() > 0.5 else 0
                is_transfer_in = 1 if transfer_in[p,
                                                  w].get_value() > 0.5 else 0
                is_transfer_out = 1 if transfer_out[p, w].get_value(
                ) > 0.5 else 0
                bench_value = -1
                for o in order:
                    if bench[p, w, o].get_value() > 0.5:
                        bench_value = o
                position = type_data.loc[lp['element_type'],
                                         'singular_name_short']
                picks.append([
                    w, lp['web_name'], position, lp['element_type'], lp['name'], buy_price[p], sell_price[p], round(
                        points_player_week[p, w], 2), minutes_player_week[p, w], is_lineup, bench_value, is_captain, is_vice, is_transfer_in, is_transfer_out
                ])

    picks_df = pd.DataFrame(picks, columns=['week', 'name', 'pos', 'type', 'team', 'buy_price', 'sell_price', 'xP', 'xMin', 'lineup', 'bench',
                            'captain', 'vicecaptain', 'transfer_in', 'transfer_out']).sort_values(by=['week', 'lineup', 'type', 'xP'], ascending=[True, False, True, True])
    total_xp = so.expr_sum((lineup[p, w] + captain[p, w]) * points_player_week[p, w]
                           for p in players for w in gameweeks).get_value()

    # Writing summary
    summary_of_actions = ""
    for w in gameweeks:
        summary_of_actions += f"** GW {w}:\n"
        summary_of_actions += f"ITB = {in_the_bank[w].get_value()}, FT={free_transfers[w].get_value()}, PT={penalized_transfers[w].get_value()}\n"
        for p in players:
            if transfer_in[p, w].get_value() > 0.5:
                summary_of_actions += f"Buy {p} - {merged_data['web_name'][p]}\n"
            if transfer_out[p, w].get_value() > 0.5:
                summary_of_actions += f"Sell {p} - {merged_data['web_name'][p]}\n"

    return {'model': model, 'picks': picks_df, 'total_xp': total_xp, 'summary': summary_of_actions}

# %%
def solve_standard_problem():
    r = solve_multi_period_fpl(
        team_id=2821496, gw=gw, ft=ft, horizon=horizon, objective='regular')
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular.csv')

# %%
def solve_autobench_problem():
    r = solve_multi_period_fpl(
        team_id=2821496, gw=gw, ft=ft, horizon=horizon, objective='regular')
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular_stage_1.csv')

    df = r['picks']
    lineup_gk = df[(df['week'] == 4) & (
        df['pos'] == 'GKP') & (df['lineup'] == 1)]
    lineup_gk = lineup_gk.iloc[0]
    lineup_gk_mins = lineup_gk['xMin']
    gk_autosub_prob = xmin_to_prob(lineup_gk_mins, sub_on=0, sub_off=0)
    gk_weight = 1-gk_autosub_prob

    field_players = df[(df['week'] == 4) & (
        df['pos'] != 'GKP') & (df['lineup'] == 1)]
    field_players_xmins = field_players['xMin'].tolist()
    field_players_probs = [xmin_to_prob(i) for i in field_players_xmins]

    prob = 1
    for i in field_players_probs:
        prob *= i
    bench_1_weight = 1 - prob

    bench_weights = {0: gk_weight, 1: bench_1_weight, 2: 0.06, 3: 0.002}
    r = solve_multi_period_fpl(team_id=2821496, gw=gw, ft=ft,
                               horizon=8, objective='regular', bench_weights=bench_weights)
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular_stage_2.csv')

# %%
def solve_randomized_problem():
    r = solve_multi_period_fpl(team_id=2821496, gw=gw, ft=ft,
                               horizon=horizon, objective='regular', seed=None, randomized=True)
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_randomized.csv')


if __name__ == '__main__':

    solve_standard_problem()  
    
    solve_randomized_problem()
# Out:
# NOTE: Initialized model mp_h5_regular.
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Nov  6 2022
#
# command line - cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/mp_h5_regular.mps solve solu mp_h5_regular_sol.txt (default strategy 1)
# At line 1 NAME    mp_h5_regular
# At line 2 ROWS
# At line 39022 COLUMNS
# At line 131473 RHS
# At line 135383 RANGES
# At line 135399 BOUNDS
# At line 174233 ENDATA
# Problem mp_h5_regular has 39018 rows, 38833 columns and 151906 elements
# Coin0008I mp_h5_regular read with 0 errors
# Continuous objective value is -421.608 - 1.58 seconds
# Cgl0002I 746 variables fixed
# Cgl0003I 0 fixed, 5 tightened bounds, 32997 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17839 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14053 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8994 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2242 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 13 strengthened rows, 0 substitutions
# Cgl0004I processed model has 15417 rows, 36815 columns (36811 integer (36806 of which binary)) and 128451 elements
# Cbc0038I Initial state - 175 integers unsatisfied sum - 41.8276
# Cbc0038I Pass   1: (12.86 seconds) suminf.    0.27556 (4) obj. -406.473 iterations 3737
# Cbc0038I Pass   2: (12.88 seconds) suminf.    0.27556 (4) obj. -406.473 iterations 82
# Cbc0038I Pass   3: (12.90 seconds) suminf.    0.00000 (0) obj. -399.024 iterations 24
# Cbc0038I Solution found of -399.024
# Cbc0038I Relaxing continuous gives -399.024
# Cbc0038I Cleaned solution of -399.024
# Cbc0038I Before mini branch and bound, 36626 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15417 rows 36815 columns, reduced to 132 rows 110 columns
# Cbc0038I Mini branch and bound improved solution from -399.024 to -409.078 (12.98 seconds)
# Cbc0038I Round again with cutoff of -409.596
# Cbc0038I Reduced cost fixing fixed 4099 variables on major pass 2
# Cbc0038I Pass   4: (13.90 seconds) suminf.    6.78767 (25) obj. -409.596 iterations 2060
# Cbc0038I Pass   5: (14.67 seconds) suminf.    0.28669 (4) obj. -409.596 iterations 3645
# Cbc0038I Pass   6: (14.80 seconds) suminf.    0.29782 (4) obj. -409.596 iterations 774
# Cbc0038I Pass   7: (15.08 seconds) suminf.    0.37044 (9) obj. -409.596 iterations 1497
# Cbc0038I Pass   8: (15.29 seconds) suminf.    0.35812 (7) obj. -409.596 iterations 1567
# Cbc0038I Pass   9: (15.68 seconds) suminf.    0.86161 (15) obj. -409.596 iterations 1893
# Cbc0038I Pass  10: (15.70 seconds) suminf.    0.86161 (15) obj. -409.596 iterations 11
# Cbc0038I Pass  11: (16.00 seconds) suminf.    0.82006 (26) obj. -409.596 iterations 1569
# Cbc0038I Pass  12: (16.02 seconds) suminf.    0.83372 (21) obj. -409.596 iterations 6
# Cbc0038I Pass  13: (16.29 seconds) suminf.    2.75490 (21) obj. -409.596 iterations 1962
# Cbc0038I Pass  14: (16.40 seconds) suminf.    0.27436 (13) obj. -409.596 iterations 444
# Cbc0038I Pass  15: (16.41 seconds) suminf.    0.27436 (13) obj. -409.596 iterations 0
# Cbc0038I Pass  16: (16.56 seconds) suminf.    0.27436 (13) obj. -409.596 iterations 1087
# Cbc0038I Pass  17: (16.67 seconds) suminf.    0.27642 (13) obj. -409.596 iterations 705
# Cbc0038I Pass  18: (16.79 seconds) suminf.    0.47436 (16) obj. -409.596 iterations 814
# Cbc0038I Pass  19: (16.88 seconds) suminf.    0.47436 (16) obj. -409.596 iterations 567
# Cbc0038I Pass  20: (16.97 seconds) suminf.    0.47405 (13) obj. -409.596 iterations 543
# Cbc0038I Pass  21: (17.07 seconds) suminf.    0.47436 (16) obj. -409.596 iterations 653
# Cbc0038I Pass  22: (17.15 seconds) suminf.    0.68738 (16) obj. -409.596 iterations 434
# Cbc0038I Pass  23: (17.23 seconds) suminf.    0.68738 (16) obj. -409.596 iterations 504
# Cbc0038I Pass  24: (17.42 seconds) suminf.    3.83751 (23) obj. -409.596 iterations 1186
# Cbc0038I Pass  25: (17.82 seconds) suminf.    0.27436 (13) obj. -409.596 iterations 2546
# Cbc0038I Pass  26: (17.83 seconds) suminf.    0.27436 (13) obj. -409.596 iterations 0
# Cbc0038I Pass  27: (18.00 seconds) suminf.    0.27436 (13) obj. -409.596 iterations 1364
# Cbc0038I Pass  28: (18.09 seconds) suminf.    0.27405 (10) obj. -409.596 iterations 582
# Cbc0038I Pass  29: (18.19 seconds) suminf.    0.47436 (16) obj. -409.596 iterations 592
# Cbc0038I Pass  30: (18.27 seconds) suminf.    0.47436 (16) obj. -409.596 iterations 481
# Cbc0038I Pass  31: (18.38 seconds) suminf.    0.27436 (13) obj. -409.596 iterations 402
# Cbc0038I Pass  32: (18.39 seconds) suminf.    0.27436 (13) obj. -409.596 iterations 0
# Cbc0038I Pass  33: (18.46 seconds) suminf.    0.27436 (13) obj. -409.596 iterations 427
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 36579 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15417 rows 36815 columns, reduced to 150 rows 141 columns
# Cbc0038I Mini branch and bound did not improve solution (18.50 seconds)
# Cbc0038I After 18.50 seconds - Feasibility pump exiting with objective of -409.078 - took 6.16 seconds
# Cbc0012I Integer solution of -409.07796 found by feasibility pump after 0 iterations and 0 nodes (18.50 seconds)
# Cbc0038I Full problem 15417 rows 36815 columns, reduced to 129 rows 103 columns
# Cbc0031I 10 added rows had average density of 1151
# Cbc0013I At root node, 10 cuts changed objective from -414.25747 to -411.09811 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 2113 column cuts (2113 active)  in 0.043 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 763.8 elements, 0 column cuts (0 active)  in 0.069 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.042 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 12 row cuts average 1246.3 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 4 row cuts average 573.2 elements, 0 column cuts (0 active)  in 0.358 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -409.07796 best solution, best possible -411.09811 (20.79 seconds)
# Cbc0004I Integer solution of -409.15406 found after 15507 iterations and 33 nodes (28.94 seconds)
# Cbc0004I Integer solution of -409.18406 found after 15681 iterations and 36 nodes (28.98 seconds)
# Cbc0038I Full problem 15417 rows 36815 columns, reduced to 121 rows 96 columns
# Cbc0038I Full problem 15427 rows 36815 columns, reduced to 8897 rows 22369 columns
# Cbc0044I Reduced cost fixing - 8897 rows, 22369 columns - restarting search
# Cbc0012I Integer solution of -409.18406 found by Previous solution after 0 iterations and 0 nodes (32.09 seconds)
# Cbc0038I Full problem 8897 rows 22369 columns, reduced to 141 rows 119 columns
# Cbc0031I 10 added rows had average density of 1078.5
# Cbc0013I At root node, 10 cuts changed objective from -414.25747 to -411.09811 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 433 column cuts (433 active)  in 0.039 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 727.5 elements, 0 column cuts (0 active)  in 0.086 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.034 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 10 row cuts average 1321.8 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 3 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.118 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 4 row cuts average 538.2 elements, 0 column cuts (0 active)  in 0.186 seconds - new frequency is 1
# Cbc0014I Cut generator 9 (Stored from first) - 11 row cuts average 1121.6 elements, 0 column cuts (0 active)
# Cbc0010I After 0 nodes, 1 on tree, -409.18406 best solution, best possible -411.09811 (33.84 seconds)
# Cbc0004I Integer solution of -409.85666 found after 14131 iterations and 30 nodes (39.88 seconds)
# Cbc0038I Full problem 8897 rows 22369 columns, reduced to 51 rows 44 columns
# Cbc0016I Integer solution of -409.88066 found by strong branching after 16848 iterations and 43 nodes (41.20 seconds)
# Cbc0016I Integer solution of -409.90866 found by strong branching after 17789 iterations and 51 nodes (41.74 seconds)
# Cbc0016I Integer solution of -409.96806 found by strong branching after 19517 iterations and 66 nodes (42.60 seconds)
# Cbc0038I Full problem 8897 rows 22369 columns, reduced to 62 rows 49 columns
# Cbc0010I After 100 nodes, 7 on tree, -409.96806 best solution, best possible -411.09811 (45.11 seconds)
# Cbc0004I Integer solution of -410.02758 found after 38610 iterations and 190 nodes (51.03 seconds)
# Cbc0038I Full problem 8897 rows 22369 columns, reduced to 0 rows 0 columns
# Cbc0012I Integer solution of -410.15866 found by RINS after 39425 iterations and 200 nodes (51.58 seconds)
# Cbc0010I After 200 nodes, 7 on tree, -410.15866 best solution, best possible -411.09811 (51.58 seconds)
# Cbc0001I Search completed - best objective -410.1586600000001, took 46091 iterations and 276 nodes (54.96 seconds)
# Cbc0032I Strong branching done 1050 times (10051 iterations), fathomed 10 nodes and fixed 2 variables
# Cbc0035I Maximum depth 16, 162191 variables fixed on reduced cost
# Cbc0038I Probing was tried 159 times and created 593 cuts of which 0 were active after adding rounds of cuts (0.247 seconds)
# Cbc0038I Gomory was tried 4 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.086 seconds)
# Cbc0038I Knapsack was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.034 seconds)
# Cbc0038I Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Cbc0038I MixedIntegerRounding2 was tried 159 times and created 204 cuts of which 0 were active after adding rounds of cuts (0.294 seconds)
# Cbc0038I FlowCover was tried 69 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.081 seconds)
# Cbc0038I TwoMirCuts was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.118 seconds)
# Cbc0038I ZeroHalf was tried 159 times and created 9 cuts of which 0 were active after adding rounds of cuts (6.576 seconds)
# Cbc0038I Stored from first was tried 159 times and created 33 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Cbc0012I Integer solution of -410.15866 found by Reduced search after 68012 iterations and 326 nodes (55.02 seconds)
# Cbc0001I Search completed - best objective -410.1586600000001, took 68012 iterations and 326 nodes (55.02 seconds)
# Cbc0032I Strong branching done 300 times (4523 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 14, 52859 variables fixed on reduced cost
# Cuts at root node changed objective from -414.257 to -411.098
# Probing was tried 19 times and created 2122 cuts of which 0 were active after adding rounds of cuts (0.081 seconds)
# Gomory was tried 3 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.069 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.042 seconds)
# Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 19 times and created 30 cuts of which 0 were active after adding rounds of cuts (0.076 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.049 seconds)
# ZeroHalf was tried 19 times and created 4 cuts of which 0 were active after adding rounds of cuts (2.176 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -410.15866000
# Enumerated nodes:               326
# Total iterations:               68012
# Time (CPU seconds):             55.15
# Time (Wallclock seconds):       57.21
#
# Total time (CPU seconds):       55.22   (Wallclock seconds):       57.29
#
#     week              name  pos  type       team  buy_price  sell_price  \
# 8     34           Ederson  GKP     1   Man City        5.4         5.4
# 12    34          Trippier  DEF     2  Newcastle        6.2         6.1
# 6     34         Robertson  DEF     2  Liverpool        6.8         6.8
# 9     34              Dias  DEF     2   Man City        6.0         6.0
# 7     34  Alexander-Arnold  DEF     2  Liverpool        7.6         7.5
# ..   ...               ...  ...   ...        ...        ...         ...
# 68    38      Arrizabalaga  GKP     1    Chelsea        4.6         4.6
# 78    38            Botman  DEF     2  Newcastle        4.5         4.5
# 77    38          Trippier  DEF     2  Newcastle        6.2         6.1
# 65    38             March  MID     3   Brighton        5.3         5.2
# 69    38         Greenwood  FWD     4      Leeds        4.0         4.0
#
#        xP  xMin  lineup  bench  captain  vicecaptain  transfer_in  \
# 8    8.55    89       1     -1        0            0            0
# 12   5.33    84       1     -1        0            0            0
# 6    7.88    76       1     -1        0            0            0
# 9    7.90    75       1     -1        0            0            0
# 7   10.06    85       1     -1        0            0            0
# ..    ...   ...     ...    ...      ...          ...          ...
# 68   3.43    82       0      0        0            0            0
# 78   2.48    77       0      2        0            0            0
# 77   2.85    77       0      1        0            0            0
# 65   3.39    74       0     -1        0            0            0
# 69   0.52     9       0      3        0            0            0
#
#     transfer_out
# 8              0
# 12             0
# 6              0
# 9              0
# 7              0
# ..           ...
# 68             0
# 78             0
# 77             0
# 65             1
# 69             0
#
# [80 rows x 15 columns]
# ** GW 34:
# ITB = 0.9, FT=1.0, PT=0
# ** GW 35:
# ITB = 2.0, FT=2.0, PT=0
# Buy 139 - Chilwell
# Sell 284 - Robertson
# ** GW 36:
# ITB = 5.5, FT=2.0, PT=0
# Sell 283 - Salah
# Buy 333 - Fernandes
# ** GW 37:
# ITB = 1.5, FT=2.0, PT=0
# Sell 139 - Chilwell
# Buy 332 - Shaw
# Sell 594 - Isak
# Buy 427 - Kane
# ** GW 38:
# ITB = 0.1, FT=1.0, PT=0
# Buy 7 - Ødegaard
# Sell 107 - March
#
# NOTE: Initialized model mp_h5_regular.
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Nov  6 2022
#
# command line - cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/mp_h5_regular.mps solve solu mp_h5_regular_sol.txt (default strategy 1)
# At line 1 NAME    mp_h5_regular
# At line 2 ROWS
# At line 39022 COLUMNS
# At line 131473 RHS
# At line 135383 RANGES
# At line 135399 BOUNDS
# At line 174233 ENDATA
# Problem mp_h5_regular has 39018 rows, 38833 columns and 151906 elements
# Coin0008I mp_h5_regular read with 0 errors
# Continuous objective value is -434.658 - 1.45 seconds
# Cgl0002I 746 variables fixed
# Cgl0003I 0 fixed, 5 tightened bounds, 32951 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17802 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14019 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8920 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2216 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0004I processed model has 15424 rows, 36769 columns (36765 integer (36760 of which binary)) and 128414 elements
# Cbc0038I Initial state - 222 integers unsatisfied sum - 50.9091
# Cbc0038I Pass   1: (15.08 seconds) suminf.    0.69393 (6) obj. -405.129 iterations 5108
# Cbc0038I Pass   2: (15.12 seconds) suminf.    0.69393 (6) obj. -405.129 iterations 82
# Cbc0038I Pass   3: (15.15 seconds) suminf.    0.00000 (0) obj. -394.517 iterations 74
# Cbc0038I Solution found of -394.517
# Cbc0038I Relaxing continuous gives -394.517
# Cbc0038I Cleaned solution of -394.517
# Cbc0038I Before mini branch and bound, 36529 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 15424 rows 36769 columns, reduced to 173 rows 143 columns
# Cbc0038I Mini branch and bound improved solution from -394.517 to -413.118 (15.26 seconds)
# Cbc0038I Round again with cutoff of -414.347
# Cbc0038I Reduced cost fixing fixed 877 variables on major pass 2
# Cbc0038I Pass   4: (15.95 seconds) suminf.    9.47767 (32) obj. -414.347 iterations 1540
# Cbc0038I Pass   5: (16.58 seconds) suminf.    7.67723 (44) obj. -414.347 iterations 3555
# Cbc0038I Pass   6: (16.91 seconds) suminf.    7.41600 (31) obj. -414.347 iterations 1981
# Cbc0038I Pass   7: (17.87 seconds) suminf.    5.89419 (451) obj. -414.347 iterations 6538
# Cbc0038I Pass   8: (18.00 seconds) suminf.    5.89217 (38) obj. -414.347 iterations 523
# Cbc0038I Pass   9: (18.23 seconds) suminf.    4.74300 (30) obj. -414.347 iterations 1337
# Cbc0038I Pass  10: (18.86 seconds) suminf.    3.51736 (34) obj. -414.347 iterations 4347
# Cbc0038I Pass  11: (19.35 seconds) suminf.    4.66614 (24) obj. -414.347 iterations 2438
# Cbc0038I Pass  12: (19.71 seconds) suminf.    3.94417 (28) obj. -414.347 iterations 2269
# Cbc0038I Pass  13: (20.21 seconds) suminf.    3.64968 (35) obj. -414.347 iterations 2968
# Cbc0038I Pass  14: (21.44 seconds) suminf.    4.27491 (487) obj. -414.347 iterations 8385
# Cbc0038I No solution found this major pass
# Cbc0038I After 21.44 seconds - Feasibility pump exiting with objective of -413.118 - took 7.14 seconds
# Cbc0012I Integer solution of -413.11827 found by feasibility pump after 0 iterations and 0 nodes (21.44 seconds)
# Cbc0038I Full problem 15424 rows 36769 columns, reduced to 168 rows 134 columns
# Cbc0031I 7 added rows had average density of 947.71429
# Cbc0013I At root node, 7 cuts changed objective from -425.40412 to -417.66156 in 6 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 2455 column cuts (2455 active)  in 0.098 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 763.8 elements, 0 column cuts (0 active)  in 0.174 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.086 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 16 row cuts average 1248.9 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.023 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 3 row cuts average 763.7 elements, 0 column cuts (0 active)  in 0.739 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -413.11827 best solution, best possible -417.66156 (25.29 seconds)
# Cbc0012I Integer solution of -414.15076 found by DiveCoefficient after 2887 iterations and 1 nodes (25.96 seconds)
# Cbc0012I Integer solution of -415.226 found by DiveCoefficient after 2995 iterations and 1 nodes (26.91 seconds)
# Cbc0038I Full problem 15424 rows 36769 columns, reduced to 40 rows 32 columns
# Cbc0038I Full problem 15431 rows 36769 columns, reduced to 7979 rows 19399 columns
# Cbc0044I Reduced cost fixing - 7979 rows, 19399 columns - restarting search
# Cbc0012I Integer solution of -415.226 found by Previous solution after 0 iterations and 0 nodes (37.75 seconds)
# Cbc0038I Full problem 7979 rows 19399 columns, reduced to 180 rows 149 columns
# Cbc0031I 8 added rows had average density of 594.5
# Cbc0013I At root node, 8 cuts changed objective from -425.40412 to -417.63364 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1894 column cuts (1894 active)  in 0.035 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 460.5 elements, 0 column cuts (0 active)  in 0.074 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.023 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 9 row cuts average 903.6 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is 1
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 413.0 elements, 0 column cuts (0 active)  in 0.090 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 4 row cuts average 473.8 elements, 0 column cuts (0 active)  in 0.132 seconds - new frequency is 1
# Cbc0014I Cut generator 9 (Stored from first) - 7 row cuts average 648.1 elements, 0 column cuts (0 active)
# Cbc0010I After 0 nodes, 1 on tree, -415.226 best solution, best possible -417.63364 (39.12 seconds)
# Cbc0004I Integer solution of -415.97169 found after 3683 iterations and 32 nodes (41.95 seconds)
# Cbc0004I Integer solution of -416.18751 found after 3704 iterations and 33 nodes (41.99 seconds)
# Cbc0038I Full problem 7979 rows 19399 columns, reduced to 107 rows 79 columns
# Cbc0004I Integer solution of -417.14801 found after 5056 iterations and 60 nodes (43.21 seconds)
# Cbc0001I Search completed - best objective -417.1480059391002, took 6491 iterations and 76 nodes (43.83 seconds)
# Cbc0032I Strong branching done 372 times (4187 iterations), fathomed 8 nodes and fixed 0 variables
# Cbc0035I Maximum depth 10, 38554 variables fixed on reduced cost
# Cbc0038I Probing was tried 53 times and created 1944 cuts of which 0 were active after adding rounds of cuts (0.088 seconds)
# Cbc0038I Gomory was tried 3 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.074 seconds)
# Cbc0038I Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.023 seconds)
# Cbc0038I Clique was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Cbc0038I MixedIntegerRounding2 was tried 53 times and created 72 cuts of which 0 were active after adding rounds of cuts (0.071 seconds)
# Cbc0038I FlowCover was tried 27 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# Cbc0038I TwoMirCuts was tried 3 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.090 seconds)
# Cbc0038I ZeroHalf was tried 53 times and created 4 cuts of which 0 were active after adding rounds of cuts (1.812 seconds)
# Cbc0038I Stored from first was tried 53 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Cbc0012I Integer solution of -417.14801 found by Reduced search after 15396 iterations and 126 nodes (43.87 seconds)
# Cbc0001I Search completed - best objective -417.1480059391002, took 15396 iterations and 126 nodes (43.87 seconds)
# Cbc0032I Strong branching done 308 times (4336 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 27, 26340 variables fixed on reduced cost
# Cuts at root node changed objective from -425.404 to -417.662
# Probing was tried 22 times and created 2470 cuts of which 0 were active after adding rounds of cuts (0.134 seconds)
# Gomory was tried 6 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.174 seconds)
# Knapsack was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.086 seconds)
# Clique was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 22 times and created 28 cuts of which 0 were active after adding rounds of cuts (0.080 seconds)
# FlowCover was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.023 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.056 seconds)
# ZeroHalf was tried 22 times and created 4 cuts of which 0 were active after adding rounds of cuts (2.410 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -417.14800594
# Enumerated nodes:               126
# Total iterations:               15396
# Time (CPU seconds):             44.01
# Time (Wallclock seconds):       367.18
#
# Total time (CPU seconds):       44.09   (Wallclock seconds):       367.26
#
#     week              name  pos  type       team  buy_price  sell_price  \
# 8     34           Ederson  GKP     1   Man City        5.4         5.4
# 12    34          Trippier  DEF     2  Newcastle        6.2         6.1
# 9     34              Dias  DEF     2   Man City        6.0         6.0
# 6     34         Robertson  DEF     2  Liverpool        6.8         6.8
# 7     34  Alexander-Arnold  DEF     2  Liverpool        7.6         7.5
# ..   ...               ...  ...   ...        ...        ...         ...
# 69    38      Arrizabalaga  GKP     1    Chelsea        4.6         4.6
# 79    38            Botman  DEF     2  Newcastle        4.5         4.5
# 78    38          Trippier  DEF     2  Newcastle        6.2         6.1
# 67    38      Mac Allister  MID     3   Brighton        5.5         5.4
# 77    38            Wilson  FWD     4  Newcastle        6.9         6.9
#
#        xP  xMin  lineup  bench  captain  vicecaptain  transfer_in  \
# 8    8.26    89       1     -1        0            0            0
# 12   5.11    84       1     -1        0            0            0
# 9    8.71    75       1     -1        0            0            0
# 6    8.76    76       1     -1        0            0            0
# 7   11.11    85       1     -1        0            0            0
# ..    ...   ...     ...    ...      ...          ...          ...
# 69   3.61    82       0      0        0            0            0
# 79   2.16    77       0      3        0            0            0
# 78   2.88    77       0      2        0            0            0
# 67   3.60    73       0     -1        0            0            0
# 77   3.05    38       0      1        0            0            0
#
#     transfer_out
# 8              0
# 12             0
# 9              0
# 6              0
# 7              0
# ..           ...
# 69             0
# 79             0
# 78             0
# 67             1
# 77             0
#
# [80 rows x 15 columns]
# ** GW 34:
# ITB = 0.9, FT=1.0, PT=0
# ** GW 35:
# ITB = 0.8, FT=2.0, PT=0
# Buy 356 - Wilson
# Sell 594 - Isak
# ** GW 36:
# ITB = 0.2, FT=2.0, PT=0
# Buy 28 - Jesus
# Sell 237 - Greenwood
# Sell 283 - Salah
# Buy 333 - Fernandes
# ** GW 37:
# ITB = 2.9, FT=1.0, PT=0
# Sell 284 - Robertson
# Buy 337 - Lindelöf
# ** GW 38:
# ITB = 0, FT=1.0, PT=0
# Buy 13 - Saka
# Sell 116 - Mac Allister

# %%
sjekk =pd.read_csv("../output/optimal_plan_regular.csv")

# %%
sjekk
# Out:
#     Unnamed: 0  week              name  pos  type       team  buy_price  \
# 0            8    34           Ederson  GKP     1   Man City        5.4
# 1           12    34          Trippier  DEF     2  Newcastle        6.2
# 2            6    34         Robertson  DEF     2  Liverpool        6.8
# 3            9    34              Dias  DEF     2   Man City        6.0
# 4            7    34  Alexander-Arnold  DEF     2  Liverpool        7.6
# ..         ...   ...               ...  ...   ...        ...        ...
# 75          68    38      Arrizabalaga  GKP     1    Chelsea        4.6
# 76          78    38            Botman  DEF     2  Newcastle        4.5
# 77          77    38          Trippier  DEF     2  Newcastle        6.2
# 78          65    38             March  MID     3   Brighton        5.3
# 79          69    38         Greenwood  FWD     4      Leeds        4.0
#
#     sell_price     xP  xMin  lineup  bench  captain  vicecaptain  transfer_in  \
# 0          5.4   8.55    89       1     -1        0            0            0
# 1          6.1   5.33    84       1     -1        0            0            0
# 2          6.8   7.88    76       1     -1        0            0            0
# 3          6.0   7.90    75       1     -1        0            0            0
# 4          7.5  10.06    85       1     -1        0            0            0
# ..         ...    ...   ...     ...    ...      ...          ...          ...
# 75         4.6   3.43    82       0      0        0            0            0
# 76         4.5   2.48    77       0      2        0            0            0
# 77         6.1   2.85    77       0      1        0            0            0
# 78         5.2   3.39    74       0     -1        0            0            0
# 79         4.0   0.52     9       0      3        0            0            0
#
#     transfer_out
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 75             0
# 76             0
# 77             0
# 78             1
# 79             0
#
# [80 rows x 16 columns]
