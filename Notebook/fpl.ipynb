# %%
import pandas as pd
import numpy as np
import sasoptpy as so
import requests
import os

import time
from subprocess import Popen, DEVNULL
gw = 2
ft=1
horizon = 5
team_id= 2435607

# %%
def xmin_to_prob(xmin, sub_on=0.5, sub_off=0.3):
    """
    Converts a given xmin value to a probability using the provided substitution rates.

    Args:
        xmin (float): The xmin value to be converted to a probability.
        sub_on (float, optional): The substitution rate when the event is "on". Defaults to 0.5.
        sub_off (float, optional): The substitution rate when the event is "off". Defaults to 0.3.

    Returns:
        float: The calculated probability corresponding to the given xmin value and substitution rates.
    """

    start = min(max((xmin - 25 * sub_on) / (90 * (1-sub_off) + 65 * sub_off - 25 * sub_on), 0.001), 0.999)
    return start + (1-start) * sub_on

# %%
import pandas as pd
import numpy as np
import requests

def get_data(team_id, gw, seed_val, horizon, randomized):
    """
    Retrieves and processes data from the Fantasy Premier League API.

    Args:
        team_id (int): The ID of the team for which the data is being retrieved.
        gw (int): The game week for which the data is being retrieved.
        seed_val (int): The seed value used for random number generation.
        horizon (int): The number of game weeks in the future to consider for randomization.
        randomized (bool): A flag indicating whether to apply randomization to future game weeks.

    Returns:
        dict: A dictionary containing the processed data including merged_data (DataFrame),
              team_data (DataFrame), type_data (DataFrame), next_gw (int),
              initial_squad (list), and itb (float).
    """

    r = requests.get('https://fantasy.premierleague.com/api/bootstrap-static/')
    fpl_data = r.json()
    element_data = pd.DataFrame(fpl_data['elements'])
    team_data = pd.DataFrame(fpl_data['teams'])
    elements_team = pd.merge(element_data, team_data, left_on='team', right_on='id')
    review_data = pd.read_csv('../Data/fplreview.csv')
    review_data = review_data.fillna(0)
    review_data['review_id'] = review_data.index+1
    merged_data = pd.merge(elements_team, review_data, left_on='id_x', right_on='review_id')
    merged_data.set_index(['id_x'], inplace=True)

    if randomized:
        rng = np.random.default_rng(seed=seed_val)
        gws = list(range(gw+1, min(39, gw+1+horizon)))
        for w in gws:
            noise = merged_data[f"{w}_Pts"] * (92 - merged_data[f"{w}_xMins"]) / 134 * rng.standard_normal(size=len(merged_data))
            merged_data[f"{w}_Pts"] = merged_data[f"{w}_Pts"] + noise

    next_gw = int(review_data.keys()[6].split('_')[0])
    type_data = pd.DataFrame(fpl_data['element_types']).set_index(['id'])

    r = requests.get(f'https://fantasy.premierleague.com/api/entry/{team_id}/event/{gw}/picks/')
    picks_data = r.json()
    initial_squad = [i['element'] for i in picks_data['picks']]
    r = requests.get(f'https://fantasy.premierleague.com/api/entry/{team_id}/')
    general_data = r.json()
    itb = general_data['last_deadline_bank'] / 10

    return {
        'merged_data': merged_data,
        'team_data': team_data,
        'type_data': type_data,
        'next_gw': next_gw,
        'initial_squad': initial_squad,
        'itb': itb
    }

# %%
# review_data = pd.read_csv('../Data/xp_points.csv')
# next_gw = int(review_data.keys()[6].split('_')[0])
# next_gw

# %%
def solve_multi_period_fpl(team_id, gw, ft, horizon, objective='regular', decay_base=0.85, bench_weights=None, seed=None, randomized=False):
    

    # Data
    problem_name = f'mp_h{horizon}_regular' if objective == 'regular' else f'mp_h{horizon}_o{objective[0]}_d{decay_base}'
    data = get_data(team_id, gw-1, seed, horizon, randomized)
    merged_data = data['merged_data']
    team_data = data['team_data']
    type_data = data['type_data']
    next_gw = data['next_gw']
    initial_squad = data['initial_squad']
    itb = data['itb']

    # Sets
    players = merged_data.index.to_list()
    element_types = type_data.index.to_list()
    teams = team_data['name'].to_list()
    gameweeks = list(range(next_gw, next_gw+horizon))
    all_gw = [next_gw-1] + gameweeks
    order = [0, 1, 2, 3]
    if bench_weights is None:
        bench_weights = {0: 0.03, 1: 0.21, 2: 0.06, 3: 0.002}

    # Model
    model = so.Model(name=problem_name)

    # Variables
    squad = model.add_variables(
        players, all_gw, name='squad', vartype=so.binary)
    lineup = model.add_variables(
        players, gameweeks, name='lineup', vartype=so.binary)
    captain = model.add_variables(
        players, gameweeks, name='captain', vartype=so.binary)
    vicecap = model.add_variables(
        players, gameweeks, name='vicecap', vartype=so.binary)
    bench = model.add_variables(
        players, gameweeks, order, name='bench', vartype=so.binary)
    transfer_in = model.add_variables(
        players, gameweeks, name='transfer_in', vartype=so.binary)
    transfer_out = model.add_variables(
        players, gameweeks, name='transfer_out', vartype=so.binary)
    in_the_bank = model.add_variables(
        all_gw, name='itb', vartype=so.continuous, lb=0)
    free_transfers = model.add_variables(
        all_gw, name='ft', vartype=so.integer, lb=1, ub=2)
    penalized_transfers = model.add_variables(
        gameweeks, name='pt', vartype=so.integer, lb=0)
    aux = model.add_variables(gameweeks, name='aux', vartype=so.binary)

    # Dictionaries
    lineup_type_count = {(t, w): so.expr_sum(
        lineup[p, w] for p in players if merged_data.loc[p, 'element_type'] == t) for t in element_types for w in gameweeks}
    squad_type_count = {(t, w): so.expr_sum(
        squad[p, w] for p in players if merged_data.loc[p, 'element_type'] == t) for t in element_types for w in gameweeks}
    player_type = merged_data['element_type'].to_dict()

    # player_price = (merged_data['now_cost'] / 10).to_dict()
    sell_price = (merged_data['SV']).to_dict()
    buy_price = (merged_data['BV']).to_dict()
    sold_amount = {w: so.expr_sum(
        sell_price[p] * transfer_out[p, w] for p in players) for w in gameweeks}
    bought_amount = {w: so.expr_sum(
        buy_price[p] * transfer_in[p, w] for p in players) for w in gameweeks}
    points_player_week = {
        (p, w): merged_data.loc[p, f'{w}_Pts'] for p in players for w in gameweeks}
    minutes_player_week = {
        (p, w): merged_data.loc[p, f'{w}_xMins'] for p in players for w in gameweeks}
    squad_count = {w: so.expr_sum(squad[p, w]
                                  for p in players) for w in gameweeks}
    number_of_transfers = {w: so.expr_sum(
        transfer_out[p, w] for p in players) for w in gameweeks}
    number_of_transfers[next_gw-1] = 1
    transfer_diff = {
        w: number_of_transfers[w] - free_transfers[w] for w in gameweeks}

    # Initial conditions
    model.add_constraints(
        (squad[p, next_gw-1] == 1 for p in initial_squad), name='initial_squad_players')
    model.add_constraints(
        (squad[p, next_gw-1] == 0 for p in players if p not in initial_squad), name='initial_squad_others')
    model.add_constraint(in_the_bank[next_gw-1] == itb, name='initial_itb')
    model.add_constraint(free_transfers[next_gw-1] == ft, name='initial_ft')

    # Constraints
    model.add_constraints(
        (squad_count[w] == 15 for w in gameweeks), name='squad_count')
    model.add_constraints((so.expr_sum(
        lineup[p, w] for p in players) == 11 for w in gameweeks), name='lineup_count')
    model.add_constraints((so.expr_sum(
        bench[p, w, 0] for p in players if player_type[p] == 1) == 1 for w in gameweeks), name='bench_gk')
    model.add_constraints((so.expr_sum(
        bench[p, w, o] for p in players) == 1 for w in gameweeks for o in [1, 2, 3]), name='bench_count')
    model.add_constraints((so.expr_sum(
        captain[p, w] for p in players) == 1 for w in gameweeks), name='captain_count')
    model.add_constraints((so.expr_sum(
        vicecap[p, w] for p in players) == 1 for w in gameweeks), name='vicecap_count')
    model.add_constraints((lineup[p, w] <= squad[p, w]
                          for p in players for w in gameweeks), name='lineup_squad_rel')
    model.add_constraints((bench[p, w, o] <= squad[p, w]
                          for p in players for w in gameweeks for o in order), name='bench_squad_rel')
    model.add_constraints((captain[p, w] <= lineup[p, w]
                          for p in players for w in gameweeks), name='captain_lineup_rel')
    model.add_constraints((vicecap[p, w] <= lineup[p, w]
                          for p in players for w in gameweeks), name='vicecap_lineup_rel')
    model.add_constraints((captain[p, w] + vicecap[p, w] <=
                          1 for p in players for w in gameweeks), name='cap_vc_rel')
    model.add_constraints((lineup[p, w] + so.expr_sum(bench[p, w, o] for o in order)
                          <= 1 for p in players for w in gameweeks), name='lineup_bench_rel')
    model.add_constraints((lineup_type_count[t, w] == [type_data.loc[t, 'squad_min_play'], type_data.loc[t,
                          'squad_max_play']] for t in element_types for w in gameweeks), name='valid_formation')
    model.add_constraints((squad_type_count[t, w] == type_data.loc[t, 'squad_select']
                          for t in element_types for w in gameweeks), name='valid_squad')
    model.add_constraints((so.expr_sum(squad[p, w] for p in players if merged_data.loc[p,
                          'name'] == t) <= 3 for t in teams for w in gameweeks), name='team_limit')

    # Transfer constraints
    model.add_constraints((squad[p, w] == squad[p, w-1] + transfer_in[p, w] - transfer_out[p, w]
                          for p in players for w in gameweeks), name='squad_transfer_rel')
    model.add_constraints((in_the_bank[w] == in_the_bank[w-1] + sold_amount[w] -
                          bought_amount[w] for w in gameweeks), name='cont_budget')

    # Free transfer constraints
    model.add_constraints(
        (free_transfers[w] == aux[w] + 1 for w in gameweeks), name='aux_ft_rel')
    model.add_constraints((free_transfers[w-1] - number_of_transfers[w-1]
                          <= 2 * aux[w] for w in gameweeks), name='force_aux_1')
    model.add_constraints((free_transfers[w-1] - number_of_transfers[w-1]
                          >= aux[w] + (-14)*(1-aux[w]) for w in gameweeks), name='force_aux_2')
    model.add_constraints(
        (penalized_transfers[w] >= transfer_diff[w] for w in gameweeks), name='pen_transfer_rel')

    # Objectives
    gw_xp = {w: so.expr_sum(points_player_week[p, w] * (lineup[p, w] + captain[p, w] + 0.1*vicecap[p, w] + so.expr_sum(
        bench_weights[o] * bench[p, w, o] for o in order)) for p in players) for w in gameweeks}
    gw_total = {w: gw_xp[w] - 4 * penalized_transfers[w] for w in gameweeks}
    if objective == 'regular':
        total_xp = so.expr_sum(gw_total[w] for w in gameweeks)
        model.set_objective(-total_xp, sense='N', name='total_regular_xp')
    else:
        decay_objective = so.expr_sum(
            gw_total[w] * pow(decay_base, w-next_gw) for w in gameweeks)
        model.set_objective(-decay_objective, sense='N', name='total_decay_xp')

    # Solve
    model.export_mps(f'{problem_name}.mps')
    command = f'cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/{problem_name}.mps solve solu {problem_name}_sol.txt'
    # add 'stdout=DEVNULL' for disabling logs
    process = Popen(command, shell=True)
    process.wait()

    # Parsing
    with open(f'{problem_name}_sol.txt', 'r') as f:
        for line in f:
            if 'objective value' in line:
                continue
            words = line.split()
            var = model.get_variable(words[1])
            var.set_value(float(words[2]))

    # DataFrame generation
    picks = []
    for w in gameweeks:
        for p in players:
            if squad[p, w].get_value() + transfer_out[p, w].get_value() > 0.5:
                lp = merged_data.loc[p]
                is_captain = 1 if captain[p, w].get_value() > 0.5 else 0
                is_lineup = 1 if lineup[p, w].get_value() > 0.5 else 0
                is_vice = 1 if vicecap[p, w].get_value() > 0.5 else 0
                is_transfer_in = 1 if transfer_in[p,
                                                  w].get_value() > 0.5 else 0
                is_transfer_out = 1 if transfer_out[p, w].get_value(
                ) > 0.5 else 0
                bench_value = -1
                for o in order:
                    if bench[p, w, o].get_value() > 0.5:
                        bench_value = o
                position = type_data.loc[lp['element_type'],
                                         'singular_name_short']
                picks.append([
                    w, lp['web_name'], position, lp['element_type'], lp['name'], buy_price[p], sell_price[p], round(
                        points_player_week[p, w], 2), minutes_player_week[p, w], is_lineup, bench_value, is_captain, is_vice, is_transfer_in, is_transfer_out
                ])

    picks_df = pd.DataFrame(picks, columns=['week', 'name', 'pos', 'type', 'team', 'buy_price', 'sell_price', 'xP', 'xMin', 'lineup', 'bench',
                            'captain', 'vicecaptain', 'transfer_in', 'transfer_out']).sort_values(by=['week', 'lineup', 'type', 'xP'], ascending=[True, False, True, True])
    total_xp = so.expr_sum((lineup[p, w] + captain[p, w]) * points_player_week[p, w]
                           for p in players for w in gameweeks).get_value()

    # Writing summary
    summary_of_actions = ""
    for w in gameweeks:
        summary_of_actions += f"** GW {w}:\n"
        summary_of_actions += f"ITB = {in_the_bank[w].get_value()}, FT={free_transfers[w].get_value()}, PT={penalized_transfers[w].get_value()}\n"
        for p in players:
            if transfer_in[p, w].get_value() > 0.5:
                summary_of_actions += f"Buy {p} - {merged_data['web_name'][p]}\n"
            if transfer_out[p, w].get_value() > 0.5:
                summary_of_actions += f"Sell {p} - {merged_data['web_name'][p]}\n"

    return {'model': model, 'picks': picks_df, 'total_xp': total_xp, 'summary': summary_of_actions}

# %%
def solve_standard_problem():
    """
    Solves the standard Fantasy Premier League problem and prints the optimal picks and summary.

    It calls the `solve_multi_period_fpl` function with the specified parameters and saves the optimal picks to a CSV file.

    Returns:
        None
    """

    r = solve_multi_period_fpl(
        team_id, gw, ft, horizon, objective='regular')
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular.csv')

# %%
def solve_autobench_problem():
    """
    Solves the autobench Fantasy Premier League problem and prints the optimal picks and summary.

    It calls the `solve_multi_period_fpl` function twice. In the first stage, it solves the problem with the regular objective and saves the picks to a CSV file.
    Then, it calculates the weights for autobenching based on the minutes played by the goalkeeper and field players in the previous week's lineup.
    In the second stage, it solves the problem with the autobench weights and saves the picks to another CSV file.

    Returns:
        None
    """

    r = solve_multi_period_fpl(
        team_id, gw, ft, horizon, objective='regular')
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular_stage_1.csv')

    df = r['picks']
    lineup_gk = df[(df['week'] == 4) & (
        df['pos'] == 'GKP') & (df['lineup'] == 1)]
    lineup_gk = lineup_gk.iloc[0]
    lineup_gk_mins = lineup_gk['xMin']
    gk_autosub_prob = xmin_to_prob(lineup_gk_mins, sub_on=0, sub_off=0)
    gk_weight = 1 - gk_autosub_prob

    field_players = df[(df['week'] == 4) & (
        df['pos'] != 'GKP') & (df['lineup'] == 1)]
    field_players_xmins = field_players['xMin'].tolist()
    field_players_probs = [xmin_to_prob(i) for i in field_players_xmins]

    prob = 1
    for i in field_players_probs:
        prob *= i
    bench_1_weight = 1 - prob

    bench_weights = {0: gk_weight, 1: bench_1_weight, 2: 0.06, 3: 0.002}
    r = solve_multi_period_fpl(team_id, gw, ft,
                               horizon, objective='regular', bench_weights=bench_weights)
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular_stage_2.csv')

# %%
def solve_randomized_problem():
    """
    Solves the randomized Fantasy Premier League problem and prints the optimal picks and summary.

    It calls the `solve_multi_period_fpl` function with randomized parameters and saves the picks to a CSV file.

    Returns:
        None
    """

    r = solve_multi_period_fpl(team_id, gw, ft, horizon, objective='regular', seed=None, randomized=True)
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_randomized.csv')


if __name__ == '__main__':
    solve_standard_problem()
    solve_randomized_problem()
# Out:
# NOTE: Initialized model mp_h5_regular.
# Welcome to the CBC MILP Solver
# Version: 2.10.10
# Build Date: Jul 24 2023
#
# command line - cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/mp_h5_regular.mps solve solu mp_h5_regular_sol.txt (default strategy 1)
# At line 1 NAME    mp_h5_regular
# At line 2 ROWS
# At line 34126 COLUMNS
# At line 115407 RHS
# At line 118837 RANGES
# At line 118853 BOUNDS
# At line 152791 ENDATA
# Problem mp_h5_regular has 34122 rows, 33937 columns and 132772 elements
# Coin0008I mp_h5_regular read with 0 errors
# Continuous objective value is -319.797 - 2.59 seconds
# Cgl0002I 650 variables fixed
# Cgl0003I 0 fixed, 5 tightened bounds, 29084 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 15842 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 12520 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8351 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2171 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20 strengthened rows, 0 substitutions
# Cgl0004I processed model has 13495 rows, 32422 columns (32418 integer (32413 of which binary)) and 112745 elements
# Cbc0038I Initial state - 122 integers unsatisfied sum - 29.071
# Cbc0038I Pass   1: (14.55 seconds) suminf.    2.31583 (17) obj. -306.62 iterations 5007
# Cbc0038I Pass   2: (14.58 seconds) suminf.    2.31583 (17) obj. -306.62 iterations 64
# Cbc0038I Pass   3: (14.64 seconds) suminf.    0.07556 (3) obj. -283.158 iterations 334
# Cbc0038I Pass   4: (14.66 seconds) suminf.    0.00000 (0) obj. -279.176 iterations 24
# Cbc0038I Solution found of -279.176
# Cbc0038I Relaxing continuous gives -279.176
# Cbc0038I Cleaned solution of -279.176
# Cbc0038I Before mini branch and bound, 32284 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 13495 rows 32422 columns, reduced to 92 rows 71 columns
# Cbc0038I Mini branch and bound improved solution from -279.176 to -304.469 (14.72 seconds)
# Cbc0038I Round again with cutoff of -305.256
# Cbc0038I Reduced cost fixing fixed 404 variables on major pass 2
# Cbc0038I Pass   5: (14.74 seconds) suminf.    2.31583 (17) obj. -306.62 iterations 0
# Cbc0038I Pass   6: (14.76 seconds) suminf.    2.31583 (17) obj. -306.62 iterations 19
# Cbc0038I Pass   7: (15.15 seconds) suminf.    3.02242 (16) obj. -305.256 iterations 2360
# Cbc0038I Pass   8: (15.24 seconds) suminf.    2.64902 (23) obj. -305.256 iterations 599
# Cbc0038I Pass   9: (15.45 seconds) suminf.    0.29619 (7) obj. -305.256 iterations 1222
# Cbc0038I Pass  10: (15.47 seconds) suminf.    0.29619 (7) obj. -305.256 iterations 18
# Cbc0038I Pass  11: (15.55 seconds) suminf.    0.66158 (4) obj. -305.256 iterations 533
# Cbc0038I Pass  12: (15.57 seconds) suminf.    0.66158 (4) obj. -305.256 iterations 6
# Cbc0038I Pass  13: (15.59 seconds) suminf.    0.66158 (4) obj. -305.256 iterations 24
# Cbc0038I Pass  14: (15.78 seconds) suminf.    0.94602 (6) obj. -305.256 iterations 1377
# Cbc0038I Pass  15: (15.92 seconds) suminf.    0.94602 (6) obj. -305.256 iterations 968
# Cbc0038I Pass  16: (15.94 seconds) suminf.    0.92824 (6) obj. -305.256 iterations 13
# Cbc0038I Pass  17: (15.95 seconds) suminf.    0.92824 (6) obj. -305.256 iterations 0
# Cbc0038I Pass  18: (15.97 seconds) suminf.    0.94602 (6) obj. -305.256 iterations 52
# Cbc0038I Pass  19: (16.09 seconds) suminf.    0.94602 (6) obj. -305.256 iterations 671
# Cbc0038I Pass  20: (16.23 seconds) suminf.    1.32570 (9) obj. -305.256 iterations 963
# Cbc0038I Pass  21: (16.33 seconds) suminf.    1.32570 (9) obj. -305.256 iterations 672
# Cbc0038I Pass  22: (16.39 seconds) suminf.    0.66158 (4) obj. -305.256 iterations 437
# Cbc0038I Pass  23: (16.40 seconds) suminf.    0.66158 (4) obj. -305.256 iterations 0
# Cbc0038I Pass  24: (16.43 seconds) suminf.    0.66158 (4) obj. -305.256 iterations 71
# Cbc0038I Pass  25: (16.53 seconds) suminf.    1.63829 (9) obj. -305.256 iterations 649
# Cbc0038I Pass  26: (16.60 seconds) suminf.    1.47237 (10) obj. -305.256 iterations 413
# Cbc0038I Pass  27: (16.67 seconds) suminf.    1.47237 (10) obj. -305.256 iterations 482
# Cbc0038I Pass  28: (16.74 seconds) suminf.    1.47237 (10) obj. -305.256 iterations 428
# Cbc0038I Pass  29: (16.82 seconds) suminf.    0.66158 (4) obj. -305.256 iterations 609
# Cbc0038I Pass  30: (16.83 seconds) suminf.    0.66158 (4) obj. -305.256 iterations 0
# Cbc0038I Pass  31: (16.85 seconds) suminf.    0.66158 (4) obj. -305.256 iterations 75
# Cbc0038I Pass  32: (16.94 seconds) suminf.    0.94602 (6) obj. -305.256 iterations 546
# Cbc0038I Pass  33: (17.03 seconds) suminf.    0.94602 (6) obj. -305.256 iterations 583
# Cbc0038I Pass  34: (17.05 seconds) suminf.    1.12256 (6) obj. -305.256 iterations 19
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32269 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 13495 rows 32422 columns, reduced to 95 rows 81 columns
# Cbc0038I Mini branch and bound did not improve solution (17.07 seconds)
# Cbc0038I After 17.07 seconds - Feasibility pump exiting with objective of -304.469 - took 3.37 seconds
# Cbc0012I Integer solution of -304.469 found by feasibility pump after 0 iterations and 0 nodes (17.08 seconds)
# Cbc0038I Full problem 13495 rows 32422 columns, reduced to 85 rows 62 columns
# Cbc0012I Integer solution of -306.4058 found by DiveCoefficient after 1723 iterations and 0 nodes (19.20 seconds)
# Cbc0031I 9 added rows had average density of 906.77778
# Cbc0013I At root node, 9 cuts changed objective from -312.33514 to -307.93501 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 3080 column cuts (3080 active)  in 0.059 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 667.8 elements, 0 column cuts (0 active)  in 0.046 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.051 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 15 row cuts average 1083.7 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 4 row cuts average 667.8 elements, 0 column cuts (0 active)  in 0.332 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -306.4058 best solution, best possible -307.93501 (20.01 seconds)
# Cbc0012I Integer solution of -307.8358 found by DiveCoefficient after 2190 iterations and 2 nodes (20.53 seconds)
# Cbc0001I Search completed - best objective -307.8358000000001, took 3197 iterations and 4 nodes (21.16 seconds)
# Cbc0032I Strong branching done 32 times (2215 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 1, 32743 variables fixed on reduced cost
# Cuts at root node changed objective from -312.335 to -307.935
# Probing was tried 9 times and created 3085 cuts of which 0 were active after adding rounds of cuts (0.072 seconds)
# Gomory was tried 4 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.046 seconds)
# Knapsack was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.051 seconds)
# Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 9 times and created 25 cuts of which 0 were active after adding rounds of cuts (0.032 seconds)
# FlowCover was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.032 seconds)
# ZeroHalf was tried 9 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.741 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -307.83580000
# Enumerated nodes:               4
# Total iterations:               3197
# Time (CPU seconds):             21.34
# Time (Wallclock seconds):       21.73
#
# Total time (CPU seconds):       21.40   (Wallclock seconds):       21.80
#
#     week         name  pos  type           team  buy_price  sell_price    xP  \
# 14     2       Turner  GKP     1  Nott'm Forest        4.0         4.0  3.88
# 5      2    Estupiñan  DEF     2       Brighton        5.1         5.0  3.96
# 2      2       Saliba  DEF     2        Arsenal        5.1         5.0  4.01
# 7      2     Chilwell  DEF     2        Chelsea        5.6         5.6  4.17
# 15     2  Richarlison  MID     3          Spurs        7.0         7.0  4.30
# ..   ...          ...  ...   ...            ...        ...         ...   ...
# 77     6       Turner  GKP     1  Nott'm Forest        4.0         4.0  2.90
# 79     6       Udogie  DEF     2          Spurs        4.5         4.5  1.70
# 65     6       Saliba  DEF     2        Arsenal        5.1         5.0  3.03
# 78     6  Richarlison  MID     3          Spurs        7.0         7.0  3.28
# 66     6       Archer  FWD     4    Aston Villa        4.5         4.5  1.36
#
#     xMin  lineup  bench  captain  vicecaptain  transfer_in  transfer_out
# 14    94       1     -1        0            0            0             0
# 5     90       1     -1        0            0            0             0
# 2     92       1     -1        0            0            0             0
# 7     85       1     -1        0            0            1             0
# 15    83       1     -1        0            0            0             0
# ..   ...     ...    ...      ...          ...          ...           ...
# 77    89       0      0        0            0            0             0
# 79    70       0      2        0            0            0             0
# 65    81       0      1        0            0            0             0
# 78    73       0     -1        0            0            0             1
# 66    30       0      3        0            0            0             0
#
# [80 rows x 15 columns]
# ** GW 2:
# ITB = 0.4, FT=1.0, PT=0
# Buy 195 - Chilwell
# Sell 206 - James
# ** GW 3:
# ITB = 0.4, FT=1.0, PT=0
# Sell 148 - Steele
# Buy 145 - Sanchez
# ** GW 4:
# ITB = 0.9, FT=1.0, PT=0
# Sell 5 - Gabriel
# Buy 519 - Udogie
# ** GW 5:
# ITB = 0, FT=1.0, PT=0
# Sell 195 - Chilwell
# Buy 430 - Trippier
# ** GW 6:
# ITB = 0.5, FT=1.0, PT=0
# Buy 226 - Eze
# Sell 509 - Richarlison
#
# NOTE: Initialized model mp_h5_regular.
# Welcome to the CBC MILP Solver
# Version: 2.10.10
# Build Date: Jul 24 2023
#
# command line - cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/mp_h5_regular.mps solve solu mp_h5_regular_sol.txt (default strategy 1)
# At line 1 NAME    mp_h5_regular
# At line 2 ROWS
# At line 34126 COLUMNS
# At line 115407 RHS
# At line 118837 RANGES
# At line 118853 BOUNDS
# At line 152791 ENDATA
# Problem mp_h5_regular has 34122 rows, 33937 columns and 132772 elements
# Coin0008I mp_h5_regular read with 0 errors
# Continuous objective value is -322.49 - 2.58 seconds
# Cgl0002I 650 variables fixed
# Cgl0003I 0 fixed, 5 tightened bounds, 29037 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 15796 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 12470 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8256 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2123 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 13 strengthened rows, 0 substitutions
# Cgl0004I processed model has 13500 rows, 32375 columns (32371 integer (32366 of which binary)) and 112676 elements
# Cbc0038I Initial state - 118 integers unsatisfied sum - 29.7782
# Cbc0038I Pass   1: (13.41 seconds) suminf.    5.76397 (23) obj. -307.835 iterations 4635
# Cbc0038I Pass   2: (13.58 seconds) suminf.    3.34530 (23) obj. -306.491 iterations 1092
# Cbc0038I Pass   3: (14.32 seconds) suminf.    0.00000 (0) obj. -278.98 iterations 2556
# Cbc0038I Solution found of -278.98
# Cbc0038I Relaxing continuous gives -278.98
# Cbc0038I Cleaned solution of -278.98
# Cbc0038I Before mini branch and bound, 32230 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 13500 rows 32375 columns, reduced to 89 rows 79 columns
# Cbc0038I Mini branch and bound improved solution from -278.98 to -298.173 (14.39 seconds)
# Cbc0038I Round again with cutoff of -299.868
# Cbc0038I Reduced cost fixing fixed 20 variables on major pass 2
# Cbc0038I Pass   4: (14.40 seconds) suminf.    5.76397 (23) obj. -307.835 iterations 0
# Cbc0038I Pass   5: (14.69 seconds) suminf.    3.34530 (23) obj. -306.491 iterations 1769
# Cbc0038I Pass   6: (15.25 seconds) suminf.    2.87286 (18) obj. -299.868 iterations 2757
# Cbc0038I Pass   7: (15.36 seconds) suminf.    2.87286 (18) obj. -299.868 iterations 651
# Cbc0038I Pass   8: (15.49 seconds) suminf.    4.16137 (16) obj. -299.868 iterations 916
# Cbc0038I Pass   9: (15.72 seconds) suminf.    2.88973 (19) obj. -299.868 iterations 1599
# Cbc0038I Pass  10: (15.90 seconds) suminf.    2.87286 (18) obj. -299.868 iterations 1095
# Cbc0038I Pass  11: (16.15 seconds) suminf.    3.29018 (23) obj. -299.868 iterations 1664
# Cbc0038I Pass  12: (16.30 seconds) suminf.    3.15771 (20) obj. -299.868 iterations 1139
# Cbc0038I Pass  13: (16.43 seconds) suminf.    4.77393 (18) obj. -299.868 iterations 809
# Cbc0038I Pass  14: (16.46 seconds) suminf.    4.77393 (18) obj. -299.868 iterations 40
# Cbc0038I Pass  15: (16.60 seconds) suminf.    3.25819 (19) obj. -299.868 iterations 743
# Cbc0038I Pass  16: (16.62 seconds) suminf.    3.14317 (18) obj. -299.868 iterations 11
# Cbc0038I Pass  17: (16.72 seconds) suminf.    1.93783 (18) obj. -299.868 iterations 630
# Cbc0038I Pass  18: (16.79 seconds) suminf.    1.93783 (18) obj. -299.868 iterations 328
# Cbc0038I Pass  19: (16.90 seconds) suminf.    3.82318 (16) obj. -299.868 iterations 714
# Cbc0038I Pass  20: (17.18 seconds) suminf.    2.90832 (18) obj. -299.868 iterations 2159
# Cbc0038I Pass  21: (17.29 seconds) suminf.    1.93783 (18) obj. -299.868 iterations 631
# Cbc0038I Pass  22: (17.59 seconds) suminf.    3.62274 (26) obj. -299.868 iterations 2364
# Cbc0038I Pass  23: (17.77 seconds) suminf.    3.33269 (23) obj. -299.868 iterations 1301
# Cbc0038I Pass  24: (17.86 seconds) suminf.    4.34036 (16) obj. -299.868 iterations 696
# Cbc0038I Pass  25: (17.90 seconds) suminf.    4.34036 (16) obj. -299.868 iterations 131
# Cbc0038I Pass  26: (18.00 seconds) suminf.    2.76428 (17) obj. -299.868 iterations 660
# Cbc0038I Pass  27: (18.07 seconds) suminf.    2.68780 (18) obj. -299.868 iterations 396
# Cbc0038I Pass  28: (18.16 seconds) suminf.    1.91011 (14) obj. -299.868 iterations 589
# Cbc0038I Pass  29: (18.45 seconds) suminf.    0.88583 (14) obj. -299.868 iterations 2125
# Cbc0038I Pass  30: (18.56 seconds) suminf.    5.64560 (16) obj. -299.868 iterations 710
# Cbc0038I Pass  31: (18.70 seconds) suminf.    2.76810 (18) obj. -299.868 iterations 1025
# Cbc0038I Pass  32: (18.84 seconds) suminf.    2.94289 (23) obj. -299.868 iterations 910
# Cbc0038I Pass  33: (19.05 seconds) suminf.    2.78340 (21) obj. -299.868 iterations 1078
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32189 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 13500 rows 32375 columns, reduced to 108 rows 112 columns
# Cbc0038I Mini branch and bound improved solution from -298.173 to -298.596 (19.08 seconds)
# Cbc0038I Round again with cutoff of -302.918
# Cbc0038I Reduced cost fixing fixed 23 variables on major pass 3
# Cbc0038I Pass  33: (19.10 seconds) suminf.    5.76397 (23) obj. -307.835 iterations 0
# Cbc0038I Pass  34: (19.39 seconds) suminf.    3.34530 (23) obj. -306.491 iterations 1769
# Cbc0038I Pass  35: (19.95 seconds) suminf.    3.10606 (18) obj. -302.918 iterations 2941
# Cbc0038I Pass  36: (20.26 seconds) suminf.    2.89146 (19) obj. -302.918 iterations 1929
# Cbc0038I Pass  37: (20.58 seconds) suminf.    4.03780 (23) obj. -302.918 iterations 2066
# Cbc0038I Pass  38: (21.12 seconds) suminf.    2.89146 (19) obj. -302.918 iterations 3494
# Cbc0038I Pass  39: (21.44 seconds) suminf.    3.74568 (22) obj. -302.918 iterations 2297
# Cbc0038I Pass  40: (21.68 seconds) suminf.    2.77229 (19) obj. -302.918 iterations 1768
# Cbc0038I Pass  41: (21.89 seconds) suminf.    2.77294 (18) obj. -302.918 iterations 1267
# Cbc0038I Pass  42: (22.19 seconds) suminf.    3.62546 (26) obj. -302.918 iterations 1564
# Cbc0038I Pass  43: (22.38 seconds) suminf.    3.12869 (27) obj. -302.918 iterations 1375
# Cbc0038I Pass  44: (22.54 seconds) suminf.    3.02368 (29) obj. -302.918 iterations 1059
# Cbc0038I Pass  45: (22.71 seconds) suminf.    2.30376 (20) obj. -302.918 iterations 916
# Cbc0038I Pass  46: (22.83 seconds) suminf.    1.05923 (16) obj. -302.918 iterations 897
# Cbc0038I Pass  47: (22.95 seconds) suminf.    2.27285 (17) obj. -302.918 iterations 755
# Cbc0038I Pass  48: (23.09 seconds) suminf.    1.89247 (17) obj. -302.918 iterations 984
# Cbc0038I Pass  49: (23.36 seconds) suminf.    0.83839 (15) obj. -302.918 iterations 2297
# Cbc0038I Pass  50: (23.48 seconds) suminf.    1.75366 (14) obj. -302.918 iterations 860
# Cbc0038I Pass  51: (23.86 seconds) suminf.    0.96337 (14) obj. -302.918 iterations 3172
# Cbc0038I Pass  52: (24.00 seconds) suminf.    1.88054 (16) obj. -302.918 iterations 979
# Cbc0038I Pass  53: (24.22 seconds) suminf.    0.96337 (14) obj. -302.918 iterations 1823
# Cbc0038I Pass  54: (24.33 seconds) suminf.    1.75366 (14) obj. -302.918 iterations 848
# Cbc0038I Pass  55: (24.46 seconds) suminf.    1.93029 (16) obj. -302.918 iterations 899
# Cbc0038I Pass  56: (24.65 seconds) suminf.    1.07969 (15) obj. -302.918 iterations 1429
# Cbc0038I Pass  57: (24.73 seconds) suminf.    1.79365 (14) obj. -302.918 iterations 589
# Cbc0038I Pass  58: (24.93 seconds) suminf.    1.95680 (19) obj. -302.918 iterations 1473
# Cbc0038I Pass  59: (25.08 seconds) suminf.    1.81025 (16) obj. -302.918 iterations 1013
# Cbc0038I Pass  60: (25.23 seconds) suminf.    1.66467 (18) obj. -302.918 iterations 1273
# Cbc0038I Pass  61: (25.36 seconds) suminf.    0.97971 (15) obj. -302.918 iterations 1059
# Cbc0038I Pass  62: (25.45 seconds) suminf.    1.52279 (14) obj. -302.918 iterations 678
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32156 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 13500 rows 32375 columns, reduced to 116 rows 127 columns
# Cbc0038I Mini branch and bound improved solution from -298.596 to -305.775 (25.49 seconds)
# Cbc0038I Round again with cutoff of -308.579
# Cbc0038I Reduced cost fixing fixed 916 variables on major pass 4
# Cbc0038I Pass  62: (26.64 seconds) suminf.    4.32883 (32) obj. -308.579 iterations 2692
# Cbc0038I Pass  63: (26.79 seconds) suminf.    3.57413 (31) obj. -308.579 iterations 1290
# Cbc0038I Pass  64: (27.10 seconds) suminf.    4.13280 (32) obj. -308.579 iterations 1978
# Cbc0038I Pass  65: (27.35 seconds) suminf.    2.93368 (29) obj. -308.579 iterations 1798
# Cbc0038I Pass  66: (27.71 seconds) suminf.    3.68836 (28) obj. -308.579 iterations 2059
# Cbc0038I Pass  67: (27.74 seconds) suminf.    3.65481 (26) obj. -308.579 iterations 91
# Cbc0038I Pass  68: (27.95 seconds) suminf.    4.58119 (28) obj. -308.579 iterations 1471
# Cbc0038I Pass  69: (27.99 seconds) suminf.    4.56714 (28) obj. -308.579 iterations 189
# Cbc0038I Pass  70: (28.73 seconds) suminf.    2.57589 (19) obj. -308.579 iterations 4842
# Cbc0038I Pass  71: (28.75 seconds) suminf.    2.57589 (19) obj. -308.579 iterations 43
# Cbc0038I Pass  72: (29.29 seconds) suminf.    3.39475 (19) obj. -308.579 iterations 2511
# Cbc0038I Pass  73: (29.68 seconds) suminf.    2.13809 (17) obj. -308.579 iterations 2578
# Cbc0038I Pass  74: (29.95 seconds) suminf.    3.39475 (19) obj. -308.579 iterations 1753
# Cbc0038I Pass  75: (30.16 seconds) suminf.    2.35182 (22) obj. -308.579 iterations 1305
# Cbc0038I Pass  76: (30.43 seconds) suminf.    3.74239 (22) obj. -308.579 iterations 2107
# Cbc0038I Pass  77: (30.72 seconds) suminf.    2.32510 (20) obj. -308.579 iterations 2467
# Cbc0038I Pass  78: (31.02 seconds) suminf.    2.04273 (17) obj. -308.579 iterations 1548
# Cbc0038I Pass  79: (31.08 seconds) suminf.    2.04273 (17) obj. -308.579 iterations 319
# Cbc0038I Pass  80: (31.24 seconds) suminf.    2.87528 (16) obj. -308.579 iterations 984
# Cbc0038I Pass  81: (31.55 seconds) suminf.    2.36368 (20) obj. -308.579 iterations 2278
# Cbc0038I Pass  82: (31.77 seconds) suminf.    3.09258 (20) obj. -308.579 iterations 1747
# Cbc0038I Pass  83: (32.01 seconds) suminf.    2.93891 (21) obj. -308.579 iterations 1896
# Cbc0038I Pass  84: (32.18 seconds) suminf.    2.35664 (19) obj. -308.579 iterations 1398
# Cbc0038I Pass  85: (32.30 seconds) suminf.    2.35664 (19) obj. -308.579 iterations 645
# Cbc0038I Pass  86: (32.43 seconds) suminf.    2.35664 (19) obj. -308.579 iterations 937
# Cbc0038I Pass  87: (32.54 seconds) suminf.    2.35664 (19) obj. -308.579 iterations 672
# Cbc0038I Pass  88: (32.69 seconds) suminf.    2.87091 (20) obj. -308.579 iterations 1137
# Cbc0038I Pass  89: (32.86 seconds) suminf.    3.37688 (20) obj. -308.579 iterations 1383
# Cbc0038I Pass  90: (33.06 seconds) suminf.    2.34564 (20) obj. -308.579 iterations 1345
# Cbc0038I Pass  91: (33.18 seconds) suminf.    3.40905 (22) obj. -308.579 iterations 645
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 32162 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 13500 rows 32375 columns, reduced to 129 rows 137 columns
# Cbc0038I Mini branch and bound did not improve solution (33.21 seconds)
# Cbc0038I After 33.21 seconds - Feasibility pump exiting with objective of -305.775 - took 20.71 seconds
# Cbc0012I Integer solution of -305.77501 found by feasibility pump after 0 iterations and 0 nodes (33.21 seconds)
# Cbc0038I Full problem 13500 rows 32375 columns, reduced to 74 rows 62 columns
# Cbc0012I Integer solution of -306.30183 found by DiveCoefficient after 1610 iterations and 0 nodes (34.95 seconds)
# Cbc0031I 9 added rows had average density of 795.44444
# Cbc0013I At root node, 9 cuts changed objective from -315.12098 to -308.10417 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 3030 column cuts (3030 active)  in 0.051 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 667.8 elements, 0 column cuts (0 active)  in 0.070 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.050 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 9 row cuts average 916.4 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 5 row cuts average 534.6 elements, 0 column cuts (0 active)  in 0.356 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -306.30183 best solution, best possible -308.10417 (35.45 seconds)
# Cbc0012I Integer solution of -307.80325 found by DiveCoefficient after 1948 iterations and 1 nodes (35.66 seconds)
# Cbc0001I Search completed - best objective -307.8032459999999, took 2542 iterations and 6 nodes (36.36 seconds)
# Cbc0032I Strong branching done 38 times (2159 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 2, 15807 variables fixed on reduced cost
# Cuts at root node changed objective from -315.121 to -308.104
# Probing was tried 9 times and created 3035 cuts of which 0 were active after adding rounds of cuts (0.060 seconds)
# Gomory was tried 4 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.070 seconds)
# Knapsack was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.050 seconds)
# Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 9 times and created 17 cuts of which 0 were active after adding rounds of cuts (0.028 seconds)
# FlowCover was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.030 seconds)
# ZeroHalf was tried 9 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.789 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -307.80324600
# Enumerated nodes:               6
# Total iterations:               2542
# Time (CPU seconds):             36.47
# Time (Wallclock seconds):       36.99
#
# Total time (CPU seconds):       36.53   (Wallclock seconds):       37.06
#
#     week         name  pos  type           team  buy_price  sell_price    xP  \
# 14     2       Turner  GKP     1  Nott'm Forest        4.0         4.0  3.98
# 5      2    Estupiñan  DEF     2       Brighton        5.1         5.0  3.91
# 2      2       Saliba  DEF     2        Arsenal        5.1         5.0  4.01
# 7      2     Chilwell  DEF     2        Chelsea        5.6         5.6  4.22
# 15     2  Richarlison  MID     3          Spurs        7.0         7.0  4.28
# ..   ...          ...  ...   ...            ...        ...         ...   ...
# 77     6       Turner  GKP     1  Nott'm Forest        4.0         4.0  2.90
# 79     6       Udogie  DEF     2          Spurs        4.5         4.5  1.53
# 65     6       Saliba  DEF     2        Arsenal        5.1         5.0  3.23
# 78     6  Richarlison  MID     3          Spurs        7.0         7.0  3.03
# 66     6       Archer  FWD     4    Aston Villa        4.5         4.5  1.12
#
#     xMin  lineup  bench  captain  vicecaptain  transfer_in  transfer_out
# 14    94       1     -1        0            0            0             0
# 5     90       1     -1        0            0            0             0
# 2     92       1     -1        0            0            0             0
# 7     85       1     -1        0            0            1             0
# 15    83       1     -1        0            0            0             0
# ..   ...     ...    ...      ...          ...          ...           ...
# 77    89       0      0        0            0            0             0
# 79    70       0      2        0            0            0             0
# 65    81       0      1        0            0            0             0
# 78    73       0     -1        0            0            0             1
# 66    30       0      3        0            0            0             0
#
# [80 rows x 15 columns]
# ** GW 2:
# ITB = 0.4, FT=1.0, PT=0
# Buy 195 - Chilwell
# Sell 206 - James
# ** GW 3:
# ITB = 0.4, FT=1.0, PT=0
# Sell 148 - Steele
# Buy 145 - Sanchez
# ** GW 4:
# ITB = 0.9, FT=1.0, PT=0
# Sell 5 - Gabriel
# Buy 519 - Udogie
# ** GW 5:
# ITB = 0, FT=1.0, PT=0
# Sell 195 - Chilwell
# Buy 430 - Trippier
# ** GW 6:
# ITB = 0.5, FT=1.0, PT=0
# Buy 226 - Eze
# Sell 509 - Richarlison

# %%
sjekk =pd.read_csv("../output/optimal_plan_regular.csv")

# %%
sjekk
# Out:
#     Unnamed: 0  week         name  pos  type           team  buy_price  \
# 0           14     2       Turner  GKP     1  Nott'm Forest        4.0
# 1            5     2    Estupiñan  DEF     2       Brighton        5.1
# 2            2     2       Saliba  DEF     2        Arsenal        5.1
# 3            7     2     Chilwell  DEF     2        Chelsea        5.6
# 4           15     2  Richarlison  MID     3          Spurs        7.0
# ..         ...   ...          ...  ...   ...            ...        ...
# 75          77     6       Turner  GKP     1  Nott'm Forest        4.0
# 76          79     6       Udogie  DEF     2          Spurs        4.5
# 77          65     6       Saliba  DEF     2        Arsenal        5.1
# 78          78     6  Richarlison  MID     3          Spurs        7.0
# 79          66     6       Archer  FWD     4    Aston Villa        4.5
#
#     sell_price    xP  xMin  lineup  bench  captain  vicecaptain  transfer_in  \
# 0          4.0  3.88    94       1     -1        0            0            0
# 1          5.0  3.96    90       1     -1        0            0            0
# 2          5.0  4.01    92       1     -1        0            0            0
# 3          5.6  4.17    85       1     -1        0            0            1
# 4          7.0  4.30    83       1     -1        0            0            0
# ..         ...   ...   ...     ...    ...      ...          ...          ...
# 75         4.0  2.90    89       0      0        0            0            0
# 76         4.5  1.70    70       0      2        0            0            0
# 77         5.0  3.03    81       0      1        0            0            0
# 78         7.0  3.28    73       0     -1        0            0            0
# 79         4.5  1.36    30       0      3        0            0            0
#
#     transfer_out
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 75             0
# 76             0
# 77             0
# 78             1
# 79             0
#
# [80 rows x 16 columns]
