# %%
import pandas as pd
import numpy as np
import sasoptpy as so
import requests
import os

import time
from subprocess import Popen, DEVNULL
gw = 22
ft=1

# %%
def xmin_to_prob(xmin, sub_on=0.5, sub_off=0.3):
    start = min(max((xmin - 25 * sub_on) / (90 * (1-sub_off) +
                65 * sub_off - 25 * sub_on), 0.001), 0.999)
    return start + (1-start) * sub_on

# %%
def get_data(team_id, gw, seed_val, horizon, randomized):
    r = requests.get('https://fantasy.premierleague.com/api/bootstrap-static/')
    fpl_data = r.json()
    element_data = pd.DataFrame(fpl_data['elements'])
    team_data = pd.DataFrame(fpl_data['teams'])
    elements_team = pd.merge(element_data, team_data,
                             left_on='team', right_on='id')
    review_data = pd.read_csv('../Data/fplreview.csv')
    review_data = review_data.fillna(0)
    review_data['review_id'] = review_data.index+1
    merged_data = pd.merge(elements_team, review_data,
                           left_on='id_x', right_on='review_id')
    merged_data.set_index(['id_x'], inplace=True)

    if randomized:
        rng = np.random.default_rng(seed=seed_val)
        gws = list(range(gw+1, min(39, gw+1+horizon)))
        for w in gws:
            noise = merged_data[f"{w}_Pts"] * (
                92 - merged_data[f"{w}_xMins"]) / 134 * rng.standard_normal(size=len(merged_data))
            merged_data[f"{w}_Pts"] = merged_data[f"{w}_Pts"] + noise

    next_gw = int(review_data.keys()[6].split('_')[0])
    type_data = pd.DataFrame(fpl_data['element_types']).set_index(['id'])

    r = requests.get(
        f'https://fantasy.premierleague.com/api/entry/{team_id}/event/{gw}/picks/')
    picks_data = r.json()
    initial_squad = [i['element'] for i in picks_data['picks']]
    r = requests.get(f'https://fantasy.premierleague.com/api/entry/{team_id}/')
    general_data = r.json()
    itb = general_data['last_deadline_bank'] / 10

    return {'merged_data': merged_data, 'team_data': team_data, 'type_data': type_data, 'next_gw': next_gw, 'initial_squad': initial_squad, 'itb': itb}

# %%
# review_data = pd.read_csv('../Data/xp_points.csv')
# next_gw = int(review_data.keys()[6].split('_')[0])
# next_gw

# %%
def solve_multi_period_fpl(team_id, gw, ft, horizon, objective='regular', decay_base=0.84, bench_weights=None, seed=None, randomized=False):
    """
    Solves multi-objective FPL problem with transfers
    Parameters
    ----------
    team_id: integer
        FPL ID of the team to be optimized
    gw: integer
        Upcoming (next) gameweek
    ft: integer
        Number of available free transfers (currently)
    horizon: integer
        Number of weeks to consider in optimization
    objective: string
        Type of objective "regular" or "decay"
    decay_base: float
        Base for the decay function
    """

    # Data
    problem_name = f'mp_h{horizon}_regular' if objective == 'regular' else f'mp_h{horizon}_o{objective[0]}_d{decay_base}'
    data = get_data(team_id, gw-1, seed, horizon, randomized)
    merged_data = data['merged_data']
    team_data = data['team_data']
    type_data = data['type_data']
    next_gw = data['next_gw']
    initial_squad = data['initial_squad']
    itb = data['itb']

    # Sets
    players = merged_data.index.to_list()
    element_types = type_data.index.to_list()
    teams = team_data['name'].to_list()
    gameweeks = list(range(next_gw, next_gw+horizon))
    all_gw = [next_gw-1] + gameweeks
    order = [0, 1, 2, 3]
    if bench_weights is None:
        bench_weights = {0: 0.03, 1: 0.21, 2: 0.06, 3: 0.002}

    # Model
    model = so.Model(name=problem_name)

    # Variables
    squad = model.add_variables(
        players, all_gw, name='squad', vartype=so.binary)
    lineup = model.add_variables(
        players, gameweeks, name='lineup', vartype=so.binary)
    captain = model.add_variables(
        players, gameweeks, name='captain', vartype=so.binary)
    vicecap = model.add_variables(
        players, gameweeks, name='vicecap', vartype=so.binary)
    bench = model.add_variables(
        players, gameweeks, order, name='bench', vartype=so.binary)
    transfer_in = model.add_variables(
        players, gameweeks, name='transfer_in', vartype=so.binary)
    transfer_out = model.add_variables(
        players, gameweeks, name='transfer_out', vartype=so.binary)
    in_the_bank = model.add_variables(
        all_gw, name='itb', vartype=so.continuous, lb=0)
    free_transfers = model.add_variables(
        all_gw, name='ft', vartype=so.integer, lb=1, ub=2)
    penalized_transfers = model.add_variables(
        gameweeks, name='pt', vartype=so.integer, lb=0)
    aux = model.add_variables(gameweeks, name='aux', vartype=so.binary)

    # Dictionaries
    lineup_type_count = {(t, w): so.expr_sum(
        lineup[p, w] for p in players if merged_data.loc[p, 'element_type'] == t) for t in element_types for w in gameweeks}
    squad_type_count = {(t, w): so.expr_sum(
        squad[p, w] for p in players if merged_data.loc[p, 'element_type'] == t) for t in element_types for w in gameweeks}
    player_type = merged_data['element_type'].to_dict()

    # player_price = (merged_data['now_cost'] / 10).to_dict()
    sell_price = (merged_data['SV']).to_dict()
    buy_price = (merged_data['BV']).to_dict()
    sold_amount = {w: so.expr_sum(
        sell_price[p] * transfer_out[p, w] for p in players) for w in gameweeks}
    bought_amount = {w: so.expr_sum(
        buy_price[p] * transfer_in[p, w] for p in players) for w in gameweeks}
    points_player_week = {
        (p, w): merged_data.loc[p, f'{w}_Pts'] for p in players for w in gameweeks}
    minutes_player_week = {
        (p, w): merged_data.loc[p, f'{w}_xMins'] for p in players for w in gameweeks}
    squad_count = {w: so.expr_sum(squad[p, w]
                                  for p in players) for w in gameweeks}
    number_of_transfers = {w: so.expr_sum(
        transfer_out[p, w] for p in players) for w in gameweeks}
    number_of_transfers[next_gw-1] = 1
    transfer_diff = {
        w: number_of_transfers[w] - free_transfers[w] for w in gameweeks}

    # Initial conditions
    model.add_constraints(
        (squad[p, next_gw-1] == 1 for p in initial_squad), name='initial_squad_players')
    model.add_constraints(
        (squad[p, next_gw-1] == 0 for p in players if p not in initial_squad), name='initial_squad_others')
    model.add_constraint(in_the_bank[next_gw-1] == itb, name='initial_itb')
    model.add_constraint(free_transfers[next_gw-1] == ft, name='initial_ft')

    # Constraints
    model.add_constraints(
        (squad_count[w] == 15 for w in gameweeks), name='squad_count')
    model.add_constraints((so.expr_sum(
        lineup[p, w] for p in players) == 11 for w in gameweeks), name='lineup_count')
    model.add_constraints((so.expr_sum(
        bench[p, w, 0] for p in players if player_type[p] == 1) == 1 for w in gameweeks), name='bench_gk')
    model.add_constraints((so.expr_sum(
        bench[p, w, o] for p in players) == 1 for w in gameweeks for o in [1, 2, 3]), name='bench_count')
    model.add_constraints((so.expr_sum(
        captain[p, w] for p in players) == 1 for w in gameweeks), name='captain_count')
    model.add_constraints((so.expr_sum(
        vicecap[p, w] for p in players) == 1 for w in gameweeks), name='vicecap_count')
    model.add_constraints((lineup[p, w] <= squad[p, w]
                          for p in players for w in gameweeks), name='lineup_squad_rel')
    model.add_constraints((bench[p, w, o] <= squad[p, w]
                          for p in players for w in gameweeks for o in order), name='bench_squad_rel')
    model.add_constraints((captain[p, w] <= lineup[p, w]
                          for p in players for w in gameweeks), name='captain_lineup_rel')
    model.add_constraints((vicecap[p, w] <= lineup[p, w]
                          for p in players for w in gameweeks), name='vicecap_lineup_rel')
    model.add_constraints((captain[p, w] + vicecap[p, w] <=
                          1 for p in players for w in gameweeks), name='cap_vc_rel')
    model.add_constraints((lineup[p, w] + so.expr_sum(bench[p, w, o] for o in order)
                          <= 1 for p in players for w in gameweeks), name='lineup_bench_rel')
    model.add_constraints((lineup_type_count[t, w] == [type_data.loc[t, 'squad_min_play'], type_data.loc[t,
                          'squad_max_play']] for t in element_types for w in gameweeks), name='valid_formation')
    model.add_constraints((squad_type_count[t, w] == type_data.loc[t, 'squad_select']
                          for t in element_types for w in gameweeks), name='valid_squad')
    model.add_constraints((so.expr_sum(squad[p, w] for p in players if merged_data.loc[p,
                          'name'] == t) <= 3 for t in teams for w in gameweeks), name='team_limit')

    # Transfer constraints
    model.add_constraints((squad[p, w] == squad[p, w-1] + transfer_in[p, w] - transfer_out[p, w]
                          for p in players for w in gameweeks), name='squad_transfer_rel')
    model.add_constraints((in_the_bank[w] == in_the_bank[w-1] + sold_amount[w] -
                          bought_amount[w] for w in gameweeks), name='cont_budget')

    # Free transfer constraints
    model.add_constraints(
        (free_transfers[w] == aux[w] + 1 for w in gameweeks), name='aux_ft_rel')
    model.add_constraints((free_transfers[w-1] - number_of_transfers[w-1]
                          <= 2 * aux[w] for w in gameweeks), name='force_aux_1')
    model.add_constraints((free_transfers[w-1] - number_of_transfers[w-1]
                          >= aux[w] + (-14)*(1-aux[w]) for w in gameweeks), name='force_aux_2')
    model.add_constraints(
        (penalized_transfers[w] >= transfer_diff[w] for w in gameweeks), name='pen_transfer_rel')

    # Objectives
    gw_xp = {w: so.expr_sum(points_player_week[p, w] * (lineup[p, w] + captain[p, w] + 0.1*vicecap[p, w] + so.expr_sum(
        bench_weights[o] * bench[p, w, o] for o in order)) for p in players) for w in gameweeks}
    gw_total = {w: gw_xp[w] - 4 * penalized_transfers[w] for w in gameweeks}
    if objective == 'regular':
        total_xp = so.expr_sum(gw_total[w] for w in gameweeks)
        model.set_objective(-total_xp, sense='N', name='total_regular_xp')
    else:
        decay_objective = so.expr_sum(
            gw_total[w] * pow(decay_base, w-next_gw) for w in gameweeks)
        model.set_objective(-decay_objective, sense='N', name='total_decay_xp')

    # Solve
    model.export_mps(f'{problem_name}.mps')
    command = f'cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/{problem_name}.mps solve solu {problem_name}_sol.txt'
    # add 'stdout=DEVNULL' for disabling logs
    process = Popen(command, shell=True)
    process.wait()

    # Parsing
    with open(f'{problem_name}_sol.txt', 'r') as f:
        for line in f:
            if 'objective value' in line:
                continue
            words = line.split()
            var = model.get_variable(words[1])
            var.set_value(float(words[2]))

    # DataFrame generation
    picks = []
    for w in gameweeks:
        for p in players:
            if squad[p, w].get_value() + transfer_out[p, w].get_value() > 0.5:
                lp = merged_data.loc[p]
                is_captain = 1 if captain[p, w].get_value() > 0.5 else 0
                is_lineup = 1 if lineup[p, w].get_value() > 0.5 else 0
                is_vice = 1 if vicecap[p, w].get_value() > 0.5 else 0
                is_transfer_in = 1 if transfer_in[p,
                                                  w].get_value() > 0.5 else 0
                is_transfer_out = 1 if transfer_out[p, w].get_value(
                ) > 0.5 else 0
                bench_value = -1
                for o in order:
                    if bench[p, w, o].get_value() > 0.5:
                        bench_value = o
                position = type_data.loc[lp['element_type'],
                                         'singular_name_short']
                picks.append([
                    w, lp['web_name'], position, lp['element_type'], lp['name'], buy_price[p], sell_price[p], round(
                        points_player_week[p, w], 2), minutes_player_week[p, w], is_lineup, bench_value, is_captain, is_vice, is_transfer_in, is_transfer_out
                ])

    picks_df = pd.DataFrame(picks, columns=['week', 'name', 'pos', 'type', 'team', 'buy_price', 'sell_price', 'xP', 'xMin', 'lineup', 'bench',
                            'captain', 'vicecaptain', 'transfer_in', 'transfer_out']).sort_values(by=['week', 'lineup', 'type', 'xP'], ascending=[True, False, True, True])
    total_xp = so.expr_sum((lineup[p, w] + captain[p, w]) * points_player_week[p, w]
                           for p in players for w in gameweeks).get_value()

    # Writing summary
    summary_of_actions = ""
    for w in gameweeks:
        summary_of_actions += f"** GW {w}:\n"
        summary_of_actions += f"ITB = {in_the_bank[w].get_value()}, FT={free_transfers[w].get_value()}, PT={penalized_transfers[w].get_value()}\n"
        for p in players:
            if transfer_in[p, w].get_value() > 0.5:
                summary_of_actions += f"Buy {p} - {merged_data['web_name'][p]}\n"
            if transfer_out[p, w].get_value() > 0.5:
                summary_of_actions += f"Sell {p} - {merged_data['web_name'][p]}\n"

    return {'model': model, 'picks': picks_df, 'total_xp': total_xp, 'summary': summary_of_actions}

# %%
def solve_standard_problem():
    r = solve_multi_period_fpl(
        team_id=2821496, gw=gw, ft=ft, horizon=5, objective='regular')
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular.csv')

# %%
def solve_autobench_problem():
    r = solve_multi_period_fpl(
        team_id=2821496, gw=gw, ft=ft, horizon=5, objective='regular')
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular_stage_1.csv')

    df = r['picks']
    lineup_gk = df[(df['week'] == 4) & (
        df['pos'] == 'GKP') & (df['lineup'] == 1)]
    lineup_gk = lineup_gk.iloc[0]
    lineup_gk_mins = lineup_gk['xMin']
    gk_autosub_prob = xmin_to_prob(lineup_gk_mins, sub_on=0, sub_off=0)
    gk_weight = 1-gk_autosub_prob

    field_players = df[(df['week'] == 4) & (
        df['pos'] != 'GKP') & (df['lineup'] == 1)]
    field_players_xmins = field_players['xMin'].tolist()
    field_players_probs = [xmin_to_prob(i) for i in field_players_xmins]

    prob = 1
    for i in field_players_probs:
        prob *= i
    bench_1_weight = 1 - prob

    bench_weights = {0: gk_weight, 1: bench_1_weight, 2: 0.06, 3: 0.002}
    r = solve_multi_period_fpl(team_id=2821496, gw=gw, ft=ft,
                               horizon=5, objective='regular', bench_weights=bench_weights)
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_regular_stage_2.csv')

# %%
def solve_randomized_problem():
    r = solve_multi_period_fpl(team_id=2821496, gw=gw, ft=ft,
                               horizon=5, objective='regular', seed=None, randomized=True)
    print(r['picks'])
    print(r['summary'])
    r['picks'].to_csv('../output/optimal_plan_randomized.csv')


if __name__ == '__main__':

    solve_standard_problem()  
    
    solve_randomized_problem()
# Out:
# NOTE: Initialized model mp_h5_regular.
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Nov  6 2022
#
# command line - cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/mp_h5_regular.mps solve solu mp_h5_regular_sol.txt (default strategy 1)
# At line 1 NAME    mp_h5_regular
# At line 2 ROWS
# At line 37645 COLUMNS
# At line 127121 RHS
# At line 130896 RANGES
# At line 130912 BOUNDS
# At line 168369 ENDATA
# Problem mp_h5_regular has 37641 rows, 37456 columns and 146493 elements
# Coin0008I mp_h5_regular read with 0 errors
# Continuous objective value is -372.905 - 3.00 seconds
# Cgl0002I 719 variables fixed
# Cgl0003I 0 fixed, 5 tightened bounds, 31949 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17321 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 13669 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8911 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2301 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0004I processed model has 14873 rows, 35632 columns (35628 integer (35623 of which binary)) and 124108 elements
# Cbc0038I Initial state - 147 integers unsatisfied sum - 36.3161
# Cbc0038I Pass   1: (14.56 seconds) suminf.    5.71778 (48) obj. -355.066 iterations 5812
# Cbc0038I Pass   2: (14.79 seconds) suminf.    4.56491 (45) obj. -354.661 iterations 1739
# Cbc0038I Pass   3: (15.19 seconds) suminf.    1.05632 (17) obj. -325.43 iterations 2048
# Cbc0038I Pass   4: (15.29 seconds) suminf.    1.05632 (17) obj. -325.43 iterations 710
# Cbc0038I Pass   5: (15.49 seconds) suminf.    0.00000 (0) obj. -306.296 iterations 1209
# Cbc0038I Solution found of -306.296
# Cbc0038I Relaxing continuous gives -306.296
# Cbc0038I Cleaned solution of -306.296
# Cbc0038I Before mini branch and bound, 35433 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 14873 rows 35632 columns, reduced to 109 rows 102 columns
# Cbc0038I Mini branch and bound improved solution from -306.296 to -333.685 (15.58 seconds)
# Cbc0038I Round again with cutoff of -336.577
# Cbc0038I Reduced cost fixing fixed 2 variables on major pass 2
# Cbc0038I Pass   6: (15.60 seconds) suminf.    5.71778 (48) obj. -355.066 iterations 0
# Cbc0038I Pass   7: (16.11 seconds) suminf.    4.56491 (45) obj. -354.661 iterations 5151
# Cbc0038I Pass   8: (16.55 seconds) suminf.    4.18423 (38) obj. -343.396 iterations 3460
# Cbc0038I Pass   9: (16.67 seconds) suminf.    3.38354 (37) obj. -345.106 iterations 1082
# Cbc0038I Pass  10: (17.10 seconds) suminf.    4.85792 (29) obj. -336.577 iterations 3172
# Cbc0038I Pass  11: (17.31 seconds) suminf.    3.87454 (45) obj. -336.577 iterations 1277
# Cbc0038I Pass  12: (17.67 seconds) suminf.    2.52054 (26) obj. -336.577 iterations 2132
# Cbc0038I Pass  13: (17.70 seconds) suminf.    2.52054 (26) obj. -336.577 iterations 21
# Cbc0038I Pass  14: (17.93 seconds) suminf.    3.27177 (29) obj. -336.577 iterations 1529
# Cbc0038I Pass  15: (17.97 seconds) suminf.    3.32639 (30) obj. -336.577 iterations 161
# Cbc0038I Pass  16: (18.35 seconds) suminf.    3.07980 (34) obj. -342.043 iterations 3483
# Cbc0038I Pass  17: (18.77 seconds) suminf.    3.32639 (30) obj. -336.577 iterations 2854
# Cbc0038I Pass  18: (18.97 seconds) suminf.    3.69585 (34) obj. -336.577 iterations 1602
# Cbc0038I Pass  19: (19.16 seconds) suminf.    3.56875 (33) obj. -336.577 iterations 1359
# Cbc0038I Pass  20: (19.41 seconds) suminf.    3.59639 (38) obj. -348.797 iterations 2282
# Cbc0038I Pass  21: (19.50 seconds) suminf.    3.53872 (38) obj. -349.096 iterations 919
# Cbc0038I Pass  22: (19.89 seconds) suminf.    3.56875 (33) obj. -336.577 iterations 2695
# Cbc0038I Pass  23: (20.09 seconds) suminf.    7.02440 (32) obj. -336.577 iterations 1381
# Cbc0038I Pass  24: (20.30 seconds) suminf.    7.02440 (32) obj. -336.577 iterations 1321
# Cbc0038I Pass  25: (20.40 seconds) suminf.    5.25470 (34) obj. -336.577 iterations 701
# Cbc0038I Pass  26: (20.47 seconds) suminf.    4.26442 (32) obj. -336.577 iterations 396
# Cbc0038I Pass  27: (20.67 seconds) suminf.    3.66149 (30) obj. -336.577 iterations 1370
# Cbc0038I Pass  28: (21.03 seconds) suminf.    3.56875 (33) obj. -336.577 iterations 2320
# Cbc0038I Pass  29: (21.06 seconds) suminf.    3.56875 (33) obj. -336.577 iterations 24
# Cbc0038I Pass  30: (21.32 seconds) suminf.    2.81313 (33) obj. -338.547 iterations 2657
# Cbc0038I Pass  31: (21.70 seconds) suminf.    3.35843 (28) obj. -336.577 iterations 2482
# Cbc0038I Pass  32: (21.75 seconds) suminf.    3.34366 (30) obj. -336.577 iterations 222
# Cbc0038I Pass  33: (22.34 seconds) suminf.    3.16692 (43) obj. -336.577 iterations 3521
# Cbc0038I Pass  34: (22.40 seconds) suminf.    3.15650 (52) obj. -336.577 iterations 303
# Cbc0038I Pass  35: (22.51 seconds) suminf.    6.55206 (38) obj. -336.577 iterations 638
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 35319 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 14873 rows 35632 columns, reduced to 158 rows 159 columns
# Cbc0038I Mini branch and bound improved solution from -333.685 to -343.167 (22.55 seconds)
# Cbc0038I Round again with cutoff of -347.054
# Cbc0038I Reduced cost fixing fixed 17 variables on major pass 3
# Cbc0038I Pass  35: (22.57 seconds) suminf.    5.71778 (48) obj. -355.066 iterations 0
# Cbc0038I Pass  36: (23.10 seconds) suminf.    4.56491 (45) obj. -354.661 iterations 5444
# Cbc0038I Pass  37: (23.85 seconds) suminf.    3.71856 (43) obj. -347.054 iterations 5317
# Cbc0038I Pass  38: (23.99 seconds) suminf.    3.66150 (47) obj. -347.054 iterations 835
# Cbc0038I Pass  39: (24.28 seconds) suminf.    9.32467 (36) obj. -347.054 iterations 2042
# Cbc0038I Pass  40: (24.35 seconds) suminf.    8.98030 (39) obj. -347.054 iterations 353
# Cbc0038I Pass  41: (24.86 seconds) suminf.    4.79532 (46) obj. -353.029 iterations 3734
# Cbc0038I Pass  42: (24.90 seconds) suminf.    4.55496 (43) obj. -353.697 iterations 207
# Cbc0038I Pass  43: (25.27 seconds) suminf.    3.52924 (40) obj. -347.054 iterations 2368
# Cbc0038I Pass  44: (25.34 seconds) suminf.    3.37507 (50) obj. -347.054 iterations 365
# Cbc0038I Pass  45: (25.55 seconds) suminf.    4.75949 (36) obj. -347.054 iterations 1460
# Cbc0038I Pass  46: (25.86 seconds) suminf.    5.42463 (51) obj. -347.054 iterations 1603
# Cbc0038I Pass  47: (26.51 seconds) suminf.    4.44573 (51) obj. -347.054 iterations 4106
# Cbc0038I Pass  48: (26.81 seconds) suminf.    4.99495 (56) obj. -347.054 iterations 2258
# Cbc0038I Pass  49: (27.10 seconds) suminf.    3.71430 (50) obj. -347.054 iterations 2040
# Cbc0038I Pass  50: (27.41 seconds) suminf.    6.91316 (38) obj. -347.054 iterations 2089
# Cbc0038I Pass  51: (27.76 seconds) suminf.    4.45866 (39) obj. -347.054 iterations 2234
# Cbc0038I Pass  52: (28.21 seconds) suminf.    3.71430 (50) obj. -347.054 iterations 2911
# Cbc0038I Pass  53: (28.71 seconds) suminf.    6.02182 (39) obj. -347.054 iterations 2581
# Cbc0038I Pass  54: (28.78 seconds) suminf.    5.38499 (45) obj. -347.054 iterations 339
# Cbc0038I Pass  55: (28.88 seconds) suminf.    7.71694 (31) obj. -347.054 iterations 550
# Cbc0038I Pass  56: (28.94 seconds) suminf.    7.53494 (37) obj. -347.054 iterations 234
# Cbc0038I Pass  57: (29.47 seconds) suminf.    3.53872 (38) obj. -350.525 iterations 3187
# Cbc0038I Pass  58: (29.85 seconds) suminf.    6.65416 (31) obj. -347.054 iterations 2343
# Cbc0038I Pass  59: (30.20 seconds) suminf.    4.63643 (39) obj. -347.054 iterations 2699
# Cbc0038I Pass  60: (30.67 seconds) suminf.    3.85548 (40) obj. -347.054 iterations 3194
# Cbc0038I Pass  61: (31.12 seconds) suminf.    5.29319 (33) obj. -347.054 iterations 3147
# Cbc0038I Pass  62: (31.39 seconds) suminf.    5.24529 (56) obj. -347.054 iterations 1954
# Cbc0038I Pass  63: (31.78 seconds) suminf.    4.16148 (51) obj. -347.054 iterations 2633
# Cbc0038I Pass  64: (32.23 seconds) suminf.    7.72980 (40) obj. -347.054 iterations 2883
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 35184 integers at bound fixed and 1 continuous
# Cbc0038I Full problem 14873 rows 35632 columns, reduced to 172 rows 171 columns
# Cbc0038I Mini branch and bound did not improve solution (32.27 seconds)
# Cbc0038I After 32.27 seconds - Feasibility pump exiting with objective of -343.167 - took 18.62 seconds
# Cbc0012I Integer solution of -343.16692 found by feasibility pump after 0 iterations and 0 nodes (32.28 seconds)
# Cbc0038I Full problem 14873 rows 35632 columns, reduced to 75 rows 60 columns
# Cbc0031I 11 added rows had average density of 1101.4545
# Cbc0013I At root node, 11 cuts changed objective from -362.60446 to -359.86265 in 6 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 358 column cuts (358 active)  in 0.110 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4 row cuts average 894.5 elements, 0 column cuts (0 active)  in 0.207 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.096 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 18 row cuts average 1230.4 elements, 0 column cuts (0 active)  in 0.035 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 734.0 elements, 0 column cuts (0 active)  in 0.029 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 4 row cuts average 553.2 elements, 0 column cuts (0 active)  in 0.743 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -343.16692 best solution, best possible -359.86265 (36.68 seconds)
# Cbc0012I Integer solution of -349.51958 found by DiveCoefficient after 5085 iterations and 3 nodes (41.47 seconds)
# Cbc0012I Integer solution of -349.58762 found by DiveCoefficient after 6244 iterations and 5 nodes (45.42 seconds)
# Cbc0012I Integer solution of -353.45588 found by DiveCoefficient after 8143 iterations and 5 nodes (47.51 seconds)
# Cbc0038I Full problem 14873 rows 35632 columns, reduced to 90 rows 75 columns
# Cbc0004I Integer solution of -354.91304 found after 60221 iterations and 67 nodes (74.86 seconds)
# Cbc0038I Full problem 14873 rows 35632 columns, reduced to 132 rows 110 columns
# Cbc0010I After 100 nodes, 11 on tree, -354.91304 best solution, best possible -359.86265 (78.12 seconds)
# Cbc0038I Full problem 14873 rows 35632 columns, reduced to 21 rows 17 columns
# Cbc0010I After 200 nodes, 9 on tree, -354.91304 best solution, best possible -359.86265 (91.04 seconds)
# Cbc0004I Integer solution of -355.17234 found after 95994 iterations and 225 nodes (92.19 seconds)
# Cbc0004I Integer solution of -355.25234 found after 96194 iterations and 230 nodes (92.24 seconds)
# Cbc0004I Integer solution of -356.02554 found after 98026 iterations and 251 nodes (93.02 seconds)
# Cbc0004I Integer solution of -356.04924 found after 98118 iterations and 253 nodes (93.13 seconds)
# Cbc0004I Integer solution of -356.12924 found after 98741 iterations and 262 nodes (93.33 seconds)
# Cbc0012I Integer solution of -356.22304 found by DiveCoefficient after 103918 iterations and 277 nodes (98.30 seconds)
# Cbc0004I Integer solution of -356.30304 found after 104049 iterations and 280 nodes (98.50 seconds)
# Cbc0010I After 300 nodes, 7 on tree, -356.30304 best solution, best possible -359.86265 (102.43 seconds)
# Cbc0010I After 400 nodes, 10 on tree, -356.30304 best solution, best possible -359.34203 (122.73 seconds)
# Cbc0038I Full problem 14873 rows 35632 columns, reduced to 81 rows 60 columns
# Cbc0004I Integer solution of -356.3232 found after 126256 iterations and 417 nodes (123.35 seconds)
# Cbc0001I Search completed - best objective -356.3231999999999, took 131305 iterations and 472 nodes (125.72 seconds)
# Cbc0032I Strong branching done 1498 times (15275 iterations), fathomed 6 nodes and fixed 7 variables
# Cbc0035I Maximum depth 27, 399057 variables fixed on reduced cost
# Cuts at root node changed objective from -362.604 to -359.863
# Probing was tried 185 times and created 526 cuts of which 0 were active after adding rounds of cuts (0.499 seconds)
# Gomory was tried 6 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.207 seconds)
# Knapsack was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.096 seconds)
# Clique was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 185 times and created 550 cuts of which 0 were active after adding rounds of cuts (0.787 seconds)
# FlowCover was tried 6 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.029 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.042 seconds)
# ZeroHalf was tried 185 times and created 17 cuts of which 0 were active after adding rounds of cuts (21.377 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -356.32320000
# Enumerated nodes:               472
# Total iterations:               131305
# Time (CPU seconds):             125.88
# Time (Wallclock seconds):       131.30
#
# Total time (CPU seconds):       125.95   (Wallclock seconds):       131.39
#
#     week              name  pos  type       team  buy_price  sell_price    xP  \
# 3     22           Sánchez  GKP     1   Brighton        4.6         4.6  4.28
# 8     22  Alexander-Arnold  DEF     2  Liverpool        7.3         7.2  4.30
# 1     22           Gabriel  DEF     2    Arsenal        5.2         5.2  4.60
# 16    22          Trippier  DEF     2  Newcastle        6.1         6.0  5.03
# 13    22              Shaw  DEF     2    Man Utd        5.3         5.0  8.54
# ..   ...               ...  ...   ...        ...        ...         ...   ...
# 75    26           Ederson  GKP     1   Man City        5.4         5.4  3.89
# 78    26              Shaw  DEF     2    Man Utd        5.3         5.0  2.13
# 79    26          Trippier  DEF     2  Newcastle        6.1         6.0  2.62
# 76    26               Aké  DEF     2   Man City        5.0         5.0  2.98
# 72    26           Andreas  MID     3     Fulham        4.5         4.5  3.01
#
#     xMin  lineup  bench  captain  vicecaptain  transfer_in  transfer_out
# 3     89       1     -1        0            0            0             0
# 8     86       1     -1        0            0            0             0
# 1     83       1     -1        0            0            0             0
# 16    87       1     -1        0            0            0             0
# 13    82       1     -1        0            0            0             0
# ..   ...     ...    ...      ...          ...          ...           ...
# 75    86       0      0        0            0            0             0
# 78    74       0     -1        0            0            0             1
# 79    78       0      3        0            0            0             0
# 76    64       0      2        0            0            0             0
# 72    71       0      1        0            0            0             0
#
# [81 rows x 15 columns]
# ** GW 22:
# ITB = 0, FT=1.0, PT=1.0
# Sell 19 - Martinelli
# Buy 124 - Mitoma
# Sell 142 - Mount
# Buy 333 - Fernandes
# ** GW 23:
# ITB = 2.1, FT=1.0, PT=0
# Buy 11 - Nketiah
# Sell 297 - Darwin
# ** GW 24:
# ITB = 2.1, FT=1.0, PT=0
# ** GW 25:
# ITB = 0, FT=2.0, PT=0
# Buy 283 - Salah
# Sell 333 - Fernandes
# Sell 335 - Rashford
# Buy 407 - Ward-Prowse
# ** GW 26:
# ITB = 0.3, FT=1.0, PT=0
# Buy 106 - Dunk
# Sell 332 - Shaw
#
# NOTE: Initialized model mp_h5_regular.
# Welcome to the CBC MILP Solver
# Version: 2.10.8
# Build Date: Nov  6 2022
#
# command line - cbc /Users/eirikoye/Documents/GitHub/FPL/Notebook/mp_h5_regular.mps solve solu mp_h5_regular_sol.txt (default strategy 1)
# At line 1 NAME    mp_h5_regular
# At line 2 ROWS
# At line 37645 COLUMNS
# At line 127121 RHS
# At line 130896 RANGES
# At line 130912 BOUNDS
# At line 168369 ENDATA
# Problem mp_h5_regular has 37641 rows, 37456 columns and 146493 elements
# Coin0008I mp_h5_regular read with 0 errors
# Continuous objective value is -384.107 - 3.44 seconds
# Cgl0002I 719 variables fixed
# Cgl0003I 0 fixed, 5 tightened bounds, 31894 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17271 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 13612 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8799 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2242 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0004I processed model has 14873 rows, 35577 columns (35573 integer (35568 of which binary)) and 123998 elements
# Cbc0038I Initial state - 147 integers unsatisfied sum - 37.2104
# Cbc0038I Pass   1: (16.39 seconds) suminf.   11.70020 (47) obj. -366.29 iterations 5309
# Cbc0038I Pass   2: (16.52 seconds) suminf.    2.90880 (16) obj. -362.324 iterations 568
# Cbc0038I Pass   3: (16.56 seconds) suminf.    3.05061 (16) obj. -361.877 iterations 122
# Cbc0038I Pass   4: (16.71 seconds) suminf.    0.00000 (0) obj. -341.688 iterations 627
# Cbc0038I Solution found of -341.688
# Cbc0038I Relaxing continuous gives -341.688
# Cbc0038I Cleaned solution of -341.688
# Cbc0038I Before mini branch and bound, 35392 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 14873 rows 35577 columns, reduced to 115 rows 110 columns
# Cbc0038I Mini branch and bound improved solution from -341.688 to -358.795 (16.83 seconds)
# Cbc0038I Round again with cutoff of -360.209
# Cbc0038I Reduced cost fixing fixed 113 variables on major pass 2
# Cbc0038I Pass   5: (16.85 seconds) suminf.   11.70020 (47) obj. -366.29 iterations 0
# Cbc0038I Pass   6: (17.01 seconds) suminf.    2.90880 (16) obj. -362.324 iterations 663
# Cbc0038I Pass   7: (17.09 seconds) suminf.    3.05061 (16) obj. -361.877 iterations 421
# Cbc0038I Pass   8: (17.62 seconds) suminf.    4.15401 (15) obj. -360.209 iterations 2988
# Cbc0038I Pass   9: (18.40 seconds) suminf.    3.16616 (15) obj. -360.209 iterations 5135
# Cbc0038I Pass  10: (18.90 seconds) suminf.    2.94536 (17) obj. -360.209 iterations 2604
# Cbc0038I Pass  11: (19.30 seconds) suminf.    2.90886 (19) obj. -360.209 iterations 2392
# Cbc0038I Pass  12: (19.51 seconds) suminf.    3.62932 (15) obj. -360.209 iterations 1083
# Cbc0038I Pass  13: (19.54 seconds) suminf.    3.62932 (15) obj. -360.209 iterations 13
# Cbc0038I Pass  14: (20.10 seconds) suminf.    2.92600 (13) obj. -360.209 iterations 2994
# Cbc0038I Pass  15: (20.14 seconds) suminf.    2.84592 (17) obj. -360.209 iterations 108
# Cbc0038I Pass  16: (20.31 seconds) suminf.    3.62932 (15) obj. -360.209 iterations 804
# Cbc0038I Pass  17: (20.45 seconds) suminf.    3.05903 (17) obj. -360.209 iterations 752
# Cbc0038I Pass  18: (20.66 seconds) suminf.    3.24046 (19) obj. -360.209 iterations 1187
# Cbc0038I Pass  19: (20.84 seconds) suminf.    1.92231 (15) obj. -360.209 iterations 987
# Cbc0038I Pass  20: (20.87 seconds) suminf.    1.92231 (15) obj. -360.209 iterations 32
# Cbc0038I Pass  21: (21.49 seconds) suminf.    2.92600 (13) obj. -360.209 iterations 3332
# Cbc0038I Pass  22: (21.51 seconds) suminf.    2.84592 (17) obj. -360.209 iterations 15
# Cbc0038I Pass  23: (21.67 seconds) suminf.    3.62932 (15) obj. -360.209 iterations 856
# Cbc0038I Pass  24: (21.69 seconds) suminf.    3.62932 (15) obj. -360.209 iterations 10
# Cbc0038I Pass  25: (22.22 seconds) suminf.    2.92600 (13) obj. -360.209 iterations 2910
# Cbc0038I Pass  26: (22.39 seconds) suminf.    3.16277 (17) obj. -360.209 iterations 930
# Cbc0038I Pass  27: (22.57 seconds) suminf.    3.07344 (19) obj. -360.209 iterations 1063
# Cbc0038I Pass  28: (22.75 seconds) suminf.    3.29153 (15) obj. -360.209 iterations 896
# Cbc0038I Pass  29: (22.77 seconds) suminf.    3.29153 (15) obj. -360.209 iterations 13
# Cbc0038I Pass  30: (23.12 seconds) suminf.    3.11538 (13) obj. -360.209 iterations 2096
# Cbc0038I Pass  31: (23.27 seconds) suminf.    2.94293 (13) obj. -360.209 iterations 961
# Cbc0038I Pass  32: (23.45 seconds) suminf.    4.57540 (15) obj. -360.209 iterations 990
# Cbc0038I Pass  33: (23.47 seconds) suminf.    4.57540 (15) obj. -360.209 iterations 8
# Cbc0038I Pass  34: (23.62 seconds) suminf.    4.07759 (15) obj. -360.209 iterations 1132
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 35377 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 14873 rows 35577 columns, reduced to 119 rows 116 columns
# Cbc0038I Mini branch and bound did not improve solution (23.65 seconds)
# Cbc0038I After 23.65 seconds - Feasibility pump exiting with objective of -358.795 - took 8.46 seconds
# Cbc0012I Integer solution of -358.7948 found by feasibility pump after 0 iterations and 0 nodes (23.65 seconds)
# Cbc0038I Full problem 14873 rows 35577 columns, reduced to 6 rows 6 columns
# Cbc0031I 10 added rows had average density of 1174.3
# Cbc0013I At root node, 10 cuts changed objective from -372.937 to -366.53508 in 7 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 2071 column cuts (2071 active)  in 0.433 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 3 row cuts average 737.0 elements, 0 column cuts (0 active)  in 0.186 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.109 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 20 row cuts average 1202.9 elements, 0 column cuts (0 active)  in 0.038 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 3 row cuts average 734.0 elements, 0 column cuts (0 active)  in 0.035 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 9 row cuts average 896.2 elements, 0 column cuts (0 active)  in 0.895 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -358.7948 best solution, best possible -366.53508 (29.34 seconds)
# Cbc0012I Integer solution of -360.74812 found by DiveCoefficient after 3049 iterations and 3 nodes (32.60 seconds)
# Cbc0038I Full problem 14873 rows 35577 columns, reduced to 98 rows 76 columns
# Cbc0004I Integer solution of -361.84698 found after 19272 iterations and 50 nodes (44.02 seconds)
# Cbc0038I Full problem 14883 rows 35577 columns, reduced to 14230 rows 31485 columns - too large
# Cbc0004I Integer solution of -362.2018 found after 23540 iterations and 71 nodes (46.34 seconds)
# Cbc0004I Integer solution of -362.5247 found after 24017 iterations and 81 nodes (46.51 seconds)
# Cbc0038I Full problem 14873 rows 35577 columns, reduced to 172 rows 142 columns
# Cbc0010I After 100 nodes, 9 on tree, -362.5247 best solution, best possible -366.53508 (52.74 seconds)
# Cbc0001I Search completed - best objective -362.5246958119999, took 59151 iterations and 188 nodes (67.25 seconds)
# Cbc0032I Strong branching done 826 times (9532 iterations), fathomed 3 nodes and fixed 0 variables
# Cbc0035I Maximum depth 20, 175810 variables fixed on reduced cost
# Cuts at root node changed objective from -372.937 to -366.535
# Probing was tried 75 times and created 2134 cuts of which 0 were active after adding rounds of cuts (0.581 seconds)
# Gomory was tried 7 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.186 seconds)
# Knapsack was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.109 seconds)
# Clique was tried 7 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 75 times and created 165 cuts of which 0 were active after adding rounds of cuts (0.283 seconds)
# FlowCover was tried 75 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.163 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.041 seconds)
# ZeroHalf was tried 75 times and created 101 cuts of which 0 were active after adding rounds of cuts (8.924 seconds)
#
# Result - Optimal solution found
#
# Objective value:                -362.52469581
# Enumerated nodes:               188
# Total iterations:               59151
# Time (CPU seconds):             67.39
# Time (Wallclock seconds):       69.35
#
# Total time (CPU seconds):       67.47   (Wallclock seconds):       69.44
#
#     week              name  pos  type       team  buy_price  sell_price    xP  \
# 3     22           Sánchez  GKP     1   Brighton        4.6         4.6  4.19
# 8     22  Alexander-Arnold  DEF     2  Liverpool        7.3         7.2  4.57
# 16    22          Trippier  DEF     2  Newcastle        6.1         6.0  5.21
# 13    22              Shaw  DEF     2    Man Utd        5.3         5.0  8.14
# 0     22              Saka  MID     3    Arsenal        8.2         8.1  5.04
# ..   ...               ...  ...   ...        ...        ...         ...   ...
# 78    26           Ederson  GKP     1   Man City        5.4         5.4  4.16
# 81    26              Shaw  DEF     2    Man Utd        5.3         5.0  2.21
# 73    26           Andreas  MID     3     Fulham        4.5         4.5  2.76
# 74    26            Gnonto  FWD     4      Leeds        5.0         5.0  3.06
# 77    26            Darwin  FWD     4  Liverpool        8.8         8.8  3.16
#
#     xMin  lineup  bench  captain  vicecaptain  transfer_in  transfer_out
# 3     89       1     -1        0            0            0             0
# 8     86       1     -1        0            0            0             0
# 16    87       1     -1        0            0            0             0
# 13    82       1     -1        0            0            0             0
# 0     83       1     -1        0            0            0             0
# ..   ...     ...    ...      ...          ...          ...           ...
# 78    86       0      0        0            0            0             0
# 81    74       0      3        0            0            0             0
# 73    71       0      2        0            0            0             0
# 74    63       0      1        0            0            0             0
# 77    62       0     -1        0            0            0             1
#
# [82 rows x 15 columns]
# ** GW 22:
# ITB = 0.3, FT=1.0, PT=1.0
# Sell 142 - Mount
# Sell 210 - Mitrović
# Buy 619 - Gnonto
# Buy 333 - Fernandes
# ** GW 23:
# ITB = 0.1, FT=1.0, PT=0
# Buy 7 - Ødegaard
# Sell 19 - Martinelli
# ** GW 24:
# ITB = 3.1, FT=1.0, PT=1.0
# Buy 106 - Dunk
# Buy 107 - March
# Sell 335 - Rashford
# Sell 357 - Trippier
# ** GW 25:
# ITB = 0.3, FT=1.0, PT=0
# Buy 283 - Salah
# Sell 333 - Fernandes
# ** GW 26:
# ITB = 1.3, FT=1.0, PT=0
# Buy 145 - Havertz
# Sell 297 - Darwin

# %%
sjekk =pd.read_csv("../output/optimal_plan_regular.csv")

# %%
sjekk
# Out:
#     Unnamed: 0  week              name  pos  type       team  buy_price  \
# 0            3    22           Sánchez  GKP     1   Brighton        4.6
# 1            8    22  Alexander-Arnold  DEF     2  Liverpool        7.3
# 2            1    22           Gabriel  DEF     2    Arsenal        5.2
# 3           16    22          Trippier  DEF     2  Newcastle        6.1
# 4           13    22              Shaw  DEF     2    Man Utd        5.3
# ..         ...   ...               ...  ...   ...        ...        ...
# 76          75    26           Ederson  GKP     1   Man City        5.4
# 77          78    26              Shaw  DEF     2    Man Utd        5.3
# 78          79    26          Trippier  DEF     2  Newcastle        6.1
# 79          76    26               Aké  DEF     2   Man City        5.0
# 80          72    26           Andreas  MID     3     Fulham        4.5
#
#     sell_price    xP  xMin  lineup  bench  captain  vicecaptain  transfer_in  \
# 0          4.6  4.28    89       1     -1        0            0            0
# 1          7.2  4.30    86       1     -1        0            0            0
# 2          5.2  4.60    83       1     -1        0            0            0
# 3          6.0  5.03    87       1     -1        0            0            0
# 4          5.0  8.54    82       1     -1        0            0            0
# ..         ...   ...   ...     ...    ...      ...          ...          ...
# 76         5.4  3.89    86       0      0        0            0            0
# 77         5.0  2.13    74       0     -1        0            0            0
# 78         6.0  2.62    78       0      3        0            0            0
# 79         5.0  2.98    64       0      2        0            0            0
# 80         4.5  3.01    71       0      1        0            0            0
#
#     transfer_out
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 76             0
# 77             1
# 78             0
# 79             0
# 80             0
#
# [81 rows x 16 columns]
